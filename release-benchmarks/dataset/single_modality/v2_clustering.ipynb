# %%
datasets= ["mouse_kidney_cell","human_pbmc_cell","human_pbmc2_cell","human_skin_cell","human_lung_cell","mouse_kidney_drop","mouse_kidney_cl2","mouse_kidney_10x"]

# %%
import argparse

import numpy as np

from dance.datasets.singlemodality import ClusteringDataset
from dance.modules.single_modality.clustering.graphsc import GraphSC
from dance.utils import set_seed


parser = argparse.ArgumentParser()
parser.add_argument("-e", "--epochs", default=100, type=int)
parser.add_argument("-dv", "--device", default="cpu")
parser.add_argument("-if", "--in_feats", default=50, type=int)
parser.add_argument("-bs", "--batch_size", default=128, type=int)
parser.add_argument("-nw", "--normalize_weights", default="log_per_cell", choices=["log_per_cell", "per_cell"])
parser.add_argument("-ac", "--activation", default="relu", choices=["leaky_relu", "relu", "prelu", "gelu"])
parser.add_argument("-drop", "--dropout", default=0.1, type=float)
parser.add_argument("-nf", "--node_features", default="scale", choices=["scale_by_cell", "scale", "none"])
parser.add_argument("-sev", "--same_edge_values", default=False, action="store_true")
parser.add_argument("-en", "--edge_norm", default=True, action="store_true")
parser.add_argument("-hr", "--hidden_relu", default=False, action="store_true")
parser.add_argument("-hbn", "--hidden_bn", default=False, action="store_true")
parser.add_argument("-lr", "--learning_rate", type=float, default=1e-5)
parser.add_argument("-nl", "--n_layers", type=int, default=1, choices=[1, 2])
parser.add_argument("-agg", "--agg", default="sum", choices=["sum", "mean"])
parser.add_argument("-hd", "--hidden_dim", type=int, default=200)
parser.add_argument("-nh", "--n_hidden", type=int, default=1, choices=[0, 1, 2])
parser.add_argument("-h1", "--hidden_1", type=int, default=300)
parser.add_argument("-h2", "--hidden_2", type=int, default=0)
parser.add_argument("-ng", "--nb_genes", type=int, default=3000)
parser.add_argument("-nr", "--num_run", type=int, default=1)
parser.add_argument("-nbw", "--num_workers", type=int, default=1)
parser.add_argument("-eve", "--eval_epoch", action="store_true")
parser.add_argument("-show", "--show_epoch_ari", action="store_true")
parser.add_argument("-plot", "--plot", default=False, action="store_true")
parser.add_argument("-dd", "--data_dir", default="./data", type=str)
parser.add_argument("-data", "--dataset", default="10X_PBMC",
                    choices=["10X_PBMC", "mouse_bladder_cell", "mouse_ES_cell", "worm_neuron_cell","mouse_kidney_cell","human_pbmc_cell","human_pbmc2_cell","human_skin_cell","human_lung_cell","mouse_kidney_drop","mouse_kidney_cl2","mouse_kidney_10x"])
parser.add_argument("--seed", type=int, default=42)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
graphsc_scores=[]
for dataset in datasets:
    args = parser.parse_args(args=['--dataset',dataset])
    set_seed(args.seed)

    # Load data and perform necessary preprocessing
    dataloader = ClusteringDataset(args.data_dir, args.dataset)
    preprocessing_pipeline = GraphSC.preprocessing_pipeline(
        n_top_genes=args.nb_genes,
        normalize_weights=args.normalize_weights,
        n_components=args.in_feats,
        normalize_edges=args.edge_norm,
    )
    data = dataloader.load_data(transform=preprocessing_pipeline, cache=args.cache)

    graph, y = data.get_train_data()
    n_clusters = len(np.unique(y))

    # Evaluate model for several runs
    for run in range(args.num_run):
        set_seed(args.seed + run)
        model = GraphSC(agg=args.agg, activation=args.activation, in_feats=args.in_feats, n_hidden=args.n_hidden,
                        hidden_dim=args.hidden_dim, hidden_1=args.hidden_1, hidden_2=args.hidden_2,
                        dropout=args.dropout, n_layers=args.n_layers, hidden_relu=args.hidden_relu,
                        hidden_bn=args.hidden_bn, n_clusters=n_clusters, cluster_method="leiden",
                        num_workers=args.num_workers, device=args.device)
        model.fit(graph, epochs=args.epochs, lr=args.learning_rate, show_epoch_ari=args.show_epoch_ari,
                  eval_epoch=args.eval_epoch)
        score = model.score(None, y)
        print(f"{score=:.4f}")
        graphsc_scores.append(score)
""" Reproduction information
10X PBMC:
python graphsc.py --dataset 10X_PBMC

Mouse ES:
python graphsc.py --dataset mouse_ES_cell

Worm Neuron:
python graphsc.py --dataset worm_neuron_cell

Mouse Bladder:
python graphsc.py --dataset mouse_bladder_cell
"""
# Out:
# [INFO][2023-09-02 15:44:15,069][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:44:15,235][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:44:15,236][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:44:15,588][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:44:15,597][dance.WeightedFeaturePCA][__call__] Start decomposing None features (902, 3000) (k=50)
# [INFO][2023-09-02 15:44:15,636][dance.WeightedFeaturePCA][__call__] Total explained variance: 47.53%
# [INFO][2023-09-02 15:44:15,718][dance.CellFeatureGraph][__call__] Number of nonzero entries: 1,423,104
# [INFO][2023-09-02 15:44:15,719][dance.CellFeatureGraph][__call__] Nonzero rate = 52.6%
# [INFO][2023-09-02 15:44:16,445][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:44:16,445][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:44:16,446][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:44:16,446][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:44:16,447][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 3000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:44:16,447][dance][wrapped_func] Took 0:00:01.375210 to load and process data.
# [WARNING][2023-09-02 15:44:16,448][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:44:16,449][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [01:56<00:00,  1.17s/it]
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# [INFO][2023-09-02 15:46:19,379][dance][set_seed] Setting global random seed to 42
# score=0.4672
# [INFO][2023-09-02 15:46:19,733][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 64535
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:46:19,734][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:46:20,202][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:46:20,207][dance.WeightedFeaturePCA][__call__] Start decomposing None features (648, 3000) (k=50)
# [INFO][2023-09-02 15:46:20,233][dance.WeightedFeaturePCA][__call__] Total explained variance: 17.32%
# [INFO][2023-09-02 15:46:20,253][dance.CellFeatureGraph][__call__] Number of nonzero entries: 114,062
# [INFO][2023-09-02 15:46:20,254][dance.CellFeatureGraph][__call__] Nonzero rate = 5.9%
# [INFO][2023-09-02 15:46:20,820][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:46:20,820][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:46:20,821][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:46:20,821][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:46:20,821][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 3000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:46:20,822][dance][wrapped_func] Took 0:00:01.441702 to load and process data.
# [WARNING][2023-09-02 15:46:20,823][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:46:20,824][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [00:09<00:00, 10.80it/s]
# [INFO][2023-09-02 15:46:31,839][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:46:31,917][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:46:31,918][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# score=0.5969
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:46:32,055][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:46:32,078][dance.WeightedFeaturePCA][__call__] Start decomposing None features (8218, 1000) (k=50)
# [INFO][2023-09-02 15:46:32,144][dance.WeightedFeaturePCA][__call__] Total explained variance: 29.20%
# [INFO][2023-09-02 15:46:32,314][dance.CellFeatureGraph][__call__] Number of nonzero entries: 3,923,204
# [INFO][2023-09-02 15:46:32,315][dance.CellFeatureGraph][__call__] Nonzero rate = 47.7%
# [INFO][2023-09-02 15:46:33,993][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:46:33,994][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:46:33,995][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:46:33,996][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:46:33,997][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:46:33,999][dance][wrapped_func] Took 0:00:02.157613 to load and process data.
# [WARNING][2023-09-02 15:46:34,000][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:46:34,002][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [05:12<00:00,  3.13s/it]
# [INFO][2023-09-02 15:52:53,535][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:52:53,575][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:52:53,577][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# score=0.2442
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:52:53,704][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:52:53,718][dance.WeightedFeaturePCA][__call__] Start decomposing None features (4853, 1000) (k=50)
# [INFO][2023-09-02 15:52:53,767][dance.WeightedFeaturePCA][__call__] Total explained variance: 46.04%
# [INFO][2023-09-02 15:52:53,885][dance.CellFeatureGraph][__call__] Number of nonzero entries: 2,819,267
# [INFO][2023-09-02 15:52:53,886][dance.CellFeatureGraph][__call__] Nonzero rate = 58.1%
# [INFO][2023-09-02 15:52:54,999][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:52:55,000][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:52:55,000][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:52:55,000][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:52:55,001][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:52:55,001][dance][wrapped_func] Took 0:00:01.463173 to load and process data.
# [WARNING][2023-09-02 15:52:55,003][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:52:55,004][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [03:54<00:00,  2.34s/it]
# [INFO][2023-09-02 15:57:06,900][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:57:06,913][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:57:06,914][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# score=0.4977
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:57:06,967][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:57:06,972][dance.WeightedFeaturePCA][__call__] Start decomposing None features (1756, 999) (k=50)
# [INFO][2023-09-02 15:57:07,000][dance.WeightedFeaturePCA][__call__] Total explained variance: 29.91%
# [INFO][2023-09-02 15:57:07,026][dance.CellFeatureGraph][__call__] Number of nonzero entries: 359,184
# [INFO][2023-09-02 15:57:07,027][dance.CellFeatureGraph][__call__] Nonzero rate = 20.5%
# [INFO][2023-09-02 15:57:07,521][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:57:07,522][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:57:07,522][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:57:07,523][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:57:07,523][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 999
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:57:07,523][dance][wrapped_func] Took 0:00:00.621243 to load and process data.
# [WARNING][2023-09-02 15:57:07,524][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:57:07,525][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [00:19<00:00,  5.11it/s]
# [INFO][2023-09-02 15:57:31,389][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:57:31,414][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:57:31,415][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# score=0.5912
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:57:31,516][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:57:31,519][dance.WeightedFeaturePCA][__call__] Start decomposing None features (225, 3000) (k=50)
# [INFO][2023-09-02 15:57:31,532][dance.WeightedFeaturePCA][__call__] Total explained variance: 46.23%
# [INFO][2023-09-02 15:57:31,544][dance.CellFeatureGraph][__call__] Number of nonzero entries: 235,178
# [INFO][2023-09-02 15:57:31,545][dance.CellFeatureGraph][__call__] Nonzero rate = 34.8%
# [INFO][2023-09-02 15:57:32,052][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:57:32,053][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:57:32,053][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:57:32,054][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:57:32,054][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 3000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:57:32,055][dance][wrapped_func] Took 0:00:00.664664 to load and process data.
# [WARNING][2023-09-02 15:57:32,055][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:57:32,056][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [00:19<00:00,  5.13it/s]
# WARNING: n_obs too small: adjusting to `n_neighbors = 113`
# [INFO][2023-09-02 15:57:51,724][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:57:51,748][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:57:51,749][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# score=0.9097
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:57:51,853][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:57:51,855][dance.WeightedFeaturePCA][__call__] Start decomposing None features (225, 3000) (k=50)
# [INFO][2023-09-02 15:57:51,868][dance.WeightedFeaturePCA][__call__] Total explained variance: 46.23%
# [INFO][2023-09-02 15:57:51,881][dance.CellFeatureGraph][__call__] Number of nonzero entries: 235,178
# [INFO][2023-09-02 15:57:51,881][dance.CellFeatureGraph][__call__] Nonzero rate = 34.8%
# [INFO][2023-09-02 15:57:52,387][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:57:52,388][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:57:52,388][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:57:52,389][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:57:52,389][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 3000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:57:52,389][dance][wrapped_func] Took 0:00:00.663815 to load and process data.
# [WARNING][2023-09-02 15:57:52,390][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:57:52,391][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [00:19<00:00,  5.06it/s]
# WARNING: n_obs too small: adjusting to `n_neighbors = 113`
# [INFO][2023-09-02 15:58:12,368][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 15:58:12,500][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 15:58:12,500][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 1}),
#   PCACellFeatureGraph(n_components=50, split_name=None),
#   SetConfig(config_dict={'feature_channel': 'CellFeatureGraph', 'feature_channel_type': 'uns', 'label_channel': 'Group'}),
# )
# score=0.9097
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 15:58:12,974][dance.WeightedFeaturePCA][__call__] Normalizing feature before PCA decomposition with mode=standardize and axis=0
# [INFO][2023-09-02 15:58:12,983][dance.WeightedFeaturePCA][__call__] Start decomposing None features (902, 3000) (k=50)
# [INFO][2023-09-02 15:58:13,018][dance.WeightedFeaturePCA][__call__] Total explained variance: 47.53%
# [INFO][2023-09-02 15:58:13,079][dance.CellFeatureGraph][__call__] Number of nonzero entries: 1,423,104
# [INFO][2023-09-02 15:58:13,080][dance.CellFeatureGraph][__call__] Nonzero rate = 52.6%
# [INFO][2023-09-02 15:58:13,786][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': 'CellFeatureGraph',
#  'feature_channel_type': 'uns',
#  'label_channel': 'Group'}
# [INFO][2023-09-02 15:58:13,787][dance][set_config_from_dict] Setting config 'feature_channel' to 'CellFeatureGraph'
# [INFO][2023-09-02 15:58:13,787][dance][set_config_from_dict] Setting config 'feature_channel_type' to 'uns'
# [INFO][2023-09-02 15:58:13,788][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 15:58:13,788][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 3000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dance_config', 'log1p', 'hvg', 'CellFeatureGraph'
#     obsm: 'Group', 'WeightedFeaturePCA'
#     varm: 'WeightedFeaturePCA'
# [INFO][2023-09-02 15:58:13,789][dance][wrapped_func] Took 0:00:01.419508 to load and process data.
# [WARNING][2023-09-02 15:58:13,789][dance][get_feature] Indexing option for 'uns' not implemented yet.
# [INFO][2023-09-02 15:58:13,791][dance][set_seed] Setting global random seed to 42
#   0%|          | 0/100 [00:00<?, ?it/s]/home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 100%|██████████| 100/100 [01:56<00:00,  1.16s/it]
# score=0.4672
# ' Reproduction information\n10X PBMC:\npython graphsc.py --dataset 10X_PBMC\n\nMouse ES:\npython graphsc.py --dataset mouse_ES_cell\n\nWorm Neuron:\npython graphsc.py --dataset worm_neuron_cell\n\nMouse Bladder:\npython graphsc.py --dataset mouse_bladder_cell\n'

# %%
graphsc_scores
# Out:
# [0.4672362410138263,
#  0.5968663719240431,
#  0.24416902238895835,
#  0.49769852192025643,
#  0.5912071617671083,
#  0.9097075531594662,
#  0.9097075531594662,
#  0.4672362410138263]

# %%
import argparse
import os

import numpy as np

from dance.datasets.singlemodality import ClusteringDataset
from dance.modules.single_modality.clustering.scdcc import ScDCC
from dance.transforms.preprocess import generate_random_pair
from dance.utils import set_seed

parser = argparse.ArgumentParser(description="train", formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--label_cells", default=0.1, type=float)
parser.add_argument("--label_cells_files", default="label_mouse_ES_cell.txt")
parser.add_argument("--n_pairwise", default=0, type=int)
parser.add_argument("--n_pairwise_error", default=0, type=float)
parser.add_argument("--batch_size", default=256, type=int)
parser.add_argument("--data_dir", default="./data")
parser.add_argument("--dataset", default="mouse_ES_cell", type=str,
                    choices=["10X_PBMC", "mouse_bladder_cell", "mouse_ES_cell", "worm_neuron_cell","mouse_kidney_cell","human_pbmc_cell","human_pbmc2_cell","human_skin_cell","human_lung_cell","mouse_kidney_drop","mouse_kidney_cl2","mouse_kidney_10x"])
parser.add_argument("--epochs", default=500, type=int)
parser.add_argument("--pretrain_epochs", default=50, type=int)
parser.add_argument("--lr", default=0.01, type=float)
parser.add_argument("--pretrain_lr", default=0.001, type=float)
parser.add_argument("--sigma", default=2.5, type=float, help="coefficient of Gaussian noise")
parser.add_argument("--gamma", default=1., type=float, help="coefficient of clustering loss")
parser.add_argument("--ml_weight", default=1., type=float, help="coefficient of must-link loss")
parser.add_argument("--cl_weight", default=1., type=float, help="coefficient of cannot-link loss")
parser.add_argument("--update_interval", default=1, type=int)
parser.add_argument("--tol", default=0.00001, type=float)
parser.add_argument("--ae_weights", default=None)
parser.add_argument("--ae_weight_file", default="AE_weights.pth.tar")
parser.add_argument("--device", default="cpu")
parser.add_argument("--seed", type=int, default=42)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
scdcc_scores=[]
for dataset in datasets:
    args = parser.parse_args(['--dataset',dataset,'--label_cells_files','label_mouse_kidney.txt','--gamma','1.5'])
    set_seed(args.seed)

    # Load data and perform necessary preprocessing
    dataloader = ClusteringDataset(args.data_dir, args.dataset)
    preprocessing_pipeline = ScDCC.preprocessing_pipeline()
    data = dataloader.load_data(transform=preprocessing_pipeline, cache=args.cache)

    # inputs: x, x_raw, n_counts
    inputs, y = data.get_train_data()
    n_clusters = len(np.unique(y))
    in_dim = inputs[0].shape[1]

    # Generate random pairs
    if not os.path.exists(args.label_cells_files):
        indx = np.arange(len(y))
        np.random.shuffle(indx)
        label_cell_indx = indx[0:int(np.ceil(args.label_cells * len(y)))]
    else:
        label_cell_indx = np.loadtxt(args.label_cells_files, dtype=np.int)

    if args.n_pairwise > 0:
        ml_ind1, ml_ind2, cl_ind1, cl_ind2, error_num = generate_random_pair(y, label_cell_indx, args.n_pairwise,
                                                                             args.n_pairwise_error)
        print("Must link paris: %d" % ml_ind1.shape[0])
        print("Cannot link paris: %d" % cl_ind1.shape[0])
        print("Number of error pairs: %d" % error_num)
    else:
        ml_ind1, ml_ind2, cl_ind1, cl_ind2 = np.array([]), np.array([]), np.array([]), np.array([])

    # Build and train moodel
    model = ScDCC(input_dim=in_dim, z_dim=32, n_clusters=n_clusters, encodeLayer=[256, 64], decodeLayer=[64, 256],
                  sigma=args.sigma, gamma=args.gamma, ml_weight=args.ml_weight, cl_weight=args.ml_weight,
                  device=args.device, pretrain_path=f"scdcc_{args.dataset}_pre.pkl")
    model.fit(inputs, y, lr=args.lr, batch_size=args.batch_size, epochs=args.epochs, ml_ind1=ml_ind1, ml_ind2=ml_ind2,
              cl_ind1=cl_ind1, cl_ind2=cl_ind2, update_interval=args.update_interval, tol=args.tol,
              pt_batch_size=args.batch_size, pt_lr=args.pretrain_lr, pt_epochs=args.pretrain_epochs)

    # Evaluate model predictions
    score = model.score(None, y)
    print(f"{score=:.4f}")
    scdcc_scores.append(score)
""" Reproduction information
10X PBMC:
python scdcc.py --dataset 10X_PBMC --label_cells_files label_10X_PBMC.txt --gamma=1.5

Mouse ES:
python scdcc.py --dataset mouse_ES_cell --label_cells_files label_mouse_ES_cell.txt --gamma 1 --ml_weight 0.8 --cl_weight 0.8

Worm Neuron:
python scdcc.py --dataset worm_neuron_cell --label_cells_files label_worm_neuron_cell.txt --gamma 1 --pretrain_epochs 300

Mouse Bladder:
python scdcc.py --dataset mouse_bladder_cell --label_cells_files label_mouse_bladder_cell.txt --gamma 1.5 --pretrain_epochs 100 --sigma 3
"""
# Out:
# [INFO][2023-09-02 16:00:11,499][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:11,625][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:11,626][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:11,731][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:11,815][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:11,816][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:11,817][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:11,817][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:11,818][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:11,819][dance][wrapped_func] Took 0:00:00.318256 to load and process data.
# [INFO][2023-09-02 16:00:11,944][dance][_pretrain] Loading pre-trained model from scdcc_mouse_kidney_cell_pre.pkl
# [INFO][2023-09-02 16:00:13,094][dance][fit] #Epoch   1: Total: 0.7937, Clustering Loss: 0.1464, ZINB Loss: 0.6473
# [INFO][2023-09-02 16:00:13,214][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:13,232][dance][set_seed] Setting global random seed to 42
# score=0.9965
# [INFO][2023-09-02 16:00:13,466][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 64535
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:13,467][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:13,660][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:13,789][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:13,790][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:13,791][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:13,792][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:13,792][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 34907
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:13,793][dance][wrapped_func] Took 0:00:00.559741 to load and process data.
# [INFO][2023-09-02 16:00:13,984][dance][_pretrain] Loading pre-trained model from scdcc_human_pbmc_cell_pre.pkl
# [INFO][2023-09-02 16:00:15,653][dance][fit] #Epoch   1: Total: 0.4095, Clustering Loss: 0.1560, ZINB Loss: 0.2535
# [INFO][2023-09-02 16:00:15,858][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:15,886][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:15,929][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:15,930][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:16,005][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:16,060][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:16,061][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:16,061][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:16,061][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:16,062][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:16,062][dance][wrapped_func] Took 0:00:00.174926 to load and process data.
# [INFO][2023-09-02 16:00:16,082][dance][_pretrain] Loading pre-trained model from scdcc_human_pbmc2_cell_pre.pkl
# score=0.2302
# [INFO][2023-09-02 16:00:17,046][dance][fit] #Epoch   1: Total: 0.9746, Clustering Loss: 0.2618, ZINB Loss: 0.7129
# [INFO][2023-09-02 16:00:17,599][dance][fit] #Epoch   2: Total: 0.9754, Clustering Loss: 0.2626, ZINB Loss: 0.7129
# [INFO][2023-09-02 16:00:18,151][dance][fit] #Epoch   3: Total: 0.9743, Clustering Loss: 0.2623, ZINB Loss: 0.7120
# [INFO][2023-09-02 16:00:18,719][dance][fit] #Epoch   4: Total: 0.9751, Clustering Loss: 0.2618, ZINB Loss: 0.7133
# [INFO][2023-09-02 16:00:19,273][dance][fit] #Epoch   5: Total: 0.9747, Clustering Loss: 0.2610, ZINB Loss: 0.7136
# [INFO][2023-09-02 16:00:19,825][dance][fit] #Epoch   6: Total: 0.9739, Clustering Loss: 0.2602, ZINB Loss: 0.7136
# [INFO][2023-09-02 16:00:20,377][dance][fit] #Epoch   7: Total: 0.9722, Clustering Loss: 0.2593, ZINB Loss: 0.7130
# [INFO][2023-09-02 16:00:20,927][dance][fit] #Epoch   8: Total: 0.9721, Clustering Loss: 0.2582, ZINB Loss: 0.7139
# [INFO][2023-09-02 16:00:21,479][dance][fit] #Epoch   9: Total: 0.9707, Clustering Loss: 0.2571, ZINB Loss: 0.7136
# [INFO][2023-09-02 16:00:21,582][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:21,586][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:21,619][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:21,620][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:21,676][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:21,710][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:21,710][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:21,710][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:21,711][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:21,711][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:21,712][dance][wrapped_func] Took 0:00:00.124570 to load and process data.
# [INFO][2023-09-02 16:00:21,727][dance][_pretrain] Loading pre-trained model from scdcc_human_skin_cell_pre.pkl
# score=0.5339
# [INFO][2023-09-02 16:00:22,355][dance][fit] #Epoch   1: Total: 0.9328, Clustering Loss: 0.3156, ZINB Loss: 0.6172
# [INFO][2023-09-02 16:00:22,683][dance][fit] #Epoch   2: Total: 0.9370, Clustering Loss: 0.3203, ZINB Loss: 0.6168
# [INFO][2023-09-02 16:00:23,007][dance][fit] #Epoch   3: Total: 0.9392, Clustering Loss: 0.3230, ZINB Loss: 0.6162
# [INFO][2023-09-02 16:00:23,330][dance][fit] #Epoch   4: Total: 0.9411, Clustering Loss: 0.3249, ZINB Loss: 0.6162
# [INFO][2023-09-02 16:00:23,660][dance][fit] #Epoch   5: Total: 0.9435, Clustering Loss: 0.3263, ZINB Loss: 0.6172
# [INFO][2023-09-02 16:00:23,984][dance][fit] #Epoch   6: Total: 0.9426, Clustering Loss: 0.3275, ZINB Loss: 0.6152
# [INFO][2023-09-02 16:00:24,308][dance][fit] #Epoch   7: Total: 0.9441, Clustering Loss: 0.3284, ZINB Loss: 0.6156
# [INFO][2023-09-02 16:00:24,631][dance][fit] #Epoch   8: Total: 0.9455, Clustering Loss: 0.3292, ZINB Loss: 0.6162
# [INFO][2023-09-02 16:00:24,956][dance][fit] #Epoch   9: Total: 0.9464, Clustering Loss: 0.3298, ZINB Loss: 0.6165
# [INFO][2023-09-02 16:00:25,282][dance][fit] #Epoch  10: Total: 0.9469, Clustering Loss: 0.3304, ZINB Loss: 0.6165
# [INFO][2023-09-02 16:00:25,607][dance][fit] #Epoch  11: Total: 0.9477, Clustering Loss: 0.3308, ZINB Loss: 0.6169
# [INFO][2023-09-02 16:00:25,931][dance][fit] #Epoch  12: Total: 0.9486, Clustering Loss: 0.3311, ZINB Loss: 0.6175
# [INFO][2023-09-02 16:00:26,257][dance][fit] #Epoch  13: Total: 0.9484, Clustering Loss: 0.3313, ZINB Loss: 0.6171
# [INFO][2023-09-02 16:00:26,585][dance][fit] #Epoch  14: Total: 0.9490, Clustering Loss: 0.3313, ZINB Loss: 0.6177
# [INFO][2023-09-02 16:00:26,906][dance][fit] #Epoch  15: Total: 0.9494, Clustering Loss: 0.3312, ZINB Loss: 0.6182
# [INFO][2023-09-02 16:00:27,230][dance][fit] #Epoch  16: Total: 0.9484, Clustering Loss: 0.3310, ZINB Loss: 0.6174
# [INFO][2023-09-02 16:00:27,553][dance][fit] #Epoch  17: Total: 0.9501, Clustering Loss: 0.3307, ZINB Loss: 0.6193
# [INFO][2023-09-02 16:00:27,874][dance][fit] #Epoch  18: Total: 0.9495, Clustering Loss: 0.3303, ZINB Loss: 0.6192
# [INFO][2023-09-02 16:00:28,198][dance][fit] #Epoch  19: Total: 0.9506, Clustering Loss: 0.3299, ZINB Loss: 0.6207
# [INFO][2023-09-02 16:00:28,518][dance][fit] #Epoch  20: Total: 0.9498, Clustering Loss: 0.3292, ZINB Loss: 0.6206
# [INFO][2023-09-02 16:00:28,841][dance][fit] #Epoch  21: Total: 0.9492, Clustering Loss: 0.3285, ZINB Loss: 0.6207
# [INFO][2023-09-02 16:00:29,163][dance][fit] #Epoch  22: Total: 0.9487, Clustering Loss: 0.3277, ZINB Loss: 0.6210
# [INFO][2023-09-02 16:00:29,485][dance][fit] #Epoch  23: Total: 0.9488, Clustering Loss: 0.3268, ZINB Loss: 0.6220
# [INFO][2023-09-02 16:00:29,806][dance][fit] #Epoch  24: Total: 0.9481, Clustering Loss: 0.3259, ZINB Loss: 0.6223
# [INFO][2023-09-02 16:00:30,131][dance][fit] #Epoch  25: Total: 0.9474, Clustering Loss: 0.3248, ZINB Loss: 0.6226
# [INFO][2023-09-02 16:00:30,460][dance][fit] #Epoch  26: Total: 0.9461, Clustering Loss: 0.3237, ZINB Loss: 0.6223
# [INFO][2023-09-02 16:00:30,788][dance][fit] #Epoch  27: Total: 0.9456, Clustering Loss: 0.3225, ZINB Loss: 0.6231
# [INFO][2023-09-02 16:00:31,118][dance][fit] #Epoch  28: Total: 0.9460, Clustering Loss: 0.3213, ZINB Loss: 0.6247
# [INFO][2023-09-02 16:00:31,444][dance][fit] #Epoch  29: Total: 0.9449, Clustering Loss: 0.3200, ZINB Loss: 0.6249
# [INFO][2023-09-02 16:00:31,507][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:31,510][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:31,522][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:31,523][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:31,533][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:31,546][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:31,546][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:31,547][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:31,547][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:31,547][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 999
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:31,548][dance][wrapped_func] Took 0:00:00.036383 to load and process data.
# [INFO][2023-09-02 16:00:31,559][dance][_pretrain] Loading pre-trained model from scdcc_human_lung_cell_pre.pkl
# score=0.6258
# [INFO][2023-09-02 16:00:31,819][dance][fit] #Epoch   1: Total: 0.7320, Clustering Loss: 0.2235, ZINB Loss: 0.5085
# [INFO][2023-09-02 16:00:31,844][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:31,846][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:31,871][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:31,871][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:31,893][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:31,917][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:31,917][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:31,918][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:31,918][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:31,918][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:31,919][dance][wrapped_func] Took 0:00:00.071660 to load and process data.
# [INFO][2023-09-02 16:00:32,015][dance][_pretrain] Loading pre-trained model from scdcc_mouse_kidney_drop_pre.pkl
# score=0.7682
# [INFO][2023-09-02 16:00:32,254][dance][fit] #Epoch   1: Total: 0.7840, Clustering Loss: 0.1484, ZINB Loss: 0.6356
# [INFO][2023-09-02 16:00:32,283][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:32,286][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:32,309][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:32,309][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:32,334][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:32,355][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:32,356][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:32,356][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:32,357][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:32,357][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:32,358][dance][wrapped_func] Took 0:00:00.071045 to load and process data.
# [INFO][2023-09-02 16:00:32,451][dance][_pretrain] Loading pre-trained model from scdcc_mouse_kidney_cl2_pre.pkl
# score=0.8688
# [INFO][2023-09-02 16:00:32,671][dance][fit] #Epoch   1: Total: 0.7840, Clustering Loss: 0.1484, ZINB Loss: 0.6356
# [INFO][2023-09-02 16:00:32,702][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# [INFO][2023-09-02 16:00:32,704][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:32,780][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:32,780][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:32,863][dance.SaveRaw][__call__] Saving data to ``.raw``
# score=0.8688
# [INFO][2023-09-02 16:00:32,957][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:32,957][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:32,958][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:32,959][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:32,960][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:32,960][dance][wrapped_func] Took 0:00:00.255337 to load and process data.
# [INFO][2023-09-02 16:00:33,057][dance][_pretrain] Loading pre-trained model from scdcc_mouse_kidney_10x_pre.pkl
# [INFO][2023-09-02 16:00:33,738][dance][fit] #Epoch   1: Total: 0.7926, Clustering Loss: 0.1452, ZINB Loss: 0.6475
# [INFO][2023-09-02 16:00:33,866][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-05). Stopping training.
# score=1.0000
# ' Reproduction information\n10X PBMC:\npython scdcc.py --dataset 10X_PBMC --label_cells_files label_10X_PBMC.txt --gamma=1.5\n\nMouse ES:\npython scdcc.py --dataset mouse_ES_cell --label_cells_files label_mouse_ES_cell.txt --gamma 1 --ml_weight 0.8 --cl_weight 0.8\n\nWorm Neuron:\npython scdcc.py --dataset worm_neuron_cell --label_cells_files label_worm_neuron_cell.txt --gamma 1 --pretrain_epochs 300\n\nMouse Bladder:\npython scdcc.py --dataset mouse_bladder_cell --label_cells_files label_mouse_bladder_cell.txt --gamma 1.5 --pretrain_epochs 100 --sigma 3\n'

# %%
scdcc_scores
# Out:
# [0.9965362702578435,
#  0.2302306982490099,
#  0.5338897606315373,
#  0.6257754637662535,
#  0.7682366319440681,
#  0.8688432600660997,
#  0.8688432600660997,
#  1.0]

# %%
import argparse

import numpy as np

from dance.datasets.singlemodality import ClusteringDataset
from dance.modules.single_modality.clustering.scdeepcluster import ScDeepCluster
from dance.utils import set_seed


parser = argparse.ArgumentParser(description="train", formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--knn", default=20, type=int,
                    help="number of nearest neighbors, used by the Louvain algorithm")
parser.add_argument(
    "--resolution", default=.8, type=float,
    help="resolution parameter, used by the Louvain algorithm, larger value for more number of clusters")
parser.add_argument("--select_genes", default=0, type=int, help="number of selected genes, 0 means using all genes")
parser.add_argument("--batch_size", default=256, type=int)
parser.add_argument("--data_dir", default="./data")
parser.add_argument("--dataset", default="mouse_bladder_cell", type=str,
                    choices=["10X_PBMC", "mouse_bladder_cell", "mouse_ES_cell", "worm_neuron_cell","mouse_kidney_cell","human_pbmc_cell","human_pbmc2_cell","human_skin_cell","human_lung_cell","mouse_kidney_drop","mouse_kidney_cl2","mouse_kidney_10x"])
parser.add_argument("--epochs", default=500, type=int)
parser.add_argument("--pretrain_epochs", default=50, type=int)
parser.add_argument("--lr", default=0.1, type=float)
parser.add_argument("--pretrain_lr", default=0.001, type=float)
parser.add_argument("--gamma", default=1., type=float, help="coefficient of clustering loss")
parser.add_argument("--sigma", default=2.5, type=float, help="coefficient of random noise")
parser.add_argument("--update_interval", default=1, type=int)
parser.add_argument("--tol", default=0.001, type=float,
                    help="tolerance for delta clustering labels to terminate training stage")
parser.add_argument("--ae_weights", default=None, help="file to pretrained weights, None for a new pretraining")
parser.add_argument("--device", default="cpu")
parser.add_argument("--seed", type=int, default=42)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
scdeepcluster_scores=[]
for dataset in datasets:
    args = parser.parse_args(args=['--dataset',dataset])
    set_seed(args.seed)

    # Load data and perform necessary preprocessing
    dataloader = ClusteringDataset(args.data_dir, args.dataset)
    preprocessing_pipeline = ScDeepCluster.preprocessing_pipeline()
    data = dataloader.load_data(transform=preprocessing_pipeline, cache=args.cache)

    # inputs: x, x_raw, n_counts
    inputs, y = data.get_train_data()
    n_clusters = len(np.unique(y))
    in_dim = inputs[0].shape[1]

    # Build and train model
    model = ScDeepCluster(input_dim=in_dim, z_dim=32, encodeLayer=[256, 64], decodeLayer=[64, 256], sigma=args.sigma,
                          gamma=args.gamma, device=args.device, pretrain_path=f"scdeepcluster_{args.dataset}_pre.pkl")
    model.fit(inputs, y, n_clusters=n_clusters, y_pred_init=None, lr=args.lr, batch_size=args.batch_size,
              epochs=args.epochs, update_interval=args.update_interval, tol=args.tol, pt_batch_size=args.batch_size,
              pt_lr=args.pretrain_lr, pt_epochs=args.pretrain_epochs)

    # Evaluate model predictions
    score = model.score(None, y)
    print(f"{score=:.4f}")
    scdeepcluster_scores.append(score)
""" Reproduction information
10X PBMC:
python scdeepcluster.py --dataset 10X_PBMC

Mouse ES:
python scdeepcluster.py --dataset mouse_ES_cell

Worm Neuron:
python scdeepcluster.py --dataset worm_neuron_cell --pretrain_epochs 300

Mouse Bladder:
python scdeepcluster.py --dataset mouse_bladder_cell --pretrain_epochs 300 --sigma 2.75
"""
# Out:
# [INFO][2023-09-02 16:00:33,931][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:34,055][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:34,056][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:34,179][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:34,266][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:34,267][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:34,268][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:34,269][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:34,270][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:34,270][dance][wrapped_func] Took 0:00:00.337821 to load and process data.
# [INFO][2023-09-02 16:00:34,366][dance][_pretrain] Loading pre-trained model from scdeepcluster_mouse_kidney_cell_pre.pkl
# [INFO][2023-09-02 16:00:34,390][dance][fit] Initializing cluster centers with kmeans.
# [INFO][2023-09-02 16:00:35,062][dance][fit] Epoch   1: Total: 0.74297461, Clustering Loss: 0.09537970, ZINB Loss: 0.64759490
# [INFO][2023-09-02 16:00:35,178][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:35,180][dance][set_seed] Setting global random seed to 42
# score=0.9965
# [INFO][2023-09-02 16:00:35,451][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 64535
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:35,452][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:35,638][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:35,756][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:35,757][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:35,758][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:35,758][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:35,759][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 34907
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:35,760][dance][wrapped_func] Took 0:00:00.578496 to load and process data.
# [INFO][2023-09-02 16:00:35,960][dance][_pretrain] Loading pre-trained model from scdeepcluster_human_pbmc_cell_pre.pkl
# [INFO][2023-09-02 16:00:36,005][dance][fit] Initializing cluster centers with kmeans.
# [INFO][2023-09-02 16:00:37,430][dance][fit] Epoch   1: Total: 0.35685867, Clustering Loss: 0.10333455, ZINB Loss: 0.25352411
# [INFO][2023-09-02 16:00:38,500][dance][fit] Epoch   2: Total: 0.35966951, Clustering Loss: 0.10609913, ZINB Loss: 0.25357037
# [INFO][2023-09-02 16:00:39,519][dance][fit] Epoch   3: Total: 0.36210901, Clustering Loss: 0.10849491, ZINB Loss: 0.25361410
# [INFO][2023-09-02 16:00:40,541][dance][fit] Epoch   4: Total: 0.36439487, Clustering Loss: 0.11077733, ZINB Loss: 0.25361754
# [INFO][2023-09-02 16:00:41,585][dance][fit] Epoch   5: Total: 0.36720547, Clustering Loss: 0.11299778, ZINB Loss: 0.25420769
# [INFO][2023-09-02 16:00:42,630][dance][fit] Epoch   6: Total: 0.36945031, Clustering Loss: 0.11512984, ZINB Loss: 0.25432048
# [INFO][2023-09-02 16:00:43,732][dance][fit] Epoch   7: Total: 0.37169875, Clustering Loss: 0.11720476, ZINB Loss: 0.25449398
# [INFO][2023-09-02 16:00:43,923][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:43,930][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:43,977][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:43,978][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:44,058][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:44,112][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:44,113][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:44,113][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:44,114][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:44,115][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:44,116][dance][wrapped_func] Took 0:00:00.184665 to load and process data.
# score=0.2403
# [INFO][2023-09-02 16:00:44,136][dance][_pretrain] Loading pre-trained model from scdeepcluster_human_pbmc2_cell_pre.pkl
# [INFO][2023-09-02 16:00:44,143][dance][fit] Initializing cluster centers with kmeans.
# [INFO][2023-09-02 16:00:45,150][dance][fit] Epoch   1: Total: 0.85924018, Clustering Loss: 0.14573694, ZINB Loss: 0.71350324
# [INFO][2023-09-02 16:00:45,743][dance][fit] Epoch   2: Total: 0.86499669, Clustering Loss: 0.15021640, ZINB Loss: 0.71478028
# [INFO][2023-09-02 16:00:46,288][dance][fit] Epoch   3: Total: 0.86306669, Clustering Loss: 0.14789919, ZINB Loss: 0.71516750
# [INFO][2023-09-02 16:00:46,832][dance][fit] Epoch   4: Total: 0.86266700, Clustering Loss: 0.14452439, ZINB Loss: 0.71814260
# [INFO][2023-09-02 16:00:47,374][dance][fit] Epoch   5: Total: 0.85929741, Clustering Loss: 0.13954957, ZINB Loss: 0.71974784
# [INFO][2023-09-02 16:00:47,923][dance][fit] Epoch   6: Total: 0.85530772, Clustering Loss: 0.13404534, ZINB Loss: 0.72126238
# [INFO][2023-09-02 16:00:48,471][dance][fit] Epoch   7: Total: 0.85047915, Clustering Loss: 0.12819992, ZINB Loss: 0.72227923
# [INFO][2023-09-02 16:00:49,016][dance][fit] Epoch   8: Total: 0.84658822, Clustering Loss: 0.12254343, ZINB Loss: 0.72404480
# [INFO][2023-09-02 16:00:49,562][dance][fit] Epoch   9: Total: 0.84226844, Clustering Loss: 0.11711425, ZINB Loss: 0.72515419
# [INFO][2023-09-02 16:00:50,108][dance][fit] Epoch  10: Total: 0.83786805, Clustering Loss: 0.11211582, ZINB Loss: 0.72575223
# [INFO][2023-09-02 16:00:50,652][dance][fit] Epoch  11: Total: 0.83443267, Clustering Loss: 0.10745601, ZINB Loss: 0.72697667
# [INFO][2023-09-02 16:00:50,749][dance][fit] Reach tolerance threshold (8.518e-04 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:50,753][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:50,778][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:50,779][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:50,806][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:50,839][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:50,839][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:50,840][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:50,840][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:50,840][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:50,841][dance][wrapped_func] Took 0:00:00.087110 to load and process data.
# [INFO][2023-09-02 16:00:50,891][dance][_pretrain] Loading pre-trained model from scdeepcluster_human_skin_cell_pre.pkl
# [INFO][2023-09-02 16:00:50,896][dance][fit] Initializing cluster centers with kmeans.
# score=0.5352
# [INFO][2023-09-02 16:00:51,484][dance][fit] Epoch   1: Total: 0.79569265, Clustering Loss: 0.17811839, ZINB Loss: 0.61757427
# [INFO][2023-09-02 16:00:51,804][dance][fit] Epoch   2: Total: 0.81139577, Clustering Loss: 0.19312188, ZINB Loss: 0.61827388
# [INFO][2023-09-02 16:00:52,124][dance][fit] Epoch   3: Total: 0.81578227, Clustering Loss: 0.19511222, ZINB Loss: 0.62067005
# [INFO][2023-09-02 16:00:52,443][dance][fit] Epoch   4: Total: 0.81771320, Clustering Loss: 0.19333718, ZINB Loss: 0.62437602
# [INFO][2023-09-02 16:00:52,763][dance][fit] Epoch   5: Total: 0.81784995, Clustering Loss: 0.18925953, ZINB Loss: 0.62859042
# [INFO][2023-09-02 16:00:53,082][dance][fit] Epoch   6: Total: 0.81448477, Clustering Loss: 0.18354857, ZINB Loss: 0.63093620
# [INFO][2023-09-02 16:00:53,402][dance][fit] Epoch   7: Total: 0.81208446, Clustering Loss: 0.17711113, ZINB Loss: 0.63497332
# [INFO][2023-09-02 16:00:53,721][dance][fit] Epoch   8: Total: 0.80960464, Clustering Loss: 0.17055195, ZINB Loss: 0.63905269
# [INFO][2023-09-02 16:00:54,040][dance][fit] Epoch   9: Total: 0.80565483, Clustering Loss: 0.16426684, ZINB Loss: 0.64138799
# [INFO][2023-09-02 16:00:54,360][dance][fit] Epoch  10: Total: 0.80282346, Clustering Loss: 0.15866262, ZINB Loss: 0.64416084
# [INFO][2023-09-02 16:00:54,680][dance][fit] Epoch  11: Total: 0.80024339, Clustering Loss: 0.15343118, ZINB Loss: 0.64681221
# [INFO][2023-09-02 16:00:54,998][dance][fit] Epoch  12: Total: 0.79751306, Clustering Loss: 0.14851990, ZINB Loss: 0.64899317
# [INFO][2023-09-02 16:00:55,317][dance][fit] Epoch  13: Total: 0.79451322, Clustering Loss: 0.14393354, ZINB Loss: 0.65057968
# [INFO][2023-09-02 16:00:55,375][dance][fit] Reach tolerance threshold (8.242e-04 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:55,379][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:55,390][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:55,391][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:55,401][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:55,413][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:55,414][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:55,414][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:55,414][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:55,415][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 999
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:55,415][dance][wrapped_func] Took 0:00:00.035390 to load and process data.
# [INFO][2023-09-02 16:00:55,426][dance][_pretrain] Loading pre-trained model from scdeepcluster_human_lung_cell_pre.pkl
# [INFO][2023-09-02 16:00:55,430][dance][fit] Initializing cluster centers with kmeans.
# score=0.6335
# [INFO][2023-09-02 16:00:55,674][dance][fit] Epoch   1: Total: 0.65420954, Clustering Loss: 0.14566157, ZINB Loss: 0.50854797
# [INFO][2023-09-02 16:00:55,697][dance][fit] Reach tolerance threshold (5.695e-04 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:55,699][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:55,723][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:55,724][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:55,747][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:55,769][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:55,770][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:55,770][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:55,771][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:55,771][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:55,771][dance][wrapped_func] Took 0:00:00.070990 to load and process data.
# [INFO][2023-09-02 16:00:55,865][dance][_pretrain] Loading pre-trained model from scdeepcluster_mouse_kidney_drop_pre.pkl
# [INFO][2023-09-02 16:00:55,884][dance][fit] Initializing cluster centers with kmeans.
# score=0.7695
# [INFO][2023-09-02 16:00:56,081][dance][fit] Epoch   1: Total: 0.73605788, Clustering Loss: 0.09888156, ZINB Loss: 0.63717633
# [INFO][2023-09-02 16:00:56,110][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:56,113][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:56,137][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:56,137][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:56,158][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:56,181][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:56,181][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:56,181][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:56,182][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:56,182][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 225 × 15127
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:56,183][dance][wrapped_func] Took 0:00:00.068547 to load and process data.
# [INFO][2023-09-02 16:00:56,276][dance][_pretrain] Loading pre-trained model from scdeepcluster_mouse_kidney_cl2_pre.pkl
# [INFO][2023-09-02 16:00:56,295][dance][fit] Initializing cluster centers with kmeans.
# score=0.8565
# [INFO][2023-09-02 16:00:56,491][dance][fit] Epoch   1: Total: 0.73605788, Clustering Loss: 0.09888156, ZINB Loss: 0.63717633
# [INFO][2023-09-02 16:00:56,520][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-03). Stopping training.
# [INFO][2023-09-02 16:00:56,523][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:56,621][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:56,621][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   SetConfig(config_dict={'feature_channel': [None, None, 'n_counts'], 'feature_channel_type': ['X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# score=0.8565
# [INFO][2023-09-02 16:00:56,750][dance.SaveRaw][__call__] Saving data to ``.raw``
# [INFO][2023-09-02 16:00:56,840][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, None, 'n_counts'],
#  'feature_channel_type': ['X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:00:56,841][dance][set_config_from_dict] Setting config 'feature_channel' to [None, None, 'n_counts']
# [INFO][2023-09-02 16:00:56,842][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:00:56,843][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:00:56,843][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     obs: 'n_counts'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'dance_config', 'log1p'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:56,844][dance][wrapped_func] Took 0:00:00.320538 to load and process data.
# [INFO][2023-09-02 16:00:56,940][dance][_pretrain] Loading pre-trained model from scdeepcluster_mouse_kidney_10x_pre.pkl
# [INFO][2023-09-02 16:00:56,964][dance][fit] Initializing cluster centers with kmeans.
# [INFO][2023-09-02 16:00:57,642][dance][fit] Epoch   1: Total: 0.74297461, Clustering Loss: 0.09537970, ZINB Loss: 0.64759490
# [INFO][2023-09-02 16:00:57,757][dance][fit] Reach tolerance threshold (0.000e+00 < 1.000e-03). Stopping training.
# score=0.9965
# ' Reproduction information\n10X PBMC:\npython scdeepcluster.py --dataset 10X_PBMC\n\nMouse ES:\npython scdeepcluster.py --dataset mouse_ES_cell\n\nWorm Neuron:\npython scdeepcluster.py --dataset worm_neuron_cell --pretrain_epochs 300\n\nMouse Bladder:\npython scdeepcluster.py --dataset mouse_bladder_cell --pretrain_epochs 300 --sigma 2.75\n'

# %%
scdeepcluster_scores
# Out:
# [0.9965362702578435,
#  0.24032257798854678,
#  0.5352188341844301,
#  0.6334722718620797,
#  0.7695415409808991,
#  0.8565223251023905,
#  0.8565223251023905,
#  0.9965362702578435]

# %%
import argparse

from dance.datasets.singlemodality import ClusteringDataset
from dance.modules.single_modality.clustering.scdsc import ScDSC
from dance.utils import set_seed


parser = argparse.ArgumentParser()

# model_para = [n_enc_1(n_dec_3), n_enc_2(n_dec_2), n_enc_3(n_dec_1)]
model_para = [512, 256, 256]
# Cluster_para = [n_z1, n_z2, n_z3, n_init, n_input, n_clusters]
Cluster_para = [256, 128, 32, 20, 100, 10]
# Balance_para = [binary_crossentropy_loss, ce_loss, re_loss, zinb_loss, sigma]
Balance_para = [1, 0.01, 0.1, 0.1, 1]

parser.add_argument("--data_dir", default="./data")
parser.add_argument("--dataset", type=str, default="worm_neuron_cell",
                    choices=["10X_PBMC", "mouse_bladder_cell", "mouse_ES_cell", "worm_neuron_cell","mouse_kidney_cell","human_pbmc_cell","human_pbmc2_cell","human_skin_cell","human_lung_cell","mouse_kidney_drop","mouse_kidney_cl2","mouse_kidney_10x"])
# TODO: implement callbacks for "heat_kernel" and "cosine_normalized"
parser.add_argument("--method", type=str, default="correlation", choices=["cosine", "correlation"])
parser.add_argument("--batch_size", default=256, type=int)
parser.add_argument("--n_enc_1", default=model_para[0], type=int)
parser.add_argument("--n_enc_2", default=model_para[1], type=int)
parser.add_argument("--n_enc_3", default=model_para[2], type=int)
parser.add_argument("--n_dec_1", default=model_para[2], type=int)
parser.add_argument("--n_dec_2", default=model_para[1], type=int)
parser.add_argument("--n_dec_3", default=model_para[0], type=int)
parser.add_argument("--topk", type=int, default=50)
parser.add_argument("--lr", type=float, default=1e-2)
parser.add_argument("--pretrain_lr", type=float, default=1e-3)
parser.add_argument("--pretrain_epochs", type=int, default=200)
parser.add_argument("--epochs", type=int, default=1000)
parser.add_argument("--n_z1", default=Cluster_para[0], type=int)
parser.add_argument("--n_z2", default=Cluster_para[1], type=int)
parser.add_argument("--n_z3", default=Cluster_para[2], type=int)
parser.add_argument("--n_input", type=int, default=Cluster_para[4])
parser.add_argument("--n_clusters", type=int, default=Cluster_para[5])
parser.add_argument("--device", type=str, default="cpu")
parser.add_argument("--v", type=int, default=1)
parser.add_argument("--nb_genes", type=int, default=2000)
parser.add_argument("--binary_crossentropy_loss", type=float, default=Balance_para[0])
parser.add_argument("--ce_loss", type=float, default=Balance_para[1])
parser.add_argument("--re_loss", type=float, default=Balance_para[2])
parser.add_argument("--zinb_loss", type=float, default=Balance_para[3])
parser.add_argument("--sigma", type=float, default=Balance_para[4])
parser.add_argument("--seed", type=int, default=42)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
scdsc_scores=[]
for dataset in datasets:
    args = parser.parse_args(['--dataset', dataset, '--method','cosine','--topk', '30', '--v', '7', '--binary_crossentropy_loss', '0.75','--ce_loss', '0.5', '--re_loss','0.1' ,'--zinb_loss','2.5','--sigma', '0.4'])
    set_seed(args.seed)

    # Load data and perform necessary preprocessing
    dataloader = ClusteringDataset(args.data_dir, args.dataset)
    preprocessing_pipeline = ScDSC.preprocessing_pipeline(n_top_genes=args.nb_genes, n_neighbors=args.topk)
    data = dataloader.load_data(transform=preprocessing_pipeline, cache=args.cache)

    # inputs: adj, x, x_raw, n_counts
    inputs, y = data.get_data(return_type="default")
    args.n_input = inputs[1].shape[1]

    model = ScDSC(pretrain_path=f"scdsc_{args.dataset}_pre.pkl", sigma=args.sigma, n_enc_1=args.n_enc_1,
                  n_enc_2=args.n_enc_2, n_enc_3=args.n_enc_3, n_dec_1=args.n_dec_1, n_dec_2=args.n_dec_2,
                  n_dec_3=args.n_dec_3, n_z1=args.n_z1, n_z2=args.n_z2, n_z3=args.n_z3, n_clusters=args.n_clusters,
                  n_input=args.n_input, v=args.v, device=args.device)

    # Build and train model
    model.fit(inputs, y, lr=args.lr, epochs=args.epochs, bcl=args.binary_crossentropy_loss, cl=args.ce_loss,
              rl=args.re_loss, zl=args.zinb_loss, pt_epochs=args.pretrain_epochs, pt_batch_size=args.batch_size,
              pt_lr=args.pretrain_lr)

    # Evaluate model predictions
    score = model.score(None, y)
    print(f"{score=:.4f}")
    scdsc_scores.append(score)
"""Reproduction information
10X PBMC:
python scdsc.py --dataset 10X_PBMC --method cosine --topk 30 --v 7 --binary_crossentropy_loss 0.75 --ce_loss 0.5 --re_loss 0.1 --zinb_loss 2.5 --sigma 0.4

Mouse Bladder:
python scdsc.py --dataset mouse_bladder_cell --topk 50 --v 7 --binary_crossentropy_loss 2.5 --ce_loss 0.1 --re_loss 0.5 --zinb_loss 1.5 --sigma 0.6

Mouse ES:
python scdsc.py --dataset mouse_ES_cell --topk 50 --v 7 --binary_crossentropy_loss 0.1 --ce_loss 0.01 --re_loss 1.5 --zinb_loss 0.5 --sigma 0.1

Worm Neuron:
python scdsc.py --dataset worm_neuron_cell --topk 20 --v 7 --binary_crossentropy_loss 2 --ce_loss 2 --re_loss 3 --zinb_loss 0.1 --sigma 0.4
"""
# Out:
# [INFO][2023-09-02 16:00:57,799][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:00:57,887][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:00:57,888][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 2000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   NeighborGraph(n_neighbors=30, n_pcs=None, knn=True, random_state=0, method='umap', metric='correlation'),
#   SetConfig(config_dict={'feature_channel': ['NeighborGraph', None, None, 'n_counts'], 'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:00:58,156][dance.SaveRaw][__call__] Saving data to ``.raw``
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 16:00:58,168][dance.NeighborGraph][__call__] Start computing the kNN connectivity adjacency matrix
# [INFO][2023-09-02 16:01:00,596][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['NeighborGraph', None, None, 'n_counts'],
#  'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:01:00,596][dance][set_config_from_dict] Setting config 'feature_channel' to ['NeighborGraph', None, None, 'n_counts']
# [INFO][2023-09-02 16:01:00,597][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:01:00,598][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:01:00,599][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 2000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'Group'
#     obsp: 'NeighborGraph'
# [INFO][2023-09-02 16:01:00,599][dance][wrapped_func] Took 0:00:02.799006 to load and process data.
# [INFO][2023-09-02 16:01:00,650][dance][_pretrain] Loading pre-trained model from scdsc_mouse_kidney_cell_pre.pkl
# [INFO][2023-09-02 16:01:00,688][dance][fit] Epoch   1, ARI: 0.2951, Best ARI: 0.2951
# [INFO][2023-09-02 16:01:01,341][dance][fit] Epoch  11, ARI: 0.4782, Best ARI: 0.4782
# [INFO][2023-09-02 16:01:01,992][dance][fit] Epoch  21, ARI: 0.5457, Best ARI: 0.5457
# [INFO][2023-09-02 16:01:02,638][dance][fit] Epoch  31, ARI: 0.5685, Best ARI: 0.5685
# [INFO][2023-09-02 16:01:03,279][dance][fit] Epoch  41, ARI: 0.5713, Best ARI: 0.5713
# [INFO][2023-09-02 16:01:03,915][dance][fit] Epoch  51, ARI: 0.5722, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:04,556][dance][fit] Epoch  61, ARI: 0.5554, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:05,193][dance][fit] Epoch  71, ARI: 0.5424, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:05,828][dance][fit] Epoch  81, ARI: 0.5300, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:06,462][dance][fit] Epoch  91, ARI: 0.5202, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:07,094][dance][fit] Epoch 101, ARI: 0.5102, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:07,722][dance][fit] Epoch 111, ARI: 0.5057, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:08,355][dance][fit] Epoch 121, ARI: 0.5029, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:08,988][dance][fit] Epoch 131, ARI: 0.4942, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:09,623][dance][fit] Epoch 141, ARI: 0.4896, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:10,260][dance][fit] Epoch 151, ARI: 0.4877, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:10,896][dance][fit] Epoch 161, ARI: 0.4844, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:11,530][dance][fit] Epoch 171, ARI: 0.4821, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:12,164][dance][fit] Epoch 181, ARI: 0.4839, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:12,798][dance][fit] Epoch 191, ARI: 0.4831, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:13,429][dance][fit] Epoch 201, ARI: 0.4821, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:14,065][dance][fit] Epoch 211, ARI: 0.4817, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:14,701][dance][fit] Epoch 221, ARI: 0.4825, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:15,332][dance][fit] Epoch 231, ARI: 0.4829, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:15,963][dance][fit] Epoch 241, ARI: 0.4829, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:16,598][dance][fit] Epoch 251, ARI: 0.4830, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:17,225][dance][fit] Epoch 261, ARI: 0.4836, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:17,855][dance][fit] Epoch 271, ARI: 0.4824, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:18,500][dance][fit] Epoch 281, ARI: 0.4827, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:19,133][dance][fit] Epoch 291, ARI: 0.4821, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:19,768][dance][fit] Epoch 301, ARI: 0.4821, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:20,401][dance][fit] Epoch 311, ARI: 0.4833, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:21,032][dance][fit] Epoch 321, ARI: 0.4831, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:21,668][dance][fit] Epoch 331, ARI: 0.4824, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:22,295][dance][fit] Epoch 341, ARI: 0.4824, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:22,928][dance][fit] Epoch 351, ARI: 0.4824, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:23,560][dance][fit] Epoch 361, ARI: 0.4821, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:24,190][dance][fit] Epoch 371, ARI: 0.4820, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:24,821][dance][fit] Epoch 381, ARI: 0.4819, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:25,452][dance][fit] Epoch 391, ARI: 0.4815, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:26,085][dance][fit] Epoch 401, ARI: 0.4812, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:26,712][dance][fit] Epoch 411, ARI: 0.4812, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:27,342][dance][fit] Epoch 421, ARI: 0.4814, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:27,969][dance][fit] Epoch 431, ARI: 0.4814, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:28,608][dance][fit] Epoch 441, ARI: 0.4807, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:29,241][dance][fit] Epoch 451, ARI: 0.4807, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:29,876][dance][fit] Epoch 461, ARI: 0.4812, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:30,516][dance][fit] Epoch 471, ARI: 0.4812, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:31,148][dance][fit] Epoch 481, ARI: 0.4812, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:31,782][dance][fit] Epoch 491, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:32,414][dance][fit] Epoch 501, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:33,047][dance][fit] Epoch 511, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:33,678][dance][fit] Epoch 521, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:34,305][dance][fit] Epoch 531, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:34,939][dance][fit] Epoch 541, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:35,574][dance][fit] Epoch 551, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:36,206][dance][fit] Epoch 561, ARI: 0.4808, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:36,838][dance][fit] Epoch 571, ARI: 0.4805, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:37,469][dance][fit] Epoch 581, ARI: 0.4792, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:38,099][dance][fit] Epoch 591, ARI: 0.4785, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:38,731][dance][fit] Epoch 601, ARI: 0.4785, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:39,358][dance][fit] Epoch 611, ARI: 0.4784, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:39,989][dance][fit] Epoch 621, ARI: 0.4772, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:40,618][dance][fit] Epoch 631, ARI: 0.4763, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:41,248][dance][fit] Epoch 641, ARI: 0.4757, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:41,878][dance][fit] Epoch 651, ARI: 0.4756, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:42,511][dance][fit] Epoch 661, ARI: 0.4756, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:43,144][dance][fit] Epoch 671, ARI: 0.4756, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:43,780][dance][fit] Epoch 681, ARI: 0.4752, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:44,411][dance][fit] Epoch 691, ARI: 0.4749, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:45,041][dance][fit] Epoch 701, ARI: 0.4749, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:45,672][dance][fit] Epoch 711, ARI: 0.4735, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:46,301][dance][fit] Epoch 721, ARI: 0.4724, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:46,935][dance][fit] Epoch 731, ARI: 0.4724, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:47,567][dance][fit] Epoch 741, ARI: 0.4724, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:48,204][dance][fit] Epoch 751, ARI: 0.4719, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:48,845][dance][fit] Epoch 761, ARI: 0.4712, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:49,473][dance][fit] Epoch 771, ARI: 0.4703, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:50,105][dance][fit] Epoch 781, ARI: 0.4703, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:50,734][dance][fit] Epoch 791, ARI: 0.4703, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:51,360][dance][fit] Epoch 801, ARI: 0.4698, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:51,993][dance][fit] Epoch 811, ARI: 0.4683, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:52,629][dance][fit] Epoch 821, ARI: 0.4674, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:53,267][dance][fit] Epoch 831, ARI: 0.4663, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:53,897][dance][fit] Epoch 841, ARI: 0.4653, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:54,559][dance][fit] Epoch 851, ARI: 0.4641, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:55,234][dance][fit] Epoch 861, ARI: 0.4626, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:55,865][dance][fit] Epoch 871, ARI: 0.4623, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:56,493][dance][fit] Epoch 881, ARI: 0.4623, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:57,132][dance][fit] Epoch 891, ARI: 0.4616, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:57,762][dance][fit] Epoch 901, ARI: 0.4616, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:58,397][dance][fit] Epoch 911, ARI: 0.4616, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:59,029][dance][fit] Epoch 921, ARI: 0.4616, Best ARI: 0.5722
# [INFO][2023-09-02 16:01:59,718][dance][fit] Epoch 931, ARI: 0.4600, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:00,409][dance][fit] Epoch 941, ARI: 0.4597, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:01,102][dance][fit] Epoch 951, ARI: 0.4597, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:01,760][dance][fit] Epoch 961, ARI: 0.4595, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:02,393][dance][fit] Epoch 971, ARI: 0.4595, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:03,029][dance][fit] Epoch 981, ARI: 0.4595, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:03,662][dance][fit] Epoch 991, ARI: 0.4594, Best ARI: 0.5722
# [INFO][2023-09-02 16:02:04,282][dance][set_seed] Setting global random seed to 42
# score=0.5722
# [INFO][2023-09-02 16:02:04,636][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 64535
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:02:04,636][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 2000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   NeighborGraph(n_neighbors=30, n_pcs=None, knn=True, random_state=0, method='umap', metric='correlation'),
#   SetConfig(config_dict={'feature_channel': ['NeighborGraph', None, None, 'n_counts'], 'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:02:04,997][dance.SaveRaw][__call__] Saving data to ``.raw``
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 16:02:05,005][dance.NeighborGraph][__call__] Start computing the kNN connectivity adjacency matrix
# [INFO][2023-09-02 16:02:05,328][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['NeighborGraph', None, None, 'n_counts'],
#  'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:02:05,329][dance][set_config_from_dict] Setting config 'feature_channel' to ['NeighborGraph', None, None, 'n_counts']
# [INFO][2023-09-02 16:02:05,330][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:02:05,331][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:02:05,332][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 648 × 2000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'Group'
#     obsp: 'NeighborGraph'
# [INFO][2023-09-02 16:02:05,333][dance][wrapped_func] Took 0:00:01.049061 to load and process data.
# [INFO][2023-09-02 16:02:05,580][dance][_pretrain] Loading pre-trained model from scdsc_human_pbmc_cell_pre.pkl
# [INFO][2023-09-02 16:02:05,614][dance][fit] Epoch   1, ARI: 0.0524, Best ARI: 0.0524
# [INFO][2023-09-02 16:02:06,122][dance][fit] Epoch  11, ARI: 0.0675, Best ARI: 0.0675
# [INFO][2023-09-02 16:02:06,613][dance][fit] Epoch  21, ARI: 0.0784, Best ARI: 0.0784
# [INFO][2023-09-02 16:02:07,102][dance][fit] Epoch  31, ARI: 0.1002, Best ARI: 0.1002
# [INFO][2023-09-02 16:02:07,595][dance][fit] Epoch  41, ARI: 0.1262, Best ARI: 0.1262
# [INFO][2023-09-02 16:02:08,084][dance][fit] Epoch  51, ARI: 0.1423, Best ARI: 0.1423
# [INFO][2023-09-02 16:02:08,573][dance][fit] Epoch  61, ARI: 0.1552, Best ARI: 0.1552
# [INFO][2023-09-02 16:02:09,062][dance][fit] Epoch  71, ARI: 0.1683, Best ARI: 0.1683
# [INFO][2023-09-02 16:02:09,552][dance][fit] Epoch  81, ARI: 0.1779, Best ARI: 0.1779
# [INFO][2023-09-02 16:02:10,043][dance][fit] Epoch  91, ARI: 0.1811, Best ARI: 0.1811
# [INFO][2023-09-02 16:02:10,540][dance][fit] Epoch 101, ARI: 0.1934, Best ARI: 0.1934
# [INFO][2023-09-02 16:02:11,033][dance][fit] Epoch 111, ARI: 0.2018, Best ARI: 0.2018
# [INFO][2023-09-02 16:02:11,524][dance][fit] Epoch 121, ARI: 0.2115, Best ARI: 0.2115
# [INFO][2023-09-02 16:02:12,017][dance][fit] Epoch 131, ARI: 0.2079, Best ARI: 0.2115
# [INFO][2023-09-02 16:02:12,508][dance][fit] Epoch 141, ARI: 0.2168, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:13,000][dance][fit] Epoch 151, ARI: 0.2155, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:13,493][dance][fit] Epoch 161, ARI: 0.2129, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:13,983][dance][fit] Epoch 171, ARI: 0.2116, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:14,476][dance][fit] Epoch 181, ARI: 0.2131, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:14,967][dance][fit] Epoch 191, ARI: 0.2109, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:15,618][dance][fit] Epoch 201, ARI: 0.2048, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:16,183][dance][fit] Epoch 211, ARI: 0.2028, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:16,724][dance][fit] Epoch 221, ARI: 0.2026, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:17,222][dance][fit] Epoch 231, ARI: 0.2030, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:17,716][dance][fit] Epoch 241, ARI: 0.2009, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:18,211][dance][fit] Epoch 251, ARI: 0.1972, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:18,732][dance][fit] Epoch 261, ARI: 0.2015, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:19,239][dance][fit] Epoch 271, ARI: 0.2144, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:19,733][dance][fit] Epoch 281, ARI: 0.2121, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:20,227][dance][fit] Epoch 291, ARI: 0.2076, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:20,718][dance][fit] Epoch 301, ARI: 0.2061, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:21,213][dance][fit] Epoch 311, ARI: 0.2055, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:21,709][dance][fit] Epoch 321, ARI: 0.2049, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:22,199][dance][fit] Epoch 331, ARI: 0.2080, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:22,694][dance][fit] Epoch 341, ARI: 0.2043, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:23,181][dance][fit] Epoch 351, ARI: 0.2015, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:23,677][dance][fit] Epoch 361, ARI: 0.2045, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:24,171][dance][fit] Epoch 371, ARI: 0.2031, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:24,665][dance][fit] Epoch 381, ARI: 0.2033, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:25,159][dance][fit] Epoch 391, ARI: 0.2081, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:25,650][dance][fit] Epoch 401, ARI: 0.2060, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:26,145][dance][fit] Epoch 411, ARI: 0.2064, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:26,640][dance][fit] Epoch 421, ARI: 0.2083, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:27,134][dance][fit] Epoch 431, ARI: 0.2111, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:27,625][dance][fit] Epoch 441, ARI: 0.2112, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:28,120][dance][fit] Epoch 451, ARI: 0.2112, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:28,613][dance][fit] Epoch 461, ARI: 0.2099, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:29,106][dance][fit] Epoch 471, ARI: 0.2099, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:29,602][dance][fit] Epoch 481, ARI: 0.2122, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:30,098][dance][fit] Epoch 491, ARI: 0.2145, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:30,595][dance][fit] Epoch 501, ARI: 0.2144, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:31,094][dance][fit] Epoch 511, ARI: 0.2134, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:31,586][dance][fit] Epoch 521, ARI: 0.2132, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:32,081][dance][fit] Epoch 531, ARI: 0.2135, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:32,577][dance][fit] Epoch 541, ARI: 0.2135, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:33,071][dance][fit] Epoch 551, ARI: 0.2116, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:33,562][dance][fit] Epoch 561, ARI: 0.2093, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:34,056][dance][fit] Epoch 571, ARI: 0.2093, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:34,551][dance][fit] Epoch 581, ARI: 0.2091, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:35,046][dance][fit] Epoch 591, ARI: 0.2092, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:35,539][dance][fit] Epoch 601, ARI: 0.2092, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:36,039][dance][fit] Epoch 611, ARI: 0.2094, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:36,533][dance][fit] Epoch 621, ARI: 0.2097, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:37,025][dance][fit] Epoch 631, ARI: 0.2112, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:37,519][dance][fit] Epoch 641, ARI: 0.2134, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:38,015][dance][fit] Epoch 651, ARI: 0.2118, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:38,506][dance][fit] Epoch 661, ARI: 0.2081, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:39,000][dance][fit] Epoch 671, ARI: 0.2039, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:39,494][dance][fit] Epoch 681, ARI: 0.2041, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:39,990][dance][fit] Epoch 691, ARI: 0.2042, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:40,488][dance][fit] Epoch 701, ARI: 0.2058, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:40,987][dance][fit] Epoch 711, ARI: 0.2033, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:41,483][dance][fit] Epoch 721, ARI: 0.2028, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:41,976][dance][fit] Epoch 731, ARI: 0.2028, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:42,473][dance][fit] Epoch 741, ARI: 0.2054, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:42,969][dance][fit] Epoch 751, ARI: 0.2054, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:43,458][dance][fit] Epoch 761, ARI: 0.2054, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:43,950][dance][fit] Epoch 771, ARI: 0.2032, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:44,445][dance][fit] Epoch 781, ARI: 0.2016, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:44,942][dance][fit] Epoch 791, ARI: 0.2015, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:45,441][dance][fit] Epoch 801, ARI: 0.2015, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:45,940][dance][fit] Epoch 811, ARI: 0.2015, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:46,433][dance][fit] Epoch 821, ARI: 0.2015, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:46,934][dance][fit] Epoch 831, ARI: 0.2016, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:47,448][dance][fit] Epoch 841, ARI: 0.2017, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:47,979][dance][fit] Epoch 851, ARI: 0.2035, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:48,503][dance][fit] Epoch 861, ARI: 0.2037, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:49,047][dance][fit] Epoch 871, ARI: 0.2037, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:49,556][dance][fit] Epoch 881, ARI: 0.2013, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:50,054][dance][fit] Epoch 891, ARI: 0.2012, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:50,553][dance][fit] Epoch 901, ARI: 0.2000, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:51,069][dance][fit] Epoch 911, ARI: 0.2000, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:51,704][dance][fit] Epoch 921, ARI: 0.2021, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:52,203][dance][fit] Epoch 931, ARI: 0.2068, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:52,700][dance][fit] Epoch 941, ARI: 0.2074, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:53,195][dance][fit] Epoch 951, ARI: 0.2079, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:53,690][dance][fit] Epoch 961, ARI: 0.2097, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:54,184][dance][fit] Epoch 971, ARI: 0.2098, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:54,682][dance][fit] Epoch 981, ARI: 0.2106, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:55,185][dance][fit] Epoch 991, ARI: 0.2090, Best ARI: 0.2168
# [INFO][2023-09-02 16:02:55,679][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:02:55,730][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:02:55,731][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 2000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   NeighborGraph(n_neighbors=30, n_pcs=None, knn=True, random_state=0, method='umap', metric='correlation'),
#   SetConfig(config_dict={'feature_channel': ['NeighborGraph', None, None, 'n_counts'], 'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# score=0.2168
# [INFO][2023-09-02 16:02:55,957][dance.SaveRaw][__call__] Saving data to ``.raw``
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 16:02:56,010][dance.NeighborGraph][__call__] Start computing the kNN connectivity adjacency matrix
# [INFO][2023-09-02 16:03:03,881][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['NeighborGraph', None, None, 'n_counts'],
#  'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:03:03,884][dance][set_config_from_dict] Setting config 'feature_channel' to ['NeighborGraph', None, None, 'n_counts']
# [INFO][2023-09-02 16:03:03,885][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:03:03,886][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:03:03,888][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 8218 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'Group'
#     obsp: 'NeighborGraph'
# [INFO][2023-09-02 16:03:03,889][dance][wrapped_func] Took 0:00:08.207870 to load and process data.
# [INFO][2023-09-02 16:03:03,930][dance][_pretrain] Loading pre-trained model from scdsc_human_pbmc2_cell_pre.pkl
# [INFO][2023-09-02 16:03:04,214][dance][fit] Epoch   1, ARI: 0.1113, Best ARI: 0.1113
# [INFO][2023-09-02 16:03:09,350][dance][fit] Epoch  11, ARI: 0.1467, Best ARI: 0.1467
# [INFO][2023-09-02 16:03:14,116][dance][fit] Epoch  21, ARI: 0.1584, Best ARI: 0.1584
# [INFO][2023-09-02 16:03:18,712][dance][fit] Epoch  31, ARI: 0.1677, Best ARI: 0.1677
# [INFO][2023-09-02 16:03:23,552][dance][fit] Epoch  41, ARI: 0.1859, Best ARI: 0.1859
# [INFO][2023-09-02 16:03:28,407][dance][fit] Epoch  51, ARI: 0.2090, Best ARI: 0.2090
# [INFO][2023-09-02 16:03:33,360][dance][fit] Epoch  61, ARI: 0.2412, Best ARI: 0.2412
# [INFO][2023-09-02 16:03:37,889][dance][fit] Epoch  71, ARI: 0.2743, Best ARI: 0.2743
# [INFO][2023-09-02 16:03:42,909][dance][fit] Epoch  81, ARI: 0.2921, Best ARI: 0.2921
# [INFO][2023-09-02 16:03:47,917][dance][fit] Epoch  91, ARI: 0.3066, Best ARI: 0.3066
# [INFO][2023-09-02 16:03:52,976][dance][fit] Epoch 101, ARI: 0.3148, Best ARI: 0.3148
# [INFO][2023-09-02 16:03:57,752][dance][fit] Epoch 111, ARI: 0.3193, Best ARI: 0.3193
# [INFO][2023-09-02 16:04:02,183][dance][fit] Epoch 121, ARI: 0.3234, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:06,652][dance][fit] Epoch 131, ARI: 0.3227, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:11,105][dance][fit] Epoch 141, ARI: 0.3233, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:15,466][dance][fit] Epoch 151, ARI: 0.3230, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:19,857][dance][fit] Epoch 161, ARI: 0.3221, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:24,260][dance][fit] Epoch 171, ARI: 0.3210, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:28,771][dance][fit] Epoch 181, ARI: 0.3197, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:33,288][dance][fit] Epoch 191, ARI: 0.3180, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:38,323][dance][fit] Epoch 201, ARI: 0.3164, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:43,042][dance][fit] Epoch 211, ARI: 0.3145, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:47,442][dance][fit] Epoch 221, ARI: 0.3137, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:51,892][dance][fit] Epoch 231, ARI: 0.3130, Best ARI: 0.3234
# [INFO][2023-09-02 16:04:56,303][dance][fit] Epoch 241, ARI: 0.3115, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:00,727][dance][fit] Epoch 251, ARI: 0.3103, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:05,078][dance][fit] Epoch 261, ARI: 0.3089, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:09,417][dance][fit] Epoch 271, ARI: 0.3081, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:13,732][dance][fit] Epoch 281, ARI: 0.3079, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:18,093][dance][fit] Epoch 291, ARI: 0.3073, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:22,474][dance][fit] Epoch 301, ARI: 0.3068, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:26,738][dance][fit] Epoch 311, ARI: 0.3056, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:30,999][dance][fit] Epoch 321, ARI: 0.3056, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:35,384][dance][fit] Epoch 331, ARI: 0.3047, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:39,816][dance][fit] Epoch 341, ARI: 0.3046, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:44,135][dance][fit] Epoch 351, ARI: 0.3046, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:48,477][dance][fit] Epoch 361, ARI: 0.3044, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:52,780][dance][fit] Epoch 371, ARI: 0.3037, Best ARI: 0.3234
# [INFO][2023-09-02 16:05:57,033][dance][fit] Epoch 381, ARI: 0.3033, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:01,296][dance][fit] Epoch 391, ARI: 0.3021, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:05,548][dance][fit] Epoch 401, ARI: 0.3020, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:09,883][dance][fit] Epoch 411, ARI: 0.3022, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:14,213][dance][fit] Epoch 421, ARI: 0.3025, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:18,531][dance][fit] Epoch 431, ARI: 0.3021, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:22,811][dance][fit] Epoch 441, ARI: 0.3019, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:27,055][dance][fit] Epoch 451, ARI: 0.3025, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:31,341][dance][fit] Epoch 461, ARI: 0.3027, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:35,614][dance][fit] Epoch 471, ARI: 0.3027, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:39,869][dance][fit] Epoch 481, ARI: 0.3032, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:44,117][dance][fit] Epoch 491, ARI: 0.3033, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:48,489][dance][fit] Epoch 501, ARI: 0.3031, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:52,908][dance][fit] Epoch 511, ARI: 0.3034, Best ARI: 0.3234
# [INFO][2023-09-02 16:06:57,177][dance][fit] Epoch 521, ARI: 0.3032, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:01,511][dance][fit] Epoch 531, ARI: 0.3034, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:05,773][dance][fit] Epoch 541, ARI: 0.3041, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:09,993][dance][fit] Epoch 551, ARI: 0.3045, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:14,333][dance][fit] Epoch 561, ARI: 0.3043, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:18,590][dance][fit] Epoch 571, ARI: 0.3051, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:22,912][dance][fit] Epoch 581, ARI: 0.3055, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:27,352][dance][fit] Epoch 591, ARI: 0.3055, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:31,641][dance][fit] Epoch 601, ARI: 0.3062, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:35,918][dance][fit] Epoch 611, ARI: 0.3065, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:40,240][dance][fit] Epoch 621, ARI: 0.3071, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:44,516][dance][fit] Epoch 631, ARI: 0.3077, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:48,791][dance][fit] Epoch 641, ARI: 0.3078, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:53,068][dance][fit] Epoch 651, ARI: 0.3080, Best ARI: 0.3234
# [INFO][2023-09-02 16:07:57,374][dance][fit] Epoch 661, ARI: 0.3081, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:01,680][dance][fit] Epoch 671, ARI: 0.3089, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:05,977][dance][fit] Epoch 681, ARI: 0.3090, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:10,253][dance][fit] Epoch 691, ARI: 0.3088, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:14,505][dance][fit] Epoch 701, ARI: 0.3088, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:18,769][dance][fit] Epoch 711, ARI: 0.3093, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:23,047][dance][fit] Epoch 721, ARI: 0.3095, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:27,336][dance][fit] Epoch 731, ARI: 0.3098, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:31,623][dance][fit] Epoch 741, ARI: 0.3099, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:35,962][dance][fit] Epoch 751, ARI: 0.3100, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:40,269][dance][fit] Epoch 761, ARI: 0.3104, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:44,637][dance][fit] Epoch 771, ARI: 0.3106, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:48,928][dance][fit] Epoch 781, ARI: 0.3105, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:53,199][dance][fit] Epoch 791, ARI: 0.3108, Best ARI: 0.3234
# [INFO][2023-09-02 16:08:57,612][dance][fit] Epoch 801, ARI: 0.3110, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:02,054][dance][fit] Epoch 811, ARI: 0.3108, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:06,342][dance][fit] Epoch 821, ARI: 0.3110, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:10,666][dance][fit] Epoch 831, ARI: 0.3111, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:14,899][dance][fit] Epoch 841, ARI: 0.3110, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:19,158][dance][fit] Epoch 851, ARI: 0.3113, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:23,400][dance][fit] Epoch 861, ARI: 0.3113, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:27,624][dance][fit] Epoch 871, ARI: 0.3114, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:31,882][dance][fit] Epoch 881, ARI: 0.3117, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:36,158][dance][fit] Epoch 891, ARI: 0.3115, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:40,382][dance][fit] Epoch 901, ARI: 0.3116, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:44,630][dance][fit] Epoch 911, ARI: 0.3118, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:48,905][dance][fit] Epoch 921, ARI: 0.3117, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:53,191][dance][fit] Epoch 931, ARI: 0.3118, Best ARI: 0.3234
# [INFO][2023-09-02 16:09:57,483][dance][fit] Epoch 941, ARI: 0.3118, Best ARI: 0.3234
# [INFO][2023-09-02 16:10:01,745][dance][fit] Epoch 951, ARI: 0.3118, Best ARI: 0.3234
# [INFO][2023-09-02 16:10:06,081][dance][fit] Epoch 961, ARI: 0.3120, Best ARI: 0.3234
# [INFO][2023-09-02 16:10:10,388][dance][fit] Epoch 971, ARI: 0.3122, Best ARI: 0.3234
# [INFO][2023-09-02 16:10:14,683][dance][fit] Epoch 981, ARI: 0.3123, Best ARI: 0.3234
# [INFO][2023-09-02 16:10:18,922][dance][fit] Epoch 991, ARI: 0.3125, Best ARI: 0.3234
# [INFO][2023-09-02 16:10:23,016][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:10:23,048][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:10:23,049][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 2000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   NeighborGraph(n_neighbors=30, n_pcs=None, knn=True, random_state=0, method='umap', metric='correlation'),
#   SetConfig(config_dict={'feature_channel': ['NeighborGraph', None, None, 'n_counts'], 'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# score=0.3234
# [INFO][2023-09-02 16:10:23,223][dance.SaveRaw][__call__] Saving data to ``.raw``
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 16:10:23,253][dance.NeighborGraph][__call__] Start computing the kNN connectivity adjacency matrix
# [INFO][2023-09-02 16:10:24,814][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['NeighborGraph', None, None, 'n_counts'],
#  'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:10:24,817][dance][set_config_from_dict] Setting config 'feature_channel' to ['NeighborGraph', None, None, 'n_counts']
# [INFO][2023-09-02 16:10:24,818][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:10:24,819][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:10:24,820][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 4853 × 1000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'Group'
#     obsp: 'NeighborGraph'
# [INFO][2023-09-02 16:10:24,821][dance][wrapped_func] Took 0:00:01.802607 to load and process data.
# [INFO][2023-09-02 16:10:24,906][dance][_pretrain] Loading pre-trained model from scdsc_human_skin_cell_pre.pkl
# [INFO][2023-09-02 16:10:25,057][dance][fit] Epoch   1, ARI: 0.2339, Best ARI: 0.2339
# [INFO][2023-09-02 16:10:28,044][dance][fit] Epoch  11, ARI: 0.3731, Best ARI: 0.3731
# [INFO][2023-09-02 16:10:30,937][dance][fit] Epoch  21, ARI: 0.4303, Best ARI: 0.4303
# [INFO][2023-09-02 16:10:33,885][dance][fit] Epoch  31, ARI: 0.4638, Best ARI: 0.4638
# [INFO][2023-09-02 16:10:36,743][dance][fit] Epoch  41, ARI: 0.4900, Best ARI: 0.4900
# [INFO][2023-09-02 16:10:39,559][dance][fit] Epoch  51, ARI: 0.5096, Best ARI: 0.5096
# [INFO][2023-09-02 16:10:42,423][dance][fit] Epoch  61, ARI: 0.5223, Best ARI: 0.5223
# [INFO][2023-09-02 16:10:45,207][dance][fit] Epoch  71, ARI: 0.5297, Best ARI: 0.5297
# [INFO][2023-09-02 16:10:48,000][dance][fit] Epoch  81, ARI: 0.5367, Best ARI: 0.5367
# [INFO][2023-09-02 16:10:50,789][dance][fit] Epoch  91, ARI: 0.5423, Best ARI: 0.5423
# [INFO][2023-09-02 16:10:53,555][dance][fit] Epoch 101, ARI: 0.5464, Best ARI: 0.5464
# [INFO][2023-09-02 16:10:56,329][dance][fit] Epoch 111, ARI: 0.5530, Best ARI: 0.5530
# [INFO][2023-09-02 16:10:59,105][dance][fit] Epoch 121, ARI: 0.5523, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:01,881][dance][fit] Epoch 131, ARI: 0.5418, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:04,655][dance][fit] Epoch 141, ARI: 0.5300, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:07,446][dance][fit] Epoch 151, ARI: 0.5167, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:10,218][dance][fit] Epoch 161, ARI: 0.5039, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:13,007][dance][fit] Epoch 171, ARI: 0.4975, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:15,779][dance][fit] Epoch 181, ARI: 0.4882, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:18,531][dance][fit] Epoch 191, ARI: 0.4823, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:21,318][dance][fit] Epoch 201, ARI: 0.4727, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:24,077][dance][fit] Epoch 211, ARI: 0.4671, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:26,844][dance][fit] Epoch 221, ARI: 0.4566, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:29,612][dance][fit] Epoch 231, ARI: 0.4474, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:32,345][dance][fit] Epoch 241, ARI: 0.4377, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:35,105][dance][fit] Epoch 251, ARI: 0.4313, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:37,870][dance][fit] Epoch 261, ARI: 0.4252, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:40,632][dance][fit] Epoch 271, ARI: 0.4169, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:43,409][dance][fit] Epoch 281, ARI: 0.4107, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:46,176][dance][fit] Epoch 291, ARI: 0.4062, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:48,952][dance][fit] Epoch 301, ARI: 0.4044, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:51,712][dance][fit] Epoch 311, ARI: 0.4025, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:54,472][dance][fit] Epoch 321, ARI: 0.4011, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:57,226][dance][fit] Epoch 331, ARI: 0.4005, Best ARI: 0.5530
# [INFO][2023-09-02 16:11:59,968][dance][fit] Epoch 341, ARI: 0.4017, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:02,736][dance][fit] Epoch 351, ARI: 0.4034, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:05,485][dance][fit] Epoch 361, ARI: 0.4062, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:08,228][dance][fit] Epoch 371, ARI: 0.4090, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:10,987][dance][fit] Epoch 381, ARI: 0.4107, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:13,902][dance][fit] Epoch 391, ARI: 0.4143, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:16,651][dance][fit] Epoch 401, ARI: 0.4162, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:19,415][dance][fit] Epoch 411, ARI: 0.4182, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:22,172][dance][fit] Epoch 421, ARI: 0.4196, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:24,923][dance][fit] Epoch 431, ARI: 0.4211, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:27,678][dance][fit] Epoch 441, ARI: 0.4214, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:30,432][dance][fit] Epoch 451, ARI: 0.4218, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:33,183][dance][fit] Epoch 461, ARI: 0.4216, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:35,956][dance][fit] Epoch 471, ARI: 0.4222, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:38,762][dance][fit] Epoch 481, ARI: 0.4222, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:41,671][dance][fit] Epoch 491, ARI: 0.4219, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:44,462][dance][fit] Epoch 501, ARI: 0.4215, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:47,239][dance][fit] Epoch 511, ARI: 0.4213, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:49,995][dance][fit] Epoch 521, ARI: 0.4221, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:52,734][dance][fit] Epoch 531, ARI: 0.4222, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:55,508][dance][fit] Epoch 541, ARI: 0.4220, Best ARI: 0.5530
# [INFO][2023-09-02 16:12:58,268][dance][fit] Epoch 551, ARI: 0.4225, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:01,029][dance][fit] Epoch 561, ARI: 0.4229, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:03,784][dance][fit] Epoch 571, ARI: 0.4233, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:06,538][dance][fit] Epoch 581, ARI: 0.4239, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:09,302][dance][fit] Epoch 591, ARI: 0.4240, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:12,065][dance][fit] Epoch 601, ARI: 0.4249, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:14,829][dance][fit] Epoch 611, ARI: 0.4259, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:17,587][dance][fit] Epoch 621, ARI: 0.4264, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:20,367][dance][fit] Epoch 631, ARI: 0.4269, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:23,154][dance][fit] Epoch 641, ARI: 0.4266, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:25,889][dance][fit] Epoch 651, ARI: 0.4268, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:28,651][dance][fit] Epoch 661, ARI: 0.4272, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:31,347][dance][fit] Epoch 671, ARI: 0.4274, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:34,037][dance][fit] Epoch 681, ARI: 0.4273, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:36,712][dance][fit] Epoch 691, ARI: 0.4275, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:39,404][dance][fit] Epoch 701, ARI: 0.4280, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:42,107][dance][fit] Epoch 711, ARI: 0.4279, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:44,817][dance][fit] Epoch 721, ARI: 0.4279, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:47,515][dance][fit] Epoch 731, ARI: 0.4280, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:50,210][dance][fit] Epoch 741, ARI: 0.4281, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:52,916][dance][fit] Epoch 751, ARI: 0.4282, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:55,612][dance][fit] Epoch 761, ARI: 0.4285, Best ARI: 0.5530
# [INFO][2023-09-02 16:13:58,347][dance][fit] Epoch 771, ARI: 0.4289, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:01,059][dance][fit] Epoch 781, ARI: 0.4288, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:03,750][dance][fit] Epoch 791, ARI: 0.4286, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:06,443][dance][fit] Epoch 801, ARI: 0.4287, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:09,125][dance][fit] Epoch 811, ARI: 0.4286, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:11,846][dance][fit] Epoch 821, ARI: 0.4283, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:14,560][dance][fit] Epoch 831, ARI: 0.4282, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:17,257][dance][fit] Epoch 841, ARI: 0.4281, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:19,990][dance][fit] Epoch 851, ARI: 0.4281, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:22,696][dance][fit] Epoch 861, ARI: 0.4284, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:25,377][dance][fit] Epoch 871, ARI: 0.4282, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:28,059][dance][fit] Epoch 881, ARI: 0.4282, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:30,780][dance][fit] Epoch 891, ARI: 0.4280, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:33,474][dance][fit] Epoch 901, ARI: 0.4280, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:36,164][dance][fit] Epoch 911, ARI: 0.4281, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:38,854][dance][fit] Epoch 921, ARI: 0.4282, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:41,532][dance][fit] Epoch 931, ARI: 0.4283, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:44,199][dance][fit] Epoch 941, ARI: 0.4283, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:46,871][dance][fit] Epoch 951, ARI: 0.4282, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:49,554][dance][fit] Epoch 961, ARI: 0.4284, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:52,233][dance][fit] Epoch 971, ARI: 0.4283, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:54,916][dance][fit] Epoch 981, ARI: 0.4281, Best ARI: 0.5530
# [INFO][2023-09-02 16:14:57,601][dance][fit] Epoch 991, ARI: 0.4280, Best ARI: 0.5530
# [INFO][2023-09-02 16:15:00,196][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:15:00,211][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1756 × 1000
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:15:00,212][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 2000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
# ...
# [INFO][2023-09-02 16:17:15,762][dance][fit] Epoch 571, ARI: 0.3239, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:16,027][dance][fit] Epoch 581, ARI: 0.3239, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:16,295][dance][fit] Epoch 591, ARI: 0.3239, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:16,559][dance][fit] Epoch 601, ARI: 0.3239, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:16,823][dance][fit] Epoch 611, ARI: 0.3239, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:17,087][dance][fit] Epoch 621, ARI: 0.3239, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:17,352][dance][fit] Epoch 631, ARI: 0.3203, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:17,615][dance][fit] Epoch 641, ARI: 0.3203, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:17,879][dance][fit] Epoch 651, ARI: 0.3203, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:18,144][dance][fit] Epoch 661, ARI: 0.3190, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:18,407][dance][fit] Epoch 671, ARI: 0.3190, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:18,673][dance][fit] Epoch 681, ARI: 0.3190, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:18,938][dance][fit] Epoch 691, ARI: 0.3190, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:19,200][dance][fit] Epoch 701, ARI: 0.3157, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:19,465][dance][fit] Epoch 711, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:19,729][dance][fit] Epoch 721, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:19,992][dance][fit] Epoch 731, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:20,258][dance][fit] Epoch 741, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:20,524][dance][fit] Epoch 751, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:20,788][dance][fit] Epoch 761, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:21,051][dance][fit] Epoch 771, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:21,315][dance][fit] Epoch 781, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:21,578][dance][fit] Epoch 791, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:21,845][dance][fit] Epoch 801, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:22,111][dance][fit] Epoch 811, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:22,376][dance][fit] Epoch 821, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:22,641][dance][fit] Epoch 831, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:22,906][dance][fit] Epoch 841, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:23,169][dance][fit] Epoch 851, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:23,439][dance][fit] Epoch 861, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:23,701][dance][fit] Epoch 871, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:23,969][dance][fit] Epoch 881, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:24,230][dance][fit] Epoch 891, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:24,495][dance][fit] Epoch 901, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:24,759][dance][fit] Epoch 911, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:25,023][dance][fit] Epoch 921, ARI: 0.3125, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:25,287][dance][fit] Epoch 931, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:25,553][dance][fit] Epoch 941, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:25,816][dance][fit] Epoch 951, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:26,081][dance][fit] Epoch 961, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:26,346][dance][fit] Epoch 971, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:26,609][dance][fit] Epoch 981, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:26,877][dance][fit] Epoch 991, ARI: 0.3131, Best ARI: 0.3271
# [INFO][2023-09-02 16:17:27,136][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:17:27,285][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:17:27,286][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 2000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   NeighborGraph(n_neighbors=30, n_pcs=None, knn=True, random_state=0, method='umap', metric='correlation'),
#   SetConfig(config_dict={'feature_channel': ['NeighborGraph', None, None, 'n_counts'], 'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# score=0.3271
# [INFO][2023-09-02 16:17:27,510][dance.SaveRaw][__call__] Saving data to ``.raw``
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 16:17:27,521][dance.NeighborGraph][__call__] Start computing the kNN connectivity adjacency matrix
# [INFO][2023-09-02 16:17:28,104][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['NeighborGraph', None, None, 'n_counts'],
#  'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:17:28,105][dance][set_config_from_dict] Setting config 'feature_channel' to ['NeighborGraph', None, None, 'n_counts']
# [INFO][2023-09-02 16:17:28,106][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:17:28,107][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:17:28,108][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 2000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'Group'
#     obsp: 'NeighborGraph'
# [INFO][2023-09-02 16:17:28,108][dance][wrapped_func] Took 0:00:00.970711 to load and process data.
# [INFO][2023-09-02 16:17:28,147][dance][_pretrain] Loading pre-trained model from scdsc_mouse_kidney_10x_pre.pkl
# [INFO][2023-09-02 16:17:28,188][dance][fit] Epoch   1, ARI: 0.2553, Best ARI: 0.2553
# [INFO][2023-09-02 16:17:28,914][dance][fit] Epoch  11, ARI: 0.4759, Best ARI: 0.4759
# [INFO][2023-09-02 16:17:29,624][dance][fit] Epoch  21, ARI: 0.5458, Best ARI: 0.5458
# [INFO][2023-09-02 16:17:30,328][dance][fit] Epoch  31, ARI: 0.5856, Best ARI: 0.5856
# [INFO][2023-09-02 16:17:31,031][dance][fit] Epoch  41, ARI: 0.5907, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:31,716][dance][fit] Epoch  51, ARI: 0.5858, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:32,359][dance][fit] Epoch  61, ARI: 0.5671, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:32,997][dance][fit] Epoch  71, ARI: 0.5520, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:33,635][dance][fit] Epoch  81, ARI: 0.5344, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:34,280][dance][fit] Epoch  91, ARI: 0.5155, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:34,918][dance][fit] Epoch 101, ARI: 0.4982, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:35,553][dance][fit] Epoch 111, ARI: 0.4908, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:36,190][dance][fit] Epoch 121, ARI: 0.4815, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:36,824][dance][fit] Epoch 131, ARI: 0.4751, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:37,463][dance][fit] Epoch 141, ARI: 0.4707, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:38,096][dance][fit] Epoch 151, ARI: 0.4655, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:38,731][dance][fit] Epoch 161, ARI: 0.4624, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:39,364][dance][fit] Epoch 171, ARI: 0.4595, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:39,996][dance][fit] Epoch 181, ARI: 0.4598, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:40,628][dance][fit] Epoch 191, ARI: 0.4585, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:41,258][dance][fit] Epoch 201, ARI: 0.4527, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:41,889][dance][fit] Epoch 211, ARI: 0.4495, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:42,517][dance][fit] Epoch 221, ARI: 0.4463, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:43,146][dance][fit] Epoch 231, ARI: 0.4445, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:43,783][dance][fit] Epoch 241, ARI: 0.4402, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:44,574][dance][fit] Epoch 251, ARI: 0.4392, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:45,206][dance][fit] Epoch 261, ARI: 0.4381, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:45,837][dance][fit] Epoch 271, ARI: 0.4369, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:46,468][dance][fit] Epoch 281, ARI: 0.4346, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:47,099][dance][fit] Epoch 291, ARI: 0.4347, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:47,731][dance][fit] Epoch 301, ARI: 0.4348, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:48,378][dance][fit] Epoch 311, ARI: 0.4327, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:49,060][dance][fit] Epoch 321, ARI: 0.4315, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:49,691][dance][fit] Epoch 331, ARI: 0.4285, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:50,322][dance][fit] Epoch 341, ARI: 0.4280, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:50,952][dance][fit] Epoch 351, ARI: 0.4260, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:51,581][dance][fit] Epoch 361, ARI: 0.4255, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:52,208][dance][fit] Epoch 371, ARI: 0.4243, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:52,842][dance][fit] Epoch 381, ARI: 0.4224, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:53,476][dance][fit] Epoch 391, ARI: 0.4199, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:54,105][dance][fit] Epoch 401, ARI: 0.4197, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:54,742][dance][fit] Epoch 411, ARI: 0.4158, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:55,372][dance][fit] Epoch 421, ARI: 0.4135, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:56,005][dance][fit] Epoch 431, ARI: 0.4120, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:56,639][dance][fit] Epoch 441, ARI: 0.4096, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:57,288][dance][fit] Epoch 451, ARI: 0.4090, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:57,939][dance][fit] Epoch 461, ARI: 0.4088, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:58,571][dance][fit] Epoch 471, ARI: 0.4081, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:59,201][dance][fit] Epoch 481, ARI: 0.4079, Best ARI: 0.5907
# [INFO][2023-09-02 16:17:59,838][dance][fit] Epoch 491, ARI: 0.4077, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:00,470][dance][fit] Epoch 501, ARI: 0.4072, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:01,100][dance][fit] Epoch 511, ARI: 0.4079, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:01,730][dance][fit] Epoch 521, ARI: 0.4068, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:02,362][dance][fit] Epoch 531, ARI: 0.4066, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:03,000][dance][fit] Epoch 541, ARI: 0.4057, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:03,632][dance][fit] Epoch 551, ARI: 0.4069, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:04,270][dance][fit] Epoch 561, ARI: 0.4067, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:04,901][dance][fit] Epoch 571, ARI: 0.4070, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:05,529][dance][fit] Epoch 581, ARI: 0.4069, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:06,162][dance][fit] Epoch 591, ARI: 0.4068, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:06,794][dance][fit] Epoch 601, ARI: 0.4069, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:07,425][dance][fit] Epoch 611, ARI: 0.4063, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:08,059][dance][fit] Epoch 621, ARI: 0.4063, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:08,710][dance][fit] Epoch 631, ARI: 0.4056, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:09,343][dance][fit] Epoch 641, ARI: 0.4055, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:09,977][dance][fit] Epoch 651, ARI: 0.4050, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:10,605][dance][fit] Epoch 661, ARI: 0.4036, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:11,237][dance][fit] Epoch 671, ARI: 0.4021, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:11,865][dance][fit] Epoch 681, ARI: 0.4007, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:12,499][dance][fit] Epoch 691, ARI: 0.4002, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:13,126][dance][fit] Epoch 701, ARI: 0.3993, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:13,761][dance][fit] Epoch 711, ARI: 0.3979, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:14,392][dance][fit] Epoch 721, ARI: 0.3968, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:15,022][dance][fit] Epoch 731, ARI: 0.3971, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:15,653][dance][fit] Epoch 741, ARI: 0.3962, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:16,281][dance][fit] Epoch 751, ARI: 0.3956, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:16,917][dance][fit] Epoch 761, ARI: 0.3954, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:17,550][dance][fit] Epoch 771, ARI: 0.3954, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:18,182][dance][fit] Epoch 781, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:18,814][dance][fit] Epoch 791, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:19,441][dance][fit] Epoch 801, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:20,074][dance][fit] Epoch 811, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:20,704][dance][fit] Epoch 821, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:21,335][dance][fit] Epoch 831, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:21,966][dance][fit] Epoch 841, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:22,597][dance][fit] Epoch 851, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:23,227][dance][fit] Epoch 861, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:23,861][dance][fit] Epoch 871, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:24,497][dance][fit] Epoch 881, ARI: 0.3955, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:25,128][dance][fit] Epoch 891, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:25,756][dance][fit] Epoch 901, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:26,383][dance][fit] Epoch 911, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:27,016][dance][fit] Epoch 921, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:27,645][dance][fit] Epoch 931, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:28,276][dance][fit] Epoch 941, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:28,907][dance][fit] Epoch 951, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:29,539][dance][fit] Epoch 961, ARI: 0.3957, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:30,170][dance][fit] Epoch 971, ARI: 0.3956, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:30,799][dance][fit] Epoch 981, ARI: 0.3956, Best ARI: 0.5907
# [INFO][2023-09-02 16:18:31,430][dance][fit] Epoch 991, ARI: 0.3956, Best ARI: 0.5907
# score=0.5907
# 'Reproduction information\n10X PBMC:\npython scdsc.py --dataset 10X_PBMC --method cosine --topk 30 --v 7 --binary_crossentropy_loss 0.75 --ce_loss 0.5 --re_loss 0.1 --zinb_loss 2.5 --sigma 0.4\n\nMouse Bladder:\npython scdsc.py --dataset mouse_bladder_cell --topk 50 --v 7 --binary_crossentropy_loss 2.5 --ce_loss 0.1 --re_loss 0.5 --zinb_loss 1.5 --sigma 0.6\n\nMouse ES:\npython scdsc.py --dataset mouse_ES_cell --topk 50 --v 7 --binary_crossentropy_loss 0.1 --ce_loss 0.01 --re_loss 1.5 --zinb_loss 0.5 --sigma 0.1\n\nWorm Neuron:\npython scdsc.py --dataset worm_neuron_cell --topk 20 --v 7 --binary_crossentropy_loss 2 --ce_loss 2 --re_loss 3 --zinb_loss 0.1 --sigma 0.4\n'

# %%
scdsc_scores
# Out:
# [0.5722479940804349,
#  0.21680167115856036,
#  0.32343149332579424,
#  0.5530234095994098,
#  0.6596624201855319,
#  0.3270840856044606,
#  0.3270840856044606,
#  0.5907197301775053]

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import argparse

import numpy as np

from dance.datasets.singlemodality import ClusteringDataset
from dance.modules.single_modality.clustering.sctag import ScTAG
from dance.utils import set_seed

parser = argparse.ArgumentParser(description="train", formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--data_dir", default="./data", type=str)
parser.add_argument("--dataset", default="mouse_bladder_cell", type=str,
                    choices=["10X_PBMC", "mouse_bladder_cell", "mouse_ES_cell", "worm_neuron_cell","mouse_kidney_cell","human_pbmc_cell","human_pbmc2_cell","human_skin_cell","human_lung_cell","mouse_kidney_drop","mouse_kidney_cl2","mouse_kidney_10x"])
parser.add_argument("--k_neighbor", default=15, type=int)
parser.add_argument("--highly_genes", default=3000, type=int)
parser.add_argument("--pca_dim", default=50, type=int)
parser.add_argument("--k", default=2, type=int)
parser.add_argument("--hidden_dim", default=128, type=int)
parser.add_argument("--latent_dim", default=15, type=int)
parser.add_argument("--dec_dim", default=None, type=int)
parser.add_argument("--dropout", default=0.4, type=float)
parser.add_argument("--alpha", default=1.0, type=float)
parser.add_argument("--pretrain_epochs", default=200, type=int)
parser.add_argument("--epochs", default=500, type=int)
parser.add_argument("--device", default="cpu")
parser.add_argument("--w_a", default=1, type=float)
parser.add_argument("--w_x", default=1, type=float)
parser.add_argument("--w_d", default=0, type=float)
parser.add_argument("--w_c", default=1, type=float)
parser.add_argument("--lr", default=1e-3, type=float)
parser.add_argument("--min_dist", default=0.5, type=float)
parser.add_argument("--max_dist", default=20.0, type=float)
parser.add_argument("--info_step", default=50, type=int)
parser.add_argument("--seed", type=int, default=42)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
sctag_scores=[]
for dataset in datasets:
    args = parser.parse_args([ '--dataset',dataset,'--pretrain_epochs','100',"--k","1"])
    set_seed(args.seed)

    # Load data and perform necessary preprocessing
    dataloader = ClusteringDataset(args.data_dir, args.dataset)
    preprocessing_pipeline = ScTAG.preprocessing_pipeline(n_top_genes=args.highly_genes, n_components=args.pca_dim,
                                                          n_neighbors=args.k_neighbor)
    data = dataloader.load_data(transform=preprocessing_pipeline, cache=args.cache)

    # inputs: adj, x, x_raw, n_counts
    inputs, y = data.get_train_data()

    n_clusters = len(np.unique(y))

    # Build and train model
    model = ScTAG(n_clusters=n_clusters, k=args.k, hidden_dim=args.hidden_dim, latent_dim=args.latent_dim,
                  dec_dim=args.dec_dim, dropout=args.dropout, device=args.device, alpha=args.alpha,
                  pretrain_path=f"sctag_{args.dataset}_pre.pkl")
    print(np.max(inputs[0]))
    model.fit(inputs, y, epochs=args.epochs, pretrain_epochs=args.pretrain_epochs, lr=args.lr, w_a=args.w_a,
              w_x=args.w_x, w_c=args.w_c, w_d=args.w_d, info_step=args.info_step, max_dist=args.max_dist,
              min_dist=args.min_dist)

    # Evaluate model predictions
    score = model.score(None, y)
    print(f"{score=:.4f}")
    sctag_scores.append(score)
"""Reproduction information
10X PBMC:
python sctag.py --dataset 10X_PBMC --pretrain_epochs 100 --w_a 0.01 --w_x 3 --w_c 0.1 --dropout 0.5

Mouse ES:
python sctag.py --dataset mouse_ES_cell --pretrain_epochs 100 --w_a 0.01 --w_x 0.75 --w_c 1

Worm Neuron:
python sctag.py --dataset worm_neuron_cell --w_a 0.01 --w_x 2 --w_c 0.25 --k 1

Mouse Bladder:
python sctag.py --dataset mouse_bladder_cell --pretrain_epochs 100 --w_a 0.1 --w_x 2.5 --w_c 3
"""
# Out:
# [INFO][2023-09-02 16:18:32,108][dance][set_seed] Setting global random seed to 42
# [INFO][2023-09-02 16:18:32,181][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 16468
#     uns: 'dance_config'
#     obsm: 'Group'
# [INFO][2023-09-02 16:18:32,181][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 3}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.normalize_per_cell, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'min_mean': 0.0125, 'max_mean': 4, 'flavor': 'cell_ranger', 'min_disp': 0.5, 'n_top_genes': 3000, 'subset': True}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_genes, func_kwargs={'min_counts': 1}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.filter_cells, func_kwargs={'min_counts': 1}),
#   SaveRaw(),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.scale, func_kwargs={}),
#   CellPCA(n_components=50),
#   NeighborGraph(n_neighbors=15, n_pcs=50, knn=True, random_state=0, method='umap', metric='euclidean'),
#   SetConfig(config_dict={'feature_channel': ['NeighborGraph', None, None, 'n_counts'], 'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'], 'label_channel': 'Group'}),
# )
# [INFO][2023-09-02 16:18:32,474][dance.SaveRaw][__call__] Saving data to ``.raw``
# WARNING: adata.X seems to be already log-transformed.
# [INFO][2023-09-02 16:18:32,491][dance.CellPCA][__call__] Start generating cell PCA features (902, 3000) (k=50)
# [INFO][2023-09-02 16:18:32,527][dance.CellPCA][__call__] Top 10 explained variances: [0.17064218 0.09295565 0.03068668 0.02320614 0.01286646 0.0118582
#  0.00996639 0.00687872 0.0059774  0.00535993]
# [INFO][2023-09-02 16:18:32,527][dance.CellPCA][__call__] Total explained variance: 47.30%
# [INFO][2023-09-02 16:18:32,528][dance.NeighborGraph][__call__] Start computing the kNN connectivity adjacency matrix
# [INFO][2023-09-02 16:18:32,570][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['NeighborGraph', None, None, 'n_counts'],
#  'feature_channel_type': ['obsp', 'X', 'raw_X', 'obs'],
#  'label_channel': 'Group'}
# [INFO][2023-09-02 16:18:32,570][dance][set_config_from_dict] Setting config 'feature_channel' to ['NeighborGraph', None, None, 'n_counts']
# [INFO][2023-09-02 16:18:32,571][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X', 'raw_X', 'obs']
# [INFO][2023-09-02 16:18:32,571][dance][set_config_from_dict] Setting config 'label_channel' to 'Group'
# [INFO][2023-09-02 16:18:32,572][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 902 × 3000
#     obs: 'n_counts'
#     var: 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'Group', 'CellPCA'
#     obsp: 'NeighborGraph'
# [INFO][2023-09-02 16:18:32,572][dance][wrapped_func] Took 0:00:00.462494 to load and process data.
# [INFO][2023-09-02 16:18:32,633][dance][_pretrain] Loading pre-trained model from sctag_mouse_kidney_cell_pre.pkl
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 1.0
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# [INFO][2023-09-02 16:18:32,727][dance][fit] Epoch   1, ARI: 0.9965, Best ARI: 0.9965
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# [INFO][2023-09-02 16:18:35,532][dance][fit] Epoch  51, ARI: 1.0000, Best ARI: 1.0000
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# ...
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# score=1.0000
# /home/zyxing/anaconda3/envs/dance-env/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# 'Reproduction information\n10X PBMC:\npython sctag.py --dataset 10X_PBMC --pretrain_epochs 100 --w_a 0.01 --w_x 3 --w_c 0.1 --dropout 0.5\n\nMouse ES:\npython sctag.py --dataset mouse_ES_cell --pretrain_epochs 100 --w_a 0.01 --w_x 0.75 --w_c 1\n\nWorm Neuron:\npython sctag.py --dataset worm_neuron_cell --w_a 0.01 --w_x 2 --w_c 0.25 --k 1\n\nMouse Bladder:\npython sctag.py --dataset mouse_bladder_cell --pretrain_epochs 100 --w_a 0.1 --w_x 2.5 --w_c 3\n'

# %%
sctag_scores
# Out:
# [1.0,
#  0.8596006841137562,
#  0.40078924676001404,
#  0.9156527237548763,
#  0.8447362442419666,
#  0.9209258226474065,
#  0.9209258226474065,
#  1.0]
