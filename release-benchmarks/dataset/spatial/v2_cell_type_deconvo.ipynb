# %%
datasets=["lung6","lung9_1","lung9_2","hcc_liver","normal_liver","kidney_1139","kidney_10838","kidney_3323","kidney_642",
        "kidney_8693","kidney_2566","kidney_213","kidney_4061","kidney_1098","kidney_8471"]

# %%
import argparse
from pprint import pprint

from dance.datasets.spatial import CellTypeDeconvoDataset
from dance.modules.spatial.cell_type_deconvo.card import Card
card_scores=[]
parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
parser.add_argument("--dataset", default="CARD_synthetic", choices=CellTypeDeconvoDataset.AVAILABLE_DATA)
parser.add_argument("--datadir", default="../../../../data/spatial", help="Directory to save the data.")
parser.add_argument("--max_iter", type=int, default=10, help="Maximum optimization iteration.")
parser.add_argument("--epsilon", type=float, default=1e-10, help="Optimization threshold.")
parser.add_argument("--location_free", action="store_true", help="Do not supply spatial location if set.")
for dataset in datasets:
    try:
        args = parser.parse_args(['--dataset',dataset])
        pprint(vars(args))

        # Load dataset
        preprocessing_pipeline = Card.preprocessing_pipeline()
        dataset = CellTypeDeconvoDataset(data_dir=args.datadir, data_id=args.dataset)
        data = dataset.load_data(transform=preprocessing_pipeline, cache=args.cache)

        # inputs: x_count, x_spatial
        inputs, y = data.get_data(split_name="test", return_type="numpy")
        basis = data.get_feature(return_type="default", channel="CellTopicProfile", channel_type="varm")

        # Train and evaluate model
        model = Card(basis)
        score = model.fit_score(inputs, y, max_iter=args.max_iter, epsilon=args.epsilon, location_free=args.location_free)
    except Exception as e:
        score=e
    finally:
        card_scores.append(score)
"""To reproduce CARD benchmarks, please refer to command lines belows:

CARD synthetic $ python card.py --dataset CARD_synthetic

GSE174746 $ python card.py --dataset GSE174746 --location_free

SPOTLight synthetic $ python card.py --dataset SPOTLight_synthetic --location_free

"""
# Out:
# {'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung6',
#  'epsilon': 1e-10,
#  'location_free': False,
#  'max_iter': 10}
# [INFO][2023-10-18 09:15:51,908][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:15:51,909][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:52,036][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:15:52,037][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='mean'),
#   FilterGenesMatch(prefixes=['mt-'], suffixes=[]),
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   FilterGenesMarker(ct_profile_channel='CellTopicProfile', subset=True, threshold=1.25, eps=1e-06),
#   FilterGenesPercentile(min_val=1, max_val=99, mode='rv'),
#   SetConfig(config_dict={'feature_channel': [None, 'spatial'], 'feature_channel_type': ['X', 'obsm'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:15:52,073][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('mean' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:15:52,083][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:15:52,087][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:15:52,088][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:15:52,090][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:15:52,092][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:15:52,099][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:15:52,101][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:15:52,102][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:15:52,104][dance.CellTopicProfile][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:15:52,109][dance.CellTopicProfile][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:15:52,111][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:15:52,112][dance.CellTopicProfile][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:15:52,113][dance.CellTopicProfile][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:15:52,116][dance.CellTopicProfile][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:15:52,118][dance.CellTopicProfile][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:15:52,120][dance.CellTopicProfile][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:15:52,121][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:15:52,124][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:15:52,125][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:15:52,127][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:15:52,128][dance.CellTopicProfile][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:15:52,130][dance.CellTopicProfile][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:15:52,130][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:15:52,133][dance.FilterGenesMatch][__call__] 0 number of genes will be removed due to prefix 'mt-'
# [INFO][2023-10-18 09:15:52,133][dance.FilterGenesMatch][__call__] Removing 0 genes in total
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:52,258][dance.FilterGenesCommon][__call__] 923 genes found in 'ref'
# [INFO][2023-10-18 09:15:52,260][dance.FilterGenesCommon][__call__] 923 genes found in 'test'
# [INFO][2023-10-18 09:15:52,261][dance.FilterGenesCommon][__call__] Found 923 common genes out of 923 total genes.
# True
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:52,339][dance.FilterGenesMarker][get_marker_genes] Found 14 marker genes for cell type 'B_cell'
# [INFO][2023-10-18 09:15:52,340][dance.FilterGenesMarker][get_marker_genes] Found 224 marker genes for cell type 'Endothelial'
# [INFO][2023-10-18 09:15:52,342][dance.FilterGenesMarker][get_marker_genes] Found 168 marker genes for cell type 'Epithelial'
# [INFO][2023-10-18 09:15:52,343][dance.FilterGenesMarker][get_marker_genes] Found 215 marker genes for cell type 'Fibroblast'
# [INFO][2023-10-18 09:15:52,344][dance.FilterGenesMarker][get_marker_genes] Found 122 marker genes for cell type 'Macrophage'
# [INFO][2023-10-18 09:15:52,346][dance.FilterGenesMarker][get_marker_genes] Found 16 marker genes for cell type 'Mast'
# [INFO][2023-10-18 09:15:52,347][dance.FilterGenesMarker][get_marker_genes] Found 18 marker genes for cell type 'Monocyte'
# [INFO][2023-10-18 09:15:52,348][dance.FilterGenesMarker][get_marker_genes] Found 91 marker genes for cell type 'Myeloid'
# [INFO][2023-10-18 09:15:52,349][dance.FilterGenesMarker][get_marker_genes] Found 47 marker genes for cell type 'NK_cell'
# [INFO][2023-10-18 09:15:52,351][dance.FilterGenesMarker][get_marker_genes] Found 23 marker genes for cell type 'Neutrophil'
# [INFO][2023-10-18 09:15:52,352][dance.FilterGenesMarker][get_marker_genes] Found 28 marker genes for cell type 'Plasma'
# [INFO][2023-10-18 09:15:52,353][dance.FilterGenesMarker][get_marker_genes] Total number of marker genes found: 695
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:52,448][dance.FilterGenesPercentile][__call__] Filtering genes based on rv expression percentiles in layer None
# [INFO][2023-10-18 09:15:52,450][dance.FilterGenesPercentile][__call__] 14 genes removed
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:52,509][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, 'spatial'],
#  'feature_channel_type': ['X', 'obsm'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:15:52,510][dance][set_config_from_dict] Setting config 'feature_channel' to [None, 'spatial']
# [INFO][2023-10-18 09:15:52,511][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'obsm']
# [INFO][2023-10-18 09:15:52,512][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:15:52,513][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 681
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile', 'FilterGenesMarker'
# [INFO][2023-10-18 09:15:52,514][dance][wrapped_func] Took 0:00:00.844426 to load and process data.
# [INFO][2023-10-18 09:15:52,746][dance][fit] Deconvolution finished
# True
# True
# {'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_1',
#  'epsilon': 1e-10,
#  'location_free': False,
#  'max_iter': 10}
# [INFO][2023-10-18 09:15:53,097][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:15:53,099][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:53,249][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:15:53,250][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='mean'),
#   FilterGenesMatch(prefixes=['mt-'], suffixes=[]),
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   FilterGenesMarker(ct_profile_channel='CellTopicProfile', subset=True, threshold=1.25, eps=1e-06),
#   FilterGenesPercentile(min_val=1, max_val=99, mode='rv'),
#   SetConfig(config_dict={'feature_channel': [None, 'spatial'], 'feature_channel_type': ['X', 'obsm'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:15:53,297][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('mean' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:15:53,306][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:15:53,311][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:15:53,313][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:15:53,316][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:15:53,317][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:15:53,325][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:15:53,326][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:15:53,328][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:15:53,329][dance.CellTopicProfile][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:15:53,335][dance.CellTopicProfile][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:15:53,336][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:15:53,339][dance.CellTopicProfile][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:15:53,341][dance.CellTopicProfile][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:15:53,344][dance.CellTopicProfile][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:15:53,346][dance.CellTopicProfile][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:15:53,349][dance.CellTopicProfile][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:15:53,350][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:15:53,354][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:15:53,355][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:15:53,356][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:15:53,358][dance.CellTopicProfile][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:15:53,360][dance.CellTopicProfile][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:15:53,361][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:15:53,363][dance.FilterGenesMatch][__call__] 0 number of genes will be removed due to prefix 'mt-'
# [INFO][2023-10-18 09:15:53,364][dance.FilterGenesMatch][__call__] Removing 0 genes in total
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:53,499][dance.FilterGenesCommon][__call__] 923 genes found in 'ref'
# [INFO][2023-10-18 09:15:53,501][dance.FilterGenesCommon][__call__] 923 genes found in 'test'
# [INFO][2023-10-18 09:15:53,502][dance.FilterGenesCommon][__call__] Found 923 common genes out of 923 total genes.
# True
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:53,579][dance.FilterGenesMarker][get_marker_genes] Found 14 marker genes for cell type 'B_cell'
# [INFO][2023-10-18 09:15:53,581][dance.FilterGenesMarker][get_marker_genes] Found 224 marker genes for cell type 'Endothelial'
# [INFO][2023-10-18 09:15:53,582][dance.FilterGenesMarker][get_marker_genes] Found 168 marker genes for cell type 'Epithelial'
# [INFO][2023-10-18 09:15:53,584][dance.FilterGenesMarker][get_marker_genes] Found 215 marker genes for cell type 'Fibroblast'
# [INFO][2023-10-18 09:15:53,585][dance.FilterGenesMarker][get_marker_genes] Found 122 marker genes for cell type 'Macrophage'
# [INFO][2023-10-18 09:15:53,586][dance.FilterGenesMarker][get_marker_genes] Found 16 marker genes for cell type 'Mast'
# [INFO][2023-10-18 09:15:53,588][dance.FilterGenesMarker][get_marker_genes] Found 18 marker genes for cell type 'Monocyte'
# [INFO][2023-10-18 09:15:53,589][dance.FilterGenesMarker][get_marker_genes] Found 91 marker genes for cell type 'Myeloid'
# [INFO][2023-10-18 09:15:53,590][dance.FilterGenesMarker][get_marker_genes] Found 47 marker genes for cell type 'NK_cell'
# [INFO][2023-10-18 09:15:53,591][dance.FilterGenesMarker][get_marker_genes] Found 23 marker genes for cell type 'Neutrophil'
# [INFO][2023-10-18 09:15:53,592][dance.FilterGenesMarker][get_marker_genes] Found 28 marker genes for cell type 'Plasma'
# [INFO][2023-10-18 09:15:53,594][dance.FilterGenesMarker][get_marker_genes] Total number of marker genes found: 695
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:53,687][dance.FilterGenesPercentile][__call__] Filtering genes based on rv expression percentiles in layer None
# [INFO][2023-10-18 09:15:53,689][dance.FilterGenesPercentile][__call__] 14 genes removed
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:53,746][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, 'spatial'],
#  'feature_channel_type': ['X', 'obsm'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:15:53,747][dance][set_config_from_dict] Setting config 'feature_channel' to [None, 'spatial']
# [INFO][2023-10-18 09:15:53,748][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'obsm']
# [INFO][2023-10-18 09:15:53,749][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:15:53,749][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 681
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile', 'FilterGenesMarker'
# [INFO][2023-10-18 09:15:53,751][dance][wrapped_func] Took 0:00:01.001781 to load and process data.
# [INFO][2023-10-18 09:15:53,868][dance][fit] Deconvolution finished
# True
# True
# {'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_2',
#  'epsilon': 1e-10,
#  'location_free': False,
#  'max_iter': 10}
# [INFO][2023-10-18 09:15:54,167][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:15:54,169][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:54,301][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:15:54,302][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='mean'),
#   FilterGenesMatch(prefixes=['mt-'], suffixes=[]),
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   FilterGenesMarker(ct_profile_channel='CellTopicProfile', subset=True, threshold=1.25, eps=1e-06),
#   FilterGenesPercentile(min_val=1, max_val=99, mode='rv'),
#   SetConfig(config_dict={'feature_channel': [None, 'spatial'], 'feature_channel_type': ['X', 'obsm'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:15:54,338][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('mean' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:15:54,346][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:15:54,350][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:15:54,351][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:15:54,353][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:15:54,355][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:15:54,362][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:15:54,363][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:15:54,365][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:15:54,366][dance.CellTopicProfile][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:15:54,371][dance.CellTopicProfile][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:15:54,372][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:15:54,374][dance.CellTopicProfile][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:15:54,375][dance.CellTopicProfile][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:15:54,378][dance.CellTopicProfile][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:15:54,379][dance.CellTopicProfile][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:15:54,382][dance.CellTopicProfile][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:15:54,383][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:15:54,386][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:15:54,387][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:15:54,389][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:15:54,390][dance.CellTopicProfile][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:15:54,392][dance.CellTopicProfile][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:15:54,392][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:15:54,395][dance.FilterGenesMatch][__call__] 0 number of genes will be removed due to prefix 'mt-'
# [INFO][2023-10-18 09:15:54,395][dance.FilterGenesMatch][__call__] Removing 0 genes in total
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:54,517][dance.FilterGenesCommon][__call__] 923 genes found in 'ref'
# [INFO][2023-10-18 09:15:54,520][dance.FilterGenesCommon][__call__] 923 genes found in 'test'
# [INFO][2023-10-18 09:15:54,521][dance.FilterGenesCommon][__call__] Found 923 common genes out of 923 total genes.
# True
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:54,602][dance.FilterGenesMarker][get_marker_genes] Found 14 marker genes for cell type 'B_cell'
# [INFO][2023-10-18 09:15:54,603][dance.FilterGenesMarker][get_marker_genes] Found 224 marker genes for cell type 'Endothelial'
# [INFO][2023-10-18 09:15:54,605][dance.FilterGenesMarker][get_marker_genes] Found 168 marker genes for cell type 'Epithelial'
# [INFO][2023-10-18 09:15:54,606][dance.FilterGenesMarker][get_marker_genes] Found 215 marker genes for cell type 'Fibroblast'
# [INFO][2023-10-18 09:15:54,607][dance.FilterGenesMarker][get_marker_genes] Found 122 marker genes for cell type 'Macrophage'
# [INFO][2023-10-18 09:15:54,608][dance.FilterGenesMarker][get_marker_genes] Found 16 marker genes for cell type 'Mast'
# [INFO][2023-10-18 09:15:54,609][dance.FilterGenesMarker][get_marker_genes] Found 18 marker genes for cell type 'Monocyte'
# [INFO][2023-10-18 09:15:54,611][dance.FilterGenesMarker][get_marker_genes] Found 91 marker genes for cell type 'Myeloid'
# [INFO][2023-10-18 09:15:54,612][dance.FilterGenesMarker][get_marker_genes] Found 47 marker genes for cell type 'NK_cell'
# [INFO][2023-10-18 09:15:54,613][dance.FilterGenesMarker][get_marker_genes] Found 23 marker genes for cell type 'Neutrophil'
# [INFO][2023-10-18 09:15:54,614][dance.FilterGenesMarker][get_marker_genes] Found 28 marker genes for cell type 'Plasma'
# [INFO][2023-10-18 09:15:54,616][dance.FilterGenesMarker][get_marker_genes] Total number of marker genes found: 695
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:54,708][dance.FilterGenesPercentile][__call__] Filtering genes based on rv expression percentiles in layer None
# [INFO][2023-10-18 09:15:54,710][dance.FilterGenesPercentile][__call__] 14 genes removed
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:54,770][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, 'spatial'],
#  'feature_channel_type': ['X', 'obsm'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:15:54,771][dance][set_config_from_dict] Setting config 'feature_channel' to [None, 'spatial']
# [INFO][2023-10-18 09:15:54,772][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'obsm']
# [INFO][2023-10-18 09:15:54,773][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:15:54,774][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 681
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile', 'FilterGenesMarker'
# [INFO][2023-10-18 09:15:54,775][dance][wrapped_func] Took 0:00:00.903604 to load and process data.
# [INFO][2023-10-18 09:15:55,111][dance][fit] Deconvolution finished
# True
# True
# {'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'hcc_liver',
#  'epsilon': 1e-10,
#  'location_free': False,
#  'max_iter': 10}
# [INFO][2023-10-18 09:15:55,406][dance][_load_raw_data] Number of cell types: reference = 10, real = 14
# [INFO][2023-10-18 09:15:55,408][dance][_load_raw_data] Subsetting to common cell types (n=6):
# ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:55,498][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 977
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:15:55,499][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='mean'),
#   FilterGenesMatch(prefixes=['mt-'], suffixes=[]),
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   FilterGenesMarker(ct_profile_channel='CellTopicProfile', subset=True, threshold=1.25, eps=1e-06),
#   FilterGenesPercentile(min_val=1, max_val=99, mode='rv'),
#   SetConfig(config_dict={'feature_channel': [None, 'spatial'], 'feature_channel_type': ['X', 'obsm'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:15:55,521][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('mean' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# [INFO][2023-10-18 09:15:55,527][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 819 samples
# [INFO][2023-10-18 09:15:55,529][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 819
# [INFO][2023-10-18 09:15:55,530][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 99 samples
# [INFO][2023-10-18 09:15:55,531][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 99
# [INFO][2023-10-18 09:15:55,532][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 34 samples
# [INFO][2023-10-18 09:15:55,533][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 34
# [INFO][2023-10-18 09:15:55,534][dance.CellTopicProfile][get_ct_profile] Aggregating 'HSC' profiles over 119 samples
# [INFO][2023-10-18 09:15:55,536][dance.CellTopicProfile][get_ct_profile] Number of 'HSC' cells in batch 0: 119
# [INFO][2023-10-18 09:15:55,537][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,973 samples
# [INFO][2023-10-18 09:15:55,540][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,973
# [INFO][2023-10-18 09:15:55,542][dance.CellTopicProfile][get_ct_profile] Aggregating 'T_cell' profiles over 7,294 samples
# [INFO][2023-10-18 09:15:55,561][dance.CellTopicProfile][get_ct_profile] Number of 'T_cell' cells in batch 0: 7,294
# [INFO][2023-10-18 09:15:55,562][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:15:55,564][dance.FilterGenesMatch][__call__] 0 number of genes will be removed due to prefix 'mt-'
# [INFO][2023-10-18 09:15:55,565][dance.FilterGenesMatch][__call__] Removing 0 genes in total
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:55,648][dance.FilterGenesCommon][__call__] 956 genes found in 'ref'
# [INFO][2023-10-18 09:15:55,654][dance.FilterGenesCommon][__call__] 977 genes found in 'test'
# [INFO][2023-10-18 09:15:55,656][dance.FilterGenesCommon][__call__] Found 956 common genes out of 977 total genes.
# True
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:55,738][dance.FilterGenesMarker][get_marker_genes] Found 50 marker genes for cell type 'B_cell'
# [INFO][2023-10-18 09:15:55,740][dance.FilterGenesMarker][get_marker_genes] Found 149 marker genes for cell type 'Endothelial'
# [INFO][2023-10-18 09:15:55,741][dance.FilterGenesMarker][get_marker_genes] Found 98 marker genes for cell type 'Epithelial'
# [INFO][2023-10-18 09:15:55,743][dance.FilterGenesMarker][get_marker_genes] Found 170 marker genes for cell type 'HSC'
# [INFO][2023-10-18 09:15:55,744][dance.FilterGenesMarker][get_marker_genes] Found 50 marker genes for cell type 'NK_cell'
# [INFO][2023-10-18 09:15:55,745][dance.FilterGenesMarker][get_marker_genes] Found 48 marker genes for cell type 'T_cell'
# [INFO][2023-10-18 09:15:55,747][dance.FilterGenesMarker][get_marker_genes] Total number of marker genes found: 535
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:55,788][dance.FilterGenesPercentile][__call__] Filtering genes based on rv expression percentiles in layer None
# [INFO][2023-10-18 09:15:55,789][dance.FilterGenesPercentile][__call__] 12 genes removed
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:15:55,821][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, 'spatial'],
#  'feature_channel_type': ['X', 'obsm'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:15:55,822][dance][set_config_from_dict] Setting config 'feature_channel' to [None, 'spatial']
# [INFO][2023-10-18 09:15:55,823][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'obsm']
# [INFO][2023-10-18 09:15:55,823][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:15:55,824][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 523
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile', 'FilterGenesMarker'
# [INFO][2023-10-18 09:15:55,827][dance][wrapped_func] Took 0:00:00.712950 to load and process data.
# [INFO][2023-10-18 09:16:04,832][dance][fit] Deconvolution finished
# [INFO][2023-10-18 09:16:04,971][dance][_load_raw_data] Number of cell types: reference = 14, real = 15
# [INFO][2023-10-18 09:16:04,972][dance][_load_raw_data] Subsetting to common cell types (n=12):
# ['alpha-beta T cell',
#  'central venous liver sinusoidal endothelial cell',
#  'cholangiocyte',
#  'erythroid cell',
#  'gamma-delta T cell',
#  'hepatic stellate cell',
#  'hepatocyte',
#  'inflammatory macrophage',
#  'mature B cell',
#  'natural killer cell',
#  'periportal liver sinusoidal endothelial cell',
#  'portal liver sinusoidal endothelial cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:05,030][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 933
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:05,031][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='mean'),
#   FilterGenesMatch(prefixes=['mt-'], suffixes=[]),
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   FilterGenesMarker(ct_profile_channel='CellTopicProfile', subset=True, threshold=1.25, eps=1e-06),
#   FilterGenesPercentile(min_val=1, max_val=99, mode='rv'),
#   SetConfig(config_dict={'feature_channel': [None, 'spatial'], 'feature_channel_type': ['X', 'obsm'], 'label_channel': 'cell_type_portion'}),
# )
# True
# True
# {'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'normal_liver',
#  'epsilon': 1e-10,
#  'location_free': False,
#  'max_iter': 10}
# [INFO][2023-10-18 09:16:05,048][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('mean' aggregation) for ['alpha-beta T cell', 'central venous liver sinusoidal endothelial cell', 'cholangiocyte', 'erythroid cell', 'gamma-delta T cell', 'hepatic stellate cell', 'hepatocyte', 'inflammatory macrophage', 'mature B cell', 'natural killer cell', 'periportal liver sinusoidal endothelial cell', 'portal liver sinusoidal endothelial cell']
# [INFO][2023-10-18 09:16:05,052][dance.CellTopicProfile][get_ct_profile] Aggregating 'alpha-beta T cell' profiles over 961 samples
# [INFO][2023-10-18 09:16:05,054][dance.CellTopicProfile][get_ct_profile] Number of 'alpha-beta T cell' cells in batch 0: 961
# [INFO][2023-10-18 09:16:05,055][dance.CellTopicProfile][get_ct_profile] Aggregating 'central venous liver sinusoidal endothelial cell' profiles over 306 samples
# [INFO][2023-10-18 09:16:05,057][dance.CellTopicProfile][get_ct_profile] Number of 'central venous liver sinusoidal endothelial cell' cells in batch 0: 306
# [INFO][2023-10-18 09:16:05,058][dance.CellTopicProfile][get_ct_profile] Aggregating 'cholangiocyte' profiles over 119 samples
# [INFO][2023-10-18 09:16:05,059][dance.CellTopicProfile][get_ct_profile] Number of 'cholangiocyte' cells in batch 0: 119
# [INFO][2023-10-18 09:16:05,060][dance.CellTopicProfile][get_ct_profile] Aggregating 'erythroid cell' profiles over 93 samples
# [INFO][2023-10-18 09:16:05,061][dance.CellTopicProfile][get_ct_profile] Number of 'erythroid cell' cells in batch 0: 93
# [INFO][2023-10-18 09:16:05,062][dance.CellTopicProfile][get_ct_profile] Aggregating 'gamma-delta T cell' profiles over 569 samples
# [INFO][2023-10-18 09:16:05,065][dance.CellTopicProfile][get_ct_profile] Number of 'gamma-delta T cell' cells in batch 0: 569
# [INFO][2023-10-18 09:16:05,066][dance.CellTopicProfile][get_ct_profile] Aggregating 'hepatic stellate cell' profiles over 37 samples
# [INFO][2023-10-18 09:16:05,067][dance.CellTopicProfile][get_ct_profile] Number of 'hepatic stellate cell' cells in batch 0: 37
# [INFO][2023-10-18 09:16:05,068][dance.CellTopicProfile][get_ct_profile] Aggregating 'hepatocyte' profiles over 3,501 samples
# [INFO][2023-10-18 09:16:05,078][dance.CellTopicProfile][get_ct_profile] Number of 'hepatocyte' cells in batch 0: 3,501
# [INFO][2023-10-18 09:16:05,079][dance.CellTopicProfile][get_ct_profile] Aggregating 'inflammatory macrophage' profiles over 813 samples
# [INFO][2023-10-18 09:16:05,082][dance.CellTopicProfile][get_ct_profile] Number of 'inflammatory macrophage' cells in batch 0: 813
# [INFO][2023-10-18 09:16:05,082][dance.CellTopicProfile][get_ct_profile] Aggregating 'mature B cell' profiles over 129 samples
# [INFO][2023-10-18 09:16:05,084][dance.CellTopicProfile][get_ct_profile] Number of 'mature B cell' cells in batch 0: 129
# [INFO][2023-10-18 09:16:05,085][dance.CellTopicProfile][get_ct_profile] Aggregating 'natural killer cell' profiles over 488 samples
# [INFO][2023-10-18 09:16:05,086][dance.CellTopicProfile][get_ct_profile] Number of 'natural killer cell' cells in batch 0: 488
# [INFO][2023-10-18 09:16:05,087][dance.CellTopicProfile][get_ct_profile] Aggregating 'periportal liver sinusoidal endothelial cell' profiles over 327 samples
# [INFO][2023-10-18 09:16:05,089][dance.CellTopicProfile][get_ct_profile] Number of 'periportal liver sinusoidal endothelial cell' cells in batch 0: 327
# [INFO][2023-10-18 09:16:05,090][dance.CellTopicProfile][get_ct_profile] Aggregating 'portal liver sinusoidal endothelial cell' profiles over 211 samples
# [INFO][2023-10-18 09:16:05,091][dance.CellTopicProfile][get_ct_profile] Number of 'portal liver sinusoidal endothelial cell' cells in batch 0: 211
# [INFO][2023-10-18 09:16:05,092][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:16:05,094][dance.FilterGenesMatch][__call__] 0 number of genes will be removed due to prefix 'mt-'
# [INFO][2023-10-18 09:16:05,095][dance.FilterGenesMatch][__call__] Removing 0 genes in total
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:05,157][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:16:05,162][dance.FilterGenesCommon][__call__] 933 genes found in 'test'
# [INFO][2023-10-18 09:16:05,163][dance.FilterGenesCommon][__call__] Found 933 common genes out of 933 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:05,218][dance.FilterGenesMarker][get_marker_genes] Found 62 marker genes for cell type 'alpha-beta T cell'
# [INFO][2023-10-18 09:16:05,220][dance.FilterGenesMarker][get_marker_genes] Found 62 marker genes for cell type 'central venous liver sinusoidal endothelial cell'
# [INFO][2023-10-18 09:16:05,221][dance.FilterGenesMarker][get_marker_genes] Found 152 marker genes for cell type 'cholangiocyte'
# [INFO][2023-10-18 09:16:05,223][dance.FilterGenesMarker][get_marker_genes] Found 27 marker genes for cell type 'erythroid cell'
# [INFO][2023-10-18 09:16:05,224][dance.FilterGenesMarker][get_marker_genes] Found 63 marker genes for cell type 'gamma-delta T cell'
# [INFO][2023-10-18 09:16:05,225][dance.FilterGenesMarker][get_marker_genes] Found 165 marker genes for cell type 'hepatic stellate cell'
# [INFO][2023-10-18 09:16:05,226][dance.FilterGenesMarker][get_marker_genes] Found 71 marker genes for cell type 'hepatocyte'
# [INFO][2023-10-18 09:16:05,228][dance.FilterGenesMarker][get_marker_genes] Found 139 marker genes for cell type 'inflammatory macrophage'
# [INFO][2023-10-18 09:16:05,229][dance.FilterGenesMarker][get_marker_genes] Found 42 marker genes for cell type 'mature B cell'
# [INFO][2023-10-18 09:16:05,230][dance.FilterGenesMarker][get_marker_genes] Found 55 marker genes for cell type 'natural killer cell'
# [INFO][2023-10-18 09:16:05,232][dance.FilterGenesMarker][get_marker_genes] Found 95 marker genes for cell type 'periportal liver sinusoidal endothelial cell'
# [INFO][2023-10-18 09:16:05,233][dance.FilterGenesMarker][get_marker_genes] Found 104 marker genes for cell type 'portal liver sinusoidal endothelial cell'
# [INFO][2023-10-18 09:16:05,235][dance.FilterGenesMarker][get_marker_genes] Total number of marker genes found: 757
# True
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:05,282][dance.FilterGenesPercentile][__call__] Filtering genes based on rv expression percentiles in layer None
# [INFO][2023-10-18 09:16:05,284][dance.FilterGenesPercentile][__call__] 16 genes removed
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:05,311][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, 'spatial'],
#  'feature_channel_type': ['X', 'obsm'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:05,312][dance][set_config_from_dict] Setting config 'feature_channel' to [None, 'spatial']
# [INFO][2023-10-18 09:16:05,313][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'obsm']
# [INFO][2023-10-18 09:16:05,314][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:05,315][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 741
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile', 'FilterGenesMarker'
# [INFO][2023-10-18 09:16:05,316][dance][wrapped_func] Took 0:00:00.474898 to load and process data.
# ...
# [INFO][2023-10-18 09:16:27,438][dance.CellTopicProfile][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:16:27,440][dance.CellTopicProfile][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:16:27,442][dance.CellTopicProfile][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:16:27,444][dance.CellTopicProfile][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:16:27,446][dance.CellTopicProfile][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:16:27,450][dance.CellTopicProfile][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:16:27,452][dance.CellTopicProfile][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:16:27,454][dance.CellTopicProfile][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:16:27,455][dance.CellTopicProfile][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:16:27,456][dance.CellTopicProfile][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:16:27,458][dance.CellTopicProfile][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:16:27,459][dance.CellTopicProfile][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:16:27,461][dance.CellTopicProfile][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:16:27,462][dance.CellTopicProfile][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:16:27,463][dance.CellTopicProfile][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:16:27,464][dance.CellTopicProfile][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:16:27,466][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:16:27,467][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:16:27,468][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:16:27,470][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:16:27,471][dance.CellTopicProfile][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:16:27,473][dance.CellTopicProfile][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:16:27,475][dance.CellTopicProfile][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:16:27,476][dance.CellTopicProfile][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:16:27,478][dance.CellTopicProfile][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:16:27,479][dance.CellTopicProfile][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:16:27,480][dance.CellTopicProfile][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:16:27,482][dance.CellTopicProfile][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:16:27,483][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:16:27,484][dance.CellTopicProfile][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:16:27,486][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:16:27,489][dance.CellTopicProfile][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:16:27,490][dance.CellTopicProfile][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:16:27,491][dance.CellTopicProfile][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:16:27,493][dance.CellTopicProfile][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:16:27,494][dance.CellTopicProfile][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:16:27,496][dance.CellTopicProfile][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:16:27,497][dance.CellTopicProfile][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:16:27,498][dance.CellTopicProfile][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:16:27,500][dance.CellTopicProfile][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:16:27,501][dance.CellTopicProfile][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:16:27,502][dance.CellTopicProfile][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:16:27,504][dance.CellTopicProfile][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:16:27,505][dance.CellTopicProfile][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:16:27,507][dance.CellTopicProfile][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# [INFO][2023-10-18 09:16:27,561][dance.CellTopicProfile][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:16:27,563][dance.CellTopicProfile][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:16:27,565][dance.CellTopicProfile][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:16:27,567][dance.CellTopicProfile][get_ct_profile] Aggregating 'Transitional urothelium' profiles over 45 samples
# [INFO][2023-10-18 09:16:27,568][dance.CellTopicProfile][get_ct_profile] Number of 'Transitional urothelium' cells in batch 0: 45
# [INFO][2023-10-18 09:16:27,569][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:16:27,570][dance.CellTopicProfile][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:16:27,572][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:16:27,573][dance.CellTopicProfile][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:16:27,575][dance.CellTopicProfile][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:16:27,576][dance.CellTopicProfile][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:16:27,577][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:16:27,579][dance.FilterGenesMatch][__call__] 0 number of genes will be removed due to prefix 'mt-'
# [INFO][2023-10-18 09:16:27,579][dance.FilterGenesMatch][__call__] Removing 0 genes in total
# True
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:27,881][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:16:27,883][dance.FilterGenesCommon][__call__] 952 genes found in 'test'
# [INFO][2023-10-18 09:16:27,884][dance.FilterGenesCommon][__call__] Found 933 common genes out of 952 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:28,147][dance.FilterGenesMarker][get_marker_genes] Found 115 marker genes for cell type 'Ascending vasa recta endothelium'
# [INFO][2023-10-18 09:16:28,148][dance.FilterGenesMarker][get_marker_genes] Found 56 marker genes for cell type 'B cell'
# [INFO][2023-10-18 09:16:28,150][dance.FilterGenesMarker][get_marker_genes] Found 70 marker genes for cell type 'CD4 T cell'
# [INFO][2023-10-18 09:16:28,151][dance.FilterGenesMarker][get_marker_genes] Found 89 marker genes for cell type 'CD8 T cell'
# [INFO][2023-10-18 09:16:28,152][dance.FilterGenesMarker][get_marker_genes] Found 36 marker genes for cell type 'Connecting tubule'
# [INFO][2023-10-18 09:16:28,154][dance.FilterGenesMarker][get_marker_genes] Found 78 marker genes for cell type 'Descending vasa recta endothelium'
# [INFO][2023-10-18 09:16:28,156][dance.FilterGenesMarker][get_marker_genes] Found 80 marker genes for cell type 'Distinct proximal tubule 1'
# [INFO][2023-10-18 09:16:28,157][dance.FilterGenesMarker][get_marker_genes] Found 37 marker genes for cell type 'Distinct proximal tubule 2'
# [INFO][2023-10-18 09:16:28,158][dance.FilterGenesMarker][get_marker_genes] Found 68 marker genes for cell type 'Epithelial progenitor cell'
# [INFO][2023-10-18 09:16:28,160][dance.FilterGenesMarker][get_marker_genes] Found 124 marker genes for cell type 'Fibroblast'
# [INFO][2023-10-18 09:16:28,161][dance.FilterGenesMarker][get_marker_genes] Found 87 marker genes for cell type 'Glomerular endothelium'
# [INFO][2023-10-18 09:16:28,162][dance.FilterGenesMarker][get_marker_genes] Found 16 marker genes for cell type 'Indistinct intercalated cell'
# [INFO][2023-10-18 09:16:28,163][dance.FilterGenesMarker][get_marker_genes] Found 119 marker genes for cell type 'MNP-a/classical monocyte derived'
# [INFO][2023-10-18 09:16:28,165][dance.FilterGenesMarker][get_marker_genes] Found 100 marker genes for cell type 'MNP-b/non-classical monocyte derived'
# [INFO][2023-10-18 09:16:28,166][dance.FilterGenesMarker][get_marker_genes] Found 51 marker genes for cell type 'Mast cell'
# [INFO][2023-10-18 09:16:28,167][dance.FilterGenesMarker][get_marker_genes] Found 106 marker genes for cell type 'NK cell'
# [INFO][2023-10-18 09:16:28,168][dance.FilterGenesMarker][get_marker_genes] Found 102 marker genes for cell type 'Pelvic epithelium'
# [INFO][2023-10-18 09:16:28,169][dance.FilterGenesMarker][get_marker_genes] Found 92 marker genes for cell type 'Peritubular capillary endothelium 1'
# [INFO][2023-10-18 09:16:28,171][dance.FilterGenesMarker][get_marker_genes] Found 94 marker genes for cell type 'Peritubular capillary endothelium 2'
# [INFO][2023-10-18 09:16:28,172][dance.FilterGenesMarker][get_marker_genes] Found 74 marker genes for cell type 'Podocyte'
# [INFO][2023-10-18 09:16:28,173][dance.FilterGenesMarker][get_marker_genes] Found 40 marker genes for cell type 'Principal cell'
# [INFO][2023-10-18 09:16:28,174][dance.FilterGenesMarker][get_marker_genes] Found 32 marker genes for cell type 'Proliferating Proximal Tubule'
# [INFO][2023-10-18 09:16:28,176][dance.FilterGenesMarker][get_marker_genes] Found 35 marker genes for cell type 'Proximal tubule'
# [INFO][2023-10-18 09:16:28,177][dance.FilterGenesMarker][get_marker_genes] Found 17 marker genes for cell type 'Thick ascending limb of Loop of Henle'
# [INFO][2023-10-18 09:16:28,178][dance.FilterGenesMarker][get_marker_genes] Found 51 marker genes for cell type 'Transitional urothelium'
# [INFO][2023-10-18 09:16:28,179][dance.FilterGenesMarker][get_marker_genes] Found 18 marker genes for cell type 'Type A intercalated cell'
# [INFO][2023-10-18 09:16:28,180][dance.FilterGenesMarker][get_marker_genes] Found 18 marker genes for cell type 'Type B intercalated cell'
# [INFO][2023-10-18 09:16:28,182][dance.FilterGenesMarker][get_marker_genes] Found 112 marker genes for cell type 'dendritic cell'
# [INFO][2023-10-18 09:16:28,183][dance.FilterGenesMarker][get_marker_genes] Total number of marker genes found: 801
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:28,431][dance.FilterGenesPercentile][__call__] Filtering genes based on rv expression percentiles in layer None
# [INFO][2023-10-18 09:16:28,433][dance.FilterGenesPercentile][__call__] 16 genes removed
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:28,609][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': [None, 'spatial'],
#  'feature_channel_type': ['X', 'obsm'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:28,610][dance][set_config_from_dict] Setting config 'feature_channel' to [None, 'spatial']
# [INFO][2023-10-18 09:16:28,611][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['X', 'obsm']
# [INFO][2023-10-18 09:16:28,612][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:28,612][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39562 × 785
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile', 'FilterGenesMarker'
# [INFO][2023-10-18 09:16:28,614][dance][wrapped_func] Took 0:00:01.748231 to load and process data.
# [INFO][2023-10-18 09:16:28,715][dance][fit] Deconvolution finished
# True
# True
# 'To reproduce CARD benchmarks, please refer to command lines belows:\n\nCARD synthetic $ python card.py --dataset CARD_synthetic\n\nGSE174746 $ python card.py --dataset GSE174746 --location_free\n\nSPOTLight synthetic $ python card.py --dataset SPOTLight_synthetic --location_free\n\n'

# %%
card_scores
# Out:
# [0.010272752447378514,
#  0.009862226044343612,
#  0.03963365760350732,
#  0.04203772165249851,
#  0.07915342912237518,
#  0.0025627811712195204,
#  0.0026267280082778836,
#  0.004993524984865446,
#  0.007193671054587352,
#  0.009280539696023327,
#  0.004437053861375017,
#  0.0035000743026642857,
#  0.007056872704951607,
#  0.00508543313727727,
#  0.005383125487452269]

# %%
import argparse
from pprint import pprint

import numpy as np
import torch

from dance.datasets.spatial import CellTypeDeconvoDataset
from dance.modules.spatial.cell_type_deconvo import DSTG
from dance.utils import set_seed

parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
parser.add_argument("--dataset", default="CARD_synthetic", choices=CellTypeDeconvoDataset.AVAILABLE_DATA)
parser.add_argument("--datadir", default="../../../../data/spatial", help="Directory to save the data.")
parser.add_argument("--sc_ref", type=bool, default=True, help="Reference scRNA (True) or cell-mixtures (False).")
parser.add_argument("--num_pseudo", type=int, default=500, help="Number of pseudo mixtures to generate.")
parser.add_argument("--n_hvg", type=int, default=2000, help="Number of HVGs.")
parser.add_argument("--lr", type=float, default=1e-2, help="Learning rate.")
parser.add_argument("--wd", type=float, default=1e-4, help="Weight decay.")
parser.add_argument("--k_filter", type=int, default=200, help="Graph node filter.")
parser.add_argument("--num_cc", type=int, default=30, help="Dimension of canonical correlation analysis.")
parser.add_argument("--bias", type=bool, default=False, help="Include/Exclude bias term.")
parser.add_argument("--nhid", type=int, default=16, help="Number of neurons in latent layer.")
parser.add_argument("--dropout", type=float, default=0., help="Dropout rate.")
parser.add_argument("--epochs", type=int, default=25, help="Number of epochs to train the model.")
parser.add_argument("--seed", type=int, default=17, help="Random seed.")
parser.add_argument("--device", default="auto", help="Computation device.")
DSTG_scores=[]
for dataset in datasets:
    try:
        args = parser.parse_args(["--dataset",dataset,"--nhid","16","--lr", ".001","--k_filter","50"])
        set_seed(args.seed)
        pprint(vars(args))

        # Load dataset
        preprocessing_pipeline = DSTG.preprocessing_pipeline(
            n_pseudo=args.num_pseudo,
            n_top_genes=args.n_hvg,
            k_filter=args.k_filter,
            num_cc=args.num_cc,
        )
        dataset = CellTypeDeconvoDataset(data_dir=args.datadir, data_id=args.dataset)
        data = dataset.load_data(transform=preprocessing_pipeline, cache=args.cache)

        (adj, x), y = data.get_data(return_type="default")
        x, y = torch.FloatTensor(x), torch.FloatTensor(y.values)
        adj = torch.sparse.FloatTensor(torch.LongTensor([adj.row.tolist(), adj.col.tolist()]),
                                    torch.FloatTensor(adj.data.astype(np.int32)))
        train_mask = data.get_split_mask("pseudo", return_type="torch")
        inputs = (adj, x, train_mask)

        # Train and evaluate model
        model = DSTG(nhid=args.nhid, bias=args.bias, dropout=args.dropout, device=args.device)
        pred = model.fit_predict(inputs, y, lr=args.lr, max_epochs=args.epochs, weight_decay=args.wd)
        test_mask = data.get_split_mask("test", return_type="torch")
        score = model.default_score_func(y[test_mask], pred[test_mask])
    except Exception as e:
        score=e
    finally:
        DSTG_scores.append(score)
        """To reproduce DSTG benchmarks, please refer to command lines belows:

        CARD synthetic $ python dstg.py --dataset CARD_synthetic --nhid 16 --lr .001 --k_filter
        50

        GSE174746 $ python dstg.py --dataset GSE174746 --nhid 16 --lr .0001 --k_filter 50

        SPOTLight synthetic $ python dstg.py --dataset SPOTLight_synthetic --nhid 32 --lr .1
        --epochs 25

        """
# Out:
# [INFO][2023-10-18 09:16:28,759][dance][set_seed] Setting global random seed to 17
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung6',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# [INFO][2023-10-18 09:16:29,025][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:16:29,026][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:29,149][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:29,150][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:29,193][dance.FilterGenesCommon][__call__] 923 genes found in 'ref'
# [INFO][2023-10-18 09:16:29,195][dance.FilterGenesCommon][__call__] 923 genes found in 'test'
# [INFO][2023-10-18 09:16:29,196][dance.FilterGenesCommon][__call__] Found 923 common genes out of 923 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:29,347][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:29,350][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:29,351][dance][pop] Updating split index for 'test'. 600 -> 600
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# [INFO][2023-10-18 09:16:29,391][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:29,394][dance.ScaleFeature][__call__] Scaling split:test (n=600)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:30,766][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:30,767][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:30,768][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:30,768][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:30,769][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1100 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:30,771][dance][wrapped_func] Took 0:00:02.010076 to load and process data.
# [INFO][2023-10-18 09:16:32,858][dance][fit] Epoch: 0005, train_loss=2.39790, time=0.00075
# [INFO][2023-10-18 09:16:32,869][dance][fit] Epoch: 0010, train_loss=2.39790, time=0.00076
# [INFO][2023-10-18 09:16:32,881][dance][fit] Epoch: 0015, train_loss=2.39790, time=0.00073
# [INFO][2023-10-18 09:16:32,892][dance][fit] Epoch: 0020, train_loss=2.39790, time=0.00071
# [INFO][2023-10-18 09:16:32,904][dance][fit] Epoch: 0025, train_loss=2.39790, time=0.00078
# [INFO][2023-10-18 09:16:32,911][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_1',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# [INFO][2023-10-18 09:16:33,205][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:16:33,206][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:33,333][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:33,334][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:33,378][dance.FilterGenesCommon][__call__] 923 genes found in 'ref'
# [INFO][2023-10-18 09:16:33,380][dance.FilterGenesCommon][__call__] 923 genes found in 'test'
# [INFO][2023-10-18 09:16:33,381][dance.FilterGenesCommon][__call__] Found 923 common genes out of 923 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:33,548][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:33,550][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:33,552][dance][pop] Updating split index for 'test'. 400 -> 400
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# [INFO][2023-10-18 09:16:33,590][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:33,593][dance.ScaleFeature][__call__] Scaling split:test (n=400)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:35,077][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:35,078][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:35,079][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:35,080][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:35,081][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 900 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:35,083][dance][wrapped_func] Took 0:00:02.169950 to load and process data.
# [INFO][2023-10-18 09:16:35,101][dance][fit] Epoch: 0005, train_loss=2.39790, time=0.00099
# [INFO][2023-10-18 09:16:35,114][dance][fit] Epoch: 0010, train_loss=2.39790, time=0.00097
# [INFO][2023-10-18 09:16:35,129][dance][fit] Epoch: 0015, train_loss=2.39790, time=0.00099
# [INFO][2023-10-18 09:16:35,142][dance][fit] Epoch: 0020, train_loss=2.39790, time=0.00097
# [INFO][2023-10-18 09:16:35,156][dance][fit] Epoch: 0025, train_loss=2.39790, time=0.00097
# [INFO][2023-10-18 09:16:35,161][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_2',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# [INFO][2023-10-18 09:16:35,447][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:16:35,449][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:35,576][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:35,577][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:35,620][dance.FilterGenesCommon][__call__] 923 genes found in 'ref'
# [INFO][2023-10-18 09:16:35,622][dance.FilterGenesCommon][__call__] 923 genes found in 'test'
# [INFO][2023-10-18 09:16:35,623][dance.FilterGenesCommon][__call__] Found 923 common genes out of 923 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:35,801][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:35,803][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:35,805][dance][pop] Updating split index for 'test'. 900 -> 900
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:16:35,849][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:35,852][dance.ScaleFeature][__call__] Scaling split:test (n=900)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:37,300][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:37,301][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:37,302][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:37,303][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:37,303][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 1400 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:37,305][dance][wrapped_func] Took 0:00:02.142962 to load and process data.
# [INFO][2023-10-18 09:16:37,321][dance][fit] Epoch: 0005, train_loss=2.39790, time=0.00085
# [INFO][2023-10-18 09:16:37,333][dance][fit] Epoch: 0010, train_loss=2.39790, time=0.00083
# [INFO][2023-10-18 09:16:37,344][dance][fit] Epoch: 0015, train_loss=2.39790, time=0.00081
# [INFO][2023-10-18 09:16:37,359][dance][fit] Epoch: 0020, train_loss=2.39790, time=0.00081
# [INFO][2023-10-18 09:16:37,372][dance][fit] Epoch: 0025, train_loss=2.39790, time=0.00083
# [INFO][2023-10-18 09:16:37,376][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'hcc_liver',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# [INFO][2023-10-18 09:16:37,627][dance][_load_raw_data] Number of cell types: reference = 10, real = 14
# [INFO][2023-10-18 09:16:37,629][dance][_load_raw_data] Subsetting to common cell types (n=6):
# ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:37,719][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 977
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:37,720][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:37,751][dance.FilterGenesCommon][__call__] 956 genes found in 'ref'
# [INFO][2023-10-18 09:16:37,757][dance.FilterGenesCommon][__call__] 977 genes found in 'test'
# [INFO][2023-10-18 09:16:37,758][dance.FilterGenesCommon][__call__] Found 956 common genes out of 977 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:37,916][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:37,918][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:37,920][dance][pop] Updating split index for 'test'. 3,447 -> 3,447
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:16:38,007][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:38,010][dance.ScaleFeature][__call__] Scaling split:test (n=3,447)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:40,631][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:40,632][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:40,633][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:40,633][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:40,634][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 3947 × 956
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:40,635][dance][wrapped_func] Took 0:00:03.258525 to load and process data.
# [INFO][2023-10-18 09:16:40,654][dance][fit] Epoch: 0005, train_loss=1.79176, time=0.00085
# [INFO][2023-10-18 09:16:40,666][dance][fit] Epoch: 0010, train_loss=1.79176, time=0.00083
# [INFO][2023-10-18 09:16:40,678][dance][fit] Epoch: 0015, train_loss=1.79176, time=0.00084
# [INFO][2023-10-18 09:16:40,691][dance][fit] Epoch: 0020, train_loss=1.79176, time=0.00085
# [INFO][2023-10-18 09:16:40,704][dance][fit] Epoch: 0025, train_loss=1.79176, time=0.00083
# [INFO][2023-10-18 09:16:40,709][dance][set_seed] Setting global random seed to 17
# [INFO][2023-10-18 09:16:40,799][dance][_load_raw_data] Number of cell types: reference = 14, real = 15
# [INFO][2023-10-18 09:16:40,800][dance][_load_raw_data] Subsetting to common cell types (n=12):
# ['alpha-beta T cell',
#  'central venous liver sinusoidal endothelial cell',
#  'cholangiocyte',
#  'erythroid cell',
#  'gamma-delta T cell',
#  'hepatic stellate cell',
#  'hepatocyte',
#  'inflammatory macrophage',
#  'mature B cell',
#  'natural killer cell',
#  'periportal liver sinusoidal endothelial cell',
#  'portal liver sinusoidal endothelial cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:40,861][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 933
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:40,862][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:40,878][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:16:40,888][dance.FilterGenesCommon][__call__] 933 genes found in 'test'
# [INFO][2023-10-18 09:16:40,889][dance.FilterGenesCommon][__call__] Found 933 common genes out of 933 total genes.
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'normal_liver',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:41,001][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:41,003][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:41,004][dance][pop] Updating split index for 'test'. 2,709 -> 2,709
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:16:41,074][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:41,077][dance.ScaleFeature][__call__] Scaling split:test (n=2,709)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:43,324][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:43,325][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:43,326][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:43,327][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:43,328][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 3209 × 933
#     obs: 'cellType', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:43,329][dance][wrapped_func] Took 0:00:02.618573 to load and process data.
# [INFO][2023-10-18 09:16:43,346][dance][fit] Epoch: 0005, train_loss=2.48491, time=0.00088
# [INFO][2023-10-18 09:16:43,358][dance][fit] Epoch: 0010, train_loss=2.48491, time=0.00089
# [INFO][2023-10-18 09:16:43,369][dance][fit] Epoch: 0015, train_loss=2.48491, time=0.00086
# [INFO][2023-10-18 09:16:43,381][dance][fit] Epoch: 0020, train_loss=2.48491, time=0.00088
# [INFO][2023-10-18 09:16:43,393][dance][fit] Epoch: 0025, train_loss=2.48491, time=0.00087
# [INFO][2023-10-18 09:16:43,398][dance][set_seed] Setting global random seed to 17
# [INFO][2023-10-18 09:16:43,591][dance][_load_raw_data] Number of cell types: reference = 31, real = 33
# [INFO][2023-10-18 09:16:43,592][dance][_load_raw_data] Subsetting to common cell types (n=28):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_1139',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:43,834][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39763 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:43,835][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:43,944][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:16:43,947][dance.FilterGenesCommon][__call__] 952 genes found in 'test'
# [INFO][2023-10-18 09:16:43,948][dance.FilterGenesCommon][__call__] Found 933 common genes out of 952 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:44,376][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:44,380][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:44,384][dance][pop] Updating split index for 'test'. 360 -> 360
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:16:44,419][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:44,422][dance.ScaleFeature][__call__] Scaling split:test (n=360)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:45,723][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:45,724][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:45,725][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:45,726][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:45,727][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 860 × 933
#     obs: 'cellType', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:45,729][dance][wrapped_func] Took 0:00:02.330085 to load and process data.
# [INFO][2023-10-18 09:16:45,744][dance][fit] Epoch: 0005, train_loss=3.33220, time=0.00083
# [INFO][2023-10-18 09:16:45,755][dance][fit] Epoch: 0010, train_loss=3.33220, time=0.00082
# [INFO][2023-10-18 09:16:45,766][dance][fit] Epoch: 0015, train_loss=3.33220, time=0.00082
# [INFO][2023-10-18 09:16:45,778][dance][fit] Epoch: 0020, train_loss=3.33220, time=0.00080
# [INFO][2023-10-18 09:16:45,790][dance][fit] Epoch: 0025, train_loss=3.33220, time=0.00086
# [INFO][2023-10-18 09:16:45,794][dance][set_seed] Setting global random seed to 17
# [INFO][2023-10-18 09:16:45,984][dance][_load_raw_data] Number of cell types: reference = 31, real = 35
# [INFO][2023-10-18 09:16:45,984][dance][_load_raw_data] Subsetting to common cell types (n=29):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_10838',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:46,223][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39668 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:16:46,223][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:16:46,325][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:16:46,327][dance.FilterGenesCommon][__call__] 952 genes found in 'test'
# [INFO][2023-10-18 09:16:46,328][dance.FilterGenesCommon][__call__] Found 933 common genes out of 952 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:16:46,729][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:16:46,733][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:16:46,738][dance][pop] Updating split index for 'test'. 220 -> 220
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:16:46,774][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:16:46,777][dance.ScaleFeature][__call__] Scaling split:test (n=220)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:16:47,961][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:16:47,962][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:16:47,963][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:16:47,964][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:16:47,965][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 720 × 933
#     obs: 'cellType', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:16:47,967][dance][wrapped_func] Took 0:00:02.171712 to load and process data.
# [INFO][2023-10-18 09:16:47,981][dance][fit] Epoch: 0005, train_loss=3.36730, time=0.00081
# [INFO][2023-10-18 09:16:47,993][dance][fit] Epoch: 0010, train_loss=3.36730, time=0.00083
# ...
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:02,637][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:17:02,638][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:17:02,639][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:02,640][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 660 × 933
#     obs: 'cellType', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:17:02,642][dance][wrapped_func] Took 0:00:02.198242 to load and process data.
# [INFO][2023-10-18 09:17:02,658][dance][fit] Epoch: 0005, train_loss=3.36730, time=0.00096
# [INFO][2023-10-18 09:17:02,670][dance][fit] Epoch: 0010, train_loss=3.36730, time=0.00095
# [INFO][2023-10-18 09:17:02,682][dance][fit] Epoch: 0015, train_loss=3.36730, time=0.00096
# [INFO][2023-10-18 09:17:02,694][dance][fit] Epoch: 0020, train_loss=3.36730, time=0.00096
# [INFO][2023-10-18 09:17:02,706][dance][fit] Epoch: 0025, train_loss=3.36730, time=0.00094
# [INFO][2023-10-18 09:17:02,711][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_1098',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# [INFO][2023-10-18 09:17:02,938][dance][_load_raw_data] Number of cell types: reference = 31, real = 35
# [INFO][2023-10-18 09:17:02,939][dance][_load_raw_data] Subsetting to common cell types (n=29):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:03,230][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39788 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:03,231][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:03,343][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:17:03,345][dance.FilterGenesCommon][__call__] 952 genes found in 'test'
# [INFO][2023-10-18 09:17:03,347][dance.FilterGenesCommon][__call__] Found 933 common genes out of 952 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:03,829][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:17:03,835][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:17:03,840][dance][pop] Updating split index for 'test'. 340 -> 340
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:17:03,889][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:17:03,892][dance.ScaleFeature][__call__] Scaling split:test (n=340)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:17:05,722][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:05,723][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:17:05,724][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:17:05,725][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:05,726][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 840 × 933
#     obs: 'cellType', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:17:05,730][dance][wrapped_func] Took 0:00:03.017567 to load and process data.
# [INFO][2023-10-18 09:17:05,748][dance][fit] Epoch: 0005, train_loss=3.36730, time=0.00093
# [INFO][2023-10-18 09:17:05,766][dance][fit] Epoch: 0010, train_loss=3.36730, time=0.00092
# [INFO][2023-10-18 09:17:05,783][dance][fit] Epoch: 0015, train_loss=3.36730, time=0.00093
# [INFO][2023-10-18 09:17:05,800][dance][fit] Epoch: 0020, train_loss=3.36730, time=0.00094
# [INFO][2023-10-18 09:17:05,819][dance][fit] Epoch: 0025, train_loss=3.36730, time=0.00093
# [INFO][2023-10-18 09:17:05,825][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': False,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_8471',
#  'device': 'auto',
#  'dropout': 0.0,
#  'epochs': 25,
#  'k_filter': 50,
#  'lr': 0.001,
#  'n_hvg': 2000,
#  'nhid': 16,
#  'num_cc': 30,
#  'num_pseudo': 500,
#  'sc_ref': True,
#  'seed': 17,
#  'wd': 0.0001}
# [INFO][2023-10-18 09:17:06,054][dance][_load_raw_data] Number of cell types: reference = 31, real = 34
# [INFO][2023-10-18 09:17:06,055][dance][_load_raw_data] Subsetting to common cell types (n=28):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:06,335][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39562 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:06,336][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   FilterGenesCommon(batch_key=None, split_keys=['ref', 'test']),
#   PseudoMixture(n_pseudo=500, nc_min=2, nc_max=10, ct_select='auto'),
#   RemoveSplit(split_name='ref'),
#   AnnDataTransform(func=scanpy.preprocessing._normalization.normalize_total, func_kwargs={'target_sum': 10000.0}),
#   AnnDataTransform(func=scanpy.preprocessing._simple.log1p, func_kwargs={}),
#   AnnDataTransform(func=scanpy.preprocessing._highly_variable_genes.highly_variable_genes, func_kwargs={'flavor': 'seurat', 'n_top_genes': 2000, 'batch_key': 'batch', 'subset': True}),
#   ScaleFeature(axis=0, mode='standardize', eps=-1, split_names='ALL', batch_key=None),
#   DSTGraph(k_filter=50, num_cc=30, ref_split='pseudo', inf_split='test'),
#   SetConfig(config_dict={'feature_channel': ['DSTGraph', None], 'feature_channel_type': ['obsp', 'X'], 'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:06,447][dance.FilterGenesCommon][__call__] 933 genes found in 'ref'
# [INFO][2023-10-18 09:17:06,449][dance.FilterGenesCommon][__call__] 952 genes found in 'test'
# [INFO][2023-10-18 09:17:06,450][dance.FilterGenesCommon][__call__] Found 933 common genes out of 952 total genes.
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:06,861][dance.RemoveSplit][__call__] Popping split: {self.split_name!r}
# [INFO][2023-10-18 09:17:06,865][dance][pop] Updating split index for 'pseudo'. 500 -> 500
# [INFO][2023-10-18 09:17:06,869][dance][pop] Updating split index for 'test'. 160 -> 160
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# [INFO][2023-10-18 09:17:06,904][dance.ScaleFeature][__call__] Scaling split:pseudo (n=500)
# [INFO][2023-10-18 09:17:06,907][dance.ScaleFeature][__call__] Scaling split:test (n=160)
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:266: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(
# [INFO][2023-10-18 09:17:08,068][dance.SetConfig][__call__] Updating the dance data object config options:
# {'feature_channel': ['DSTGraph', None],
#  'feature_channel_type': ['obsp', 'X'],
#  'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:08,069][dance][set_config_from_dict] Setting config 'feature_channel' to ['DSTGraph', None]
# [INFO][2023-10-18 09:17:08,070][dance][set_config_from_dict] Setting config 'feature_channel_type' to ['obsp', 'X']
# [INFO][2023-10-18 09:17:08,072][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:08,072][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 660 × 933
#     obs: 'cellType', 'batch', 'cell_count', 'total_umi_count'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dance_config', 'log1p', 'hvg'
#     obsm: 'cell_type_portion', 'spatial'
#     obsp: 'DSTGraph'
# [INFO][2023-10-18 09:17:08,075][dance][wrapped_func] Took 0:00:02.248430 to load and process data.
# [INFO][2023-10-18 09:17:08,088][dance][fit] Epoch: 0005, train_loss=3.33220, time=0.00080
# [INFO][2023-10-18 09:17:08,101][dance][fit] Epoch: 0010, train_loss=3.33220, time=0.00080
# [INFO][2023-10-18 09:17:08,113][dance][fit] Epoch: 0015, train_loss=3.33220, time=0.00080
# [INFO][2023-10-18 09:17:08,126][dance][fit] Epoch: 0020, train_loss=3.33220, time=0.00079
# [INFO][2023-10-18 09:17:08,139][dance][fit] Epoch: 0025, train_loss=3.33220, time=0.00079
# True
# True

# %%
DSTG_scores
# Out:
# [0.00932844,
#  0.008754343,
#  0.008421534,
#  0.023887137,
#  0.046285834,
#  0.0049878345,
#  0.0030663814,
#  0.003820763,
#  0.004870248,
#  0.0055336705,
#  0.0040534544,
#  0.004075728,
#  0.004991771,
#  0.0042319656,
#  0.0041610063]

# %%
import argparse
from pprint import pprint

from dance.datasets.spatial import CellTypeDeconvoDataset
from dance.modules.spatial.cell_type_deconvo.spatialdecon import SpatialDecon
from dance.utils import set_seed

parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
parser.add_argument("--dataset", default="CARD_synthetic", choices=CellTypeDeconvoDataset.AVAILABLE_DATA)
parser.add_argument("--datadir", default="../../../../data/spatial", help="Directory to save the data.")
parser.add_argument("--lr", type=float, default=1e-4, help="Learning rate.")
parser.add_argument("--bias", type=bool, default=False, help="Include/Exclude bias term.")
parser.add_argument("--max_iter", type=int, default=10000, help="Maximum optimization iteration.")
parser.add_argument("--seed", type=int, default=17, help="Random seed.")
parser.add_argument("--device", default="auto", help="Computation device.")

SpatialDecon_scores=[]
for dataset in datasets:
    try:
        args = parser.parse_args(["--dataset",dataset, "--lr", ".01","--max_iter","2250","--bias","1"])
        set_seed(args.seed)
        pprint(vars(args))

        # Load dataset
        preprocessing_pipeline = SpatialDecon.preprocessing_pipeline()
        dataset = CellTypeDeconvoDataset(data_dir=args.datadir, data_id=args.dataset)
        data = dataset.load_data(transform=preprocessing_pipeline, cache=args.cache)
        cell_types = data.data.obsm["cell_type_portion"].columns.tolist()

        x, y = data.get_data(split_name="test", return_type="torch")
        ct_profile = data.get_feature(return_type="torch", channel="CellTopicProfile", channel_type="varm")

        # Train and evaluate model
        spaDecon = SpatialDecon(ct_profile, ct_select=cell_types, bias=args.bias, device=args.device)
        score = spaDecon.fit_score(x, y, lr=args.lr, max_iter=args.max_iter, print_period=100)
    except Exception as e:
        score=e
    finally:
        SpatialDecon_scores.append(score)
"""To reproduce SpatialDecon benchmarks, please refer to command lines belows:

CARD synthetic $ python spatialdecon.py --dataset CARD_synthetic --lr .01 --max_iter
2250 --bias 1

GSE174746 $ python spatialdecon.py --dataset GSE174746 --lr .0001 --max_iter 20000
--bias 1

SPOTLight synthetic $ python spatialdecon.py --dataset SPOTLight_synthetic --lr .01
--max_iter 500 --bias 1

"""
# Out:
# [INFO][2023-10-18 09:17:08,178][dance][set_seed] Setting global random seed to 17
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung6',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:08,418][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:17:08,419][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:08,539][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:08,539][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:08,573][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:17:08,583][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:17:08,599][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:17:08,600][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:17:08,610][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:17:08,611][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:17:08,656][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:17:08,658][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:17:08,661][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:17:08,662][dance.CellTopicProfile][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:17:08,707][dance.CellTopicProfile][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:17:08,708][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:17:08,714][dance.CellTopicProfile][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:17:08,716][dance.CellTopicProfile][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:17:08,730][dance.CellTopicProfile][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:17:08,731][dance.CellTopicProfile][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:17:08,744][dance.CellTopicProfile][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:17:08,745][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:17:08,760][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:17:08,761][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:17:08,763][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:17:08,764][dance.CellTopicProfile][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:17:08,772][dance.CellTopicProfile][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:17:08,772][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:08,774][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:08,774][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:08,775][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:08,776][dance][wrapped_func] Took 0:00:00.597408 to load and process data.
# True
# [INFO][2023-10-18 09:17:08,871][dance][fit] Epoch: 100/2250 Loss: 4.49833e+00
# [INFO][2023-10-18 09:17:08,965][dance][fit] Epoch: 200/2250 Loss: 3.57504e+00
# [INFO][2023-10-18 09:17:09,065][dance][fit] Epoch: 300/2250 Loss: 3.07046e+00
# [INFO][2023-10-18 09:17:09,168][dance][fit] Epoch: 400/2250 Loss: 2.73843e+00
# [INFO][2023-10-18 09:17:09,275][dance][fit] Epoch: 500/2250 Loss: 2.49880e+00
# [INFO][2023-10-18 09:17:09,390][dance][fit] Epoch: 600/2250 Loss: 2.31574e+00
# [INFO][2023-10-18 09:17:09,499][dance][fit] Epoch: 700/2250 Loss: 2.17017e+00
# [INFO][2023-10-18 09:17:09,611][dance][fit] Epoch: 800/2250 Loss: 2.05105e+00
# [INFO][2023-10-18 09:17:09,721][dance][fit] Epoch: 900/2250 Loss: 1.95139e+00
# [INFO][2023-10-18 09:17:09,832][dance][fit] Epoch: 1000/2250 Loss: 1.86654e+00
# [INFO][2023-10-18 09:17:09,944][dance][fit] Epoch: 1100/2250 Loss: 1.79329e+00
# [INFO][2023-10-18 09:17:10,055][dance][fit] Epoch: 1200/2250 Loss: 1.72929e+00
# [INFO][2023-10-18 09:17:10,164][dance][fit] Epoch: 1300/2250 Loss: 1.67283e+00
# [INFO][2023-10-18 09:17:10,273][dance][fit] Epoch: 1400/2250 Loss: 1.62263e+00
# [INFO][2023-10-18 09:17:10,384][dance][fit] Epoch: 1500/2250 Loss: 1.57769e+00
# [INFO][2023-10-18 09:17:10,493][dance][fit] Epoch: 1600/2250 Loss: 1.53721e+00
# [INFO][2023-10-18 09:17:10,602][dance][fit] Epoch: 1700/2250 Loss: 1.50057e+00
# [INFO][2023-10-18 09:17:10,713][dance][fit] Epoch: 1800/2250 Loss: 1.46725e+00
# [INFO][2023-10-18 09:17:10,820][dance][fit] Epoch: 1900/2250 Loss: 1.43682e+00
# [INFO][2023-10-18 09:17:10,951][dance][fit] Epoch: 2000/2250 Loss: 1.40893e+00
# [INFO][2023-10-18 09:17:11,112][dance][fit] Epoch: 2100/2250 Loss: 1.38330e+00
# [INFO][2023-10-18 09:17:11,265][dance][fit] Epoch: 2200/2250 Loss: 1.35969e+00
# [INFO][2023-10-18 09:17:11,354][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_1',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:11,644][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:17:11,645][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:11,797][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:11,798][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:11,843][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:17:11,852][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:17:11,872][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:17:11,874][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:17:11,886][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:17:11,888][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:17:11,955][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:17:11,957][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:17:11,961][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:17:11,963][dance.CellTopicProfile][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:17:12,029][dance.CellTopicProfile][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:17:12,031][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:17:12,040][dance.CellTopicProfile][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:17:12,041][dance.CellTopicProfile][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# True
# [INFO][2023-10-18 09:17:12,060][dance.CellTopicProfile][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:17:12,061][dance.CellTopicProfile][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:17:12,078][dance.CellTopicProfile][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:17:12,080][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:17:12,097][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:17:12,100][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:17:12,102][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:17:12,103][dance.CellTopicProfile][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:17:12,113][dance.CellTopicProfile][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:17:12,114][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:12,116][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:12,117][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:12,118][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:12,119][dance][wrapped_func] Took 0:00:00.763295 to load and process data.
# [INFO][2023-10-18 09:17:12,240][dance][fit] Epoch: 100/2250 Loss: 6.21083e+00
# [INFO][2023-10-18 09:17:12,371][dance][fit] Epoch: 200/2250 Loss: 4.93778e+00
# [INFO][2023-10-18 09:17:12,500][dance][fit] Epoch: 300/2250 Loss: 4.21374e+00
# [INFO][2023-10-18 09:17:12,651][dance][fit] Epoch: 400/2250 Loss: 3.72220e+00
# [INFO][2023-10-18 09:17:12,789][dance][fit] Epoch: 500/2250 Loss: 3.35793e+00
# [INFO][2023-10-18 09:17:12,952][dance][fit] Epoch: 600/2250 Loss: 3.07305e+00
# [INFO][2023-10-18 09:17:13,094][dance][fit] Epoch: 700/2250 Loss: 2.84194e+00
# [INFO][2023-10-18 09:17:13,234][dance][fit] Epoch: 800/2250 Loss: 2.64931e+00
# [INFO][2023-10-18 09:17:13,399][dance][fit] Epoch: 900/2250 Loss: 2.48543e+00
# [INFO][2023-10-18 09:17:13,557][dance][fit] Epoch: 1000/2250 Loss: 2.34380e+00
# [INFO][2023-10-18 09:17:13,701][dance][fit] Epoch: 1100/2250 Loss: 2.21983e+00
# [INFO][2023-10-18 09:17:13,863][dance][fit] Epoch: 1200/2250 Loss: 2.11013e+00
# [INFO][2023-10-18 09:17:14,021][dance][fit] Epoch: 1300/2250 Loss: 2.01215e+00
# [INFO][2023-10-18 09:17:14,166][dance][fit] Epoch: 1400/2250 Loss: 1.92397e+00
# [INFO][2023-10-18 09:17:14,302][dance][fit] Epoch: 1500/2250 Loss: 1.84408e+00
# [INFO][2023-10-18 09:17:14,445][dance][fit] Epoch: 1600/2250 Loss: 1.77129e+00
# [INFO][2023-10-18 09:17:14,575][dance][fit] Epoch: 1700/2250 Loss: 1.70463e+00
# [INFO][2023-10-18 09:17:14,714][dance][fit] Epoch: 1800/2250 Loss: 1.64329e+00
# [INFO][2023-10-18 09:17:14,861][dance][fit] Epoch: 1900/2250 Loss: 1.58664e+00
# [INFO][2023-10-18 09:17:15,036][dance][fit] Epoch: 2000/2250 Loss: 1.53413e+00
# [INFO][2023-10-18 09:17:15,184][dance][fit] Epoch: 2100/2250 Loss: 1.48529e+00
# [INFO][2023-10-18 09:17:15,342][dance][fit] Epoch: 2200/2250 Loss: 1.43975e+00
# [INFO][2023-10-18 09:17:15,410][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_2',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:15,715][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:17:15,717][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:15,870][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:15,871][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:15,917][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:17:15,926][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:17:15,945][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:17:15,947][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:17:15,959][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:17:15,961][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:17:16,027][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:17:16,029][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:17:16,033][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:17:16,035][dance.CellTopicProfile][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:17:16,101][dance.CellTopicProfile][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:17:16,103][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:17:16,111][dance.CellTopicProfile][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:17:16,113][dance.CellTopicProfile][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# True
# [INFO][2023-10-18 09:17:16,133][dance.CellTopicProfile][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:17:16,136][dance.CellTopicProfile][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:17:16,155][dance.CellTopicProfile][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:17:16,157][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:17:16,174][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:17:16,176][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:17:16,179][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:17:16,181][dance.CellTopicProfile][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:17:16,191][dance.CellTopicProfile][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:17:16,192][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:16,194][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:16,195][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:16,195][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:16,198][dance][wrapped_func] Took 0:00:00.786532 to load and process data.
# [INFO][2023-10-18 09:17:16,324][dance][fit] Epoch: 100/2250 Loss: 3.81765e+00
# [INFO][2023-10-18 09:17:16,485][dance][fit] Epoch: 200/2250 Loss: 2.93679e+00
# [INFO][2023-10-18 09:17:16,654][dance][fit] Epoch: 300/2250 Loss: 2.45014e+00
# [INFO][2023-10-18 09:17:16,806][dance][fit] Epoch: 400/2250 Loss: 2.12722e+00
# [INFO][2023-10-18 09:17:16,986][dance][fit] Epoch: 500/2250 Loss: 1.89264e+00
# [INFO][2023-10-18 09:17:17,166][dance][fit] Epoch: 600/2250 Loss: 1.71254e+00
# [INFO][2023-10-18 09:17:17,313][dance][fit] Epoch: 700/2250 Loss: 1.56894e+00
# [INFO][2023-10-18 09:17:17,491][dance][fit] Epoch: 800/2250 Loss: 1.45124e+00
# [INFO][2023-10-18 09:17:17,663][dance][fit] Epoch: 900/2250 Loss: 1.35271e+00
# [INFO][2023-10-18 09:17:17,819][dance][fit] Epoch: 1000/2250 Loss: 1.26886e+00
# [INFO][2023-10-18 09:17:17,997][dance][fit] Epoch: 1100/2250 Loss: 1.19654e+00
# [INFO][2023-10-18 09:17:18,159][dance][fit] Epoch: 1200/2250 Loss: 1.13349e+00
# [INFO][2023-10-18 09:17:18,325][dance][fit] Epoch: 1300/2250 Loss: 1.07803e+00
# [INFO][2023-10-18 09:17:18,498][dance][fit] Epoch: 1400/2250 Loss: 1.02887e+00
# [INFO][2023-10-18 09:17:18,671][dance][fit] Epoch: 1500/2250 Loss: 9.85028e-01
# [INFO][2023-10-18 09:17:18,812][dance][fit] Epoch: 1600/2250 Loss: 9.45712e-01
# [INFO][2023-10-18 09:17:18,985][dance][fit] Epoch: 1700/2250 Loss: 9.10286e-01
# [INFO][2023-10-18 09:17:19,171][dance][fit] Epoch: 1800/2250 Loss: 8.78232e-01
# [INFO][2023-10-18 09:17:19,340][dance][fit] Epoch: 1900/2250 Loss: 8.49129e-01
# [INFO][2023-10-18 09:17:19,520][dance][fit] Epoch: 2000/2250 Loss: 8.22622e-01
# [INFO][2023-10-18 09:17:19,691][dance][fit] Epoch: 2100/2250 Loss: 7.98419e-01
# [INFO][2023-10-18 09:17:19,842][dance][fit] Epoch: 2200/2250 Loss: 7.76272e-01
# [INFO][2023-10-18 09:17:19,936][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'hcc_liver',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:20,227][dance][_load_raw_data] Number of cell types: reference = 10, real = 14
# [INFO][2023-10-18 09:17:20,228][dance][_load_raw_data] Subsetting to common cell types (n=6):
# ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:20,316][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 977
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:20,318][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:20,339][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# [INFO][2023-10-18 09:17:20,345][dance.CellTopicProfile][get_ct_profile] Aggregating 'B_cell' profiles over 819 samples
# [INFO][2023-10-18 09:17:20,353][dance.CellTopicProfile][get_ct_profile] Number of 'B_cell' cells in batch 0: 819
# [INFO][2023-10-18 09:17:20,354][dance.CellTopicProfile][get_ct_profile] Aggregating 'Endothelial' profiles over 99 samples
# [INFO][2023-10-18 09:17:20,356][dance.CellTopicProfile][get_ct_profile] Number of 'Endothelial' cells in batch 0: 99
# [INFO][2023-10-18 09:17:20,357][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial' profiles over 34 samples
# [INFO][2023-10-18 09:17:20,359][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial' cells in batch 0: 34
# [INFO][2023-10-18 09:17:20,359][dance.CellTopicProfile][get_ct_profile] Aggregating 'HSC' profiles over 119 samples
# [INFO][2023-10-18 09:17:20,362][dance.CellTopicProfile][get_ct_profile] Number of 'HSC' cells in batch 0: 119
# [INFO][2023-10-18 09:17:20,363][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK_cell' profiles over 1,973 samples
# [INFO][2023-10-18 09:17:20,382][dance.CellTopicProfile][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,973
# [INFO][2023-10-18 09:17:20,384][dance.CellTopicProfile][get_ct_profile] Aggregating 'T_cell' profiles over 7,294 samples
# [INFO][2023-10-18 09:17:20,492][dance.CellTopicProfile][get_ct_profile] Number of 'T_cell' cells in batch 0: 7,294
# [INFO][2023-10-18 09:17:20,494][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:20,495][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:20,496][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:20,497][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 977
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:20,498][dance][wrapped_func] Took 0:00:00.561056 to load and process data.
# True
# [INFO][2023-10-18 09:17:20,597][dance][fit] Epoch: 100/2250 Loss: 6.85403e+00
# [INFO][2023-10-18 09:17:20,691][dance][fit] Epoch: 200/2250 Loss: 5.48648e+00
# [INFO][2023-10-18 09:17:20,790][dance][fit] Epoch: 300/2250 Loss: 4.71783e+00
# [INFO][2023-10-18 09:17:20,891][dance][fit] Epoch: 400/2250 Loss: 4.19782e+00
# [INFO][2023-10-18 09:17:21,004][dance][fit] Epoch: 500/2250 Loss: 3.81337e+00
# [INFO][2023-10-18 09:17:21,114][dance][fit] Epoch: 600/2250 Loss: 3.51343e+00
# [INFO][2023-10-18 09:17:21,220][dance][fit] Epoch: 700/2250 Loss: 3.27070e+00
# [INFO][2023-10-18 09:17:21,328][dance][fit] Epoch: 800/2250 Loss: 3.06897e+00
# [INFO][2023-10-18 09:17:21,433][dance][fit] Epoch: 900/2250 Loss: 2.89789e+00
# [INFO][2023-10-18 09:17:21,539][dance][fit] Epoch: 1000/2250 Loss: 2.75047e+00
# [INFO][2023-10-18 09:17:21,644][dance][fit] Epoch: 1100/2250 Loss: 2.62178e+00
# [INFO][2023-10-18 09:17:21,750][dance][fit] Epoch: 1200/2250 Loss: 2.50825e+00
# [INFO][2023-10-18 09:17:21,856][dance][fit] Epoch: 1300/2250 Loss: 2.40718e+00
# [INFO][2023-10-18 09:17:21,962][dance][fit] Epoch: 1400/2250 Loss: 2.31653e+00
# [INFO][2023-10-18 09:17:22,068][dance][fit] Epoch: 1500/2250 Loss: 2.23469e+00
# [INFO][2023-10-18 09:17:22,174][dance][fit] Epoch: 1600/2250 Loss: 2.16038e+00
# [INFO][2023-10-18 09:17:22,281][dance][fit] Epoch: 1700/2250 Loss: 2.09257e+00
# [INFO][2023-10-18 09:17:22,393][dance][fit] Epoch: 1800/2250 Loss: 2.03043e+00
# [INFO][2023-10-18 09:17:22,507][dance][fit] Epoch: 1900/2250 Loss: 1.97324e+00
# [INFO][2023-10-18 09:17:22,615][dance][fit] Epoch: 2000/2250 Loss: 1.92045e+00
# [INFO][2023-10-18 09:17:22,721][dance][fit] Epoch: 2100/2250 Loss: 1.87155e+00
# [INFO][2023-10-18 09:17:22,830][dance][fit] Epoch: 2200/2250 Loss: 1.82613e+00
# [INFO][2023-10-18 09:17:22,888][dance][set_seed] Setting global random seed to 17
# [INFO][2023-10-18 09:17:23,004][dance][_load_raw_data] Number of cell types: reference = 14, real = 15
# [INFO][2023-10-18 09:17:23,005][dance][_load_raw_data] Subsetting to common cell types (n=12):
# ['alpha-beta T cell',
#  'central venous liver sinusoidal endothelial cell',
#  'cholangiocyte',
#  'erythroid cell',
#  'gamma-delta T cell',
#  'hepatic stellate cell',
#  'hepatocyte',
#  'inflammatory macrophage',
#  'mature B cell',
#  'natural killer cell',
#  'periportal liver sinusoidal endothelial cell',
#  'portal liver sinusoidal endothelial cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:23,078][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 933
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:23,079][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'normal_liver',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:23,093][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['alpha-beta T cell', 'central venous liver sinusoidal endothelial cell', 'cholangiocyte', 'erythroid cell', 'gamma-delta T cell', 'hepatic stellate cell', 'hepatocyte', 'inflammatory macrophage', 'mature B cell', 'natural killer cell', 'periportal liver sinusoidal endothelial cell', 'portal liver sinusoidal endothelial cell']
# [INFO][2023-10-18 09:17:23,099][dance.CellTopicProfile][get_ct_profile] Aggregating 'alpha-beta T cell' profiles over 961 samples
# [INFO][2023-10-18 09:17:23,107][dance.CellTopicProfile][get_ct_profile] Number of 'alpha-beta T cell' cells in batch 0: 961
# [INFO][2023-10-18 09:17:23,108][dance.CellTopicProfile][get_ct_profile] Aggregating 'central venous liver sinusoidal endothelial cell' profiles over 306 samples
# [INFO][2023-10-18 09:17:23,112][dance.CellTopicProfile][get_ct_profile] Number of 'central venous liver sinusoidal endothelial cell' cells in batch 0: 306
# [INFO][2023-10-18 09:17:23,113][dance.CellTopicProfile][get_ct_profile] Aggregating 'cholangiocyte' profiles over 119 samples
# [INFO][2023-10-18 09:17:23,115][dance.CellTopicProfile][get_ct_profile] Number of 'cholangiocyte' cells in batch 0: 119
# [INFO][2023-10-18 09:17:23,116][dance.CellTopicProfile][get_ct_profile] Aggregating 'erythroid cell' profiles over 93 samples
# [INFO][2023-10-18 09:17:23,118][dance.CellTopicProfile][get_ct_profile] Number of 'erythroid cell' cells in batch 0: 93
# [INFO][2023-10-18 09:17:23,119][dance.CellTopicProfile][get_ct_profile] Aggregating 'gamma-delta T cell' profiles over 569 samples
# [INFO][2023-10-18 09:17:23,124][dance.CellTopicProfile][get_ct_profile] Number of 'gamma-delta T cell' cells in batch 0: 569
# [INFO][2023-10-18 09:17:23,125][dance.CellTopicProfile][get_ct_profile] Aggregating 'hepatic stellate cell' profiles over 37 samples
# [INFO][2023-10-18 09:17:23,126][dance.CellTopicProfile][get_ct_profile] Number of 'hepatic stellate cell' cells in batch 0: 37
# [INFO][2023-10-18 09:17:23,128][dance.CellTopicProfile][get_ct_profile] Aggregating 'hepatocyte' profiles over 3,501 samples
# [INFO][2023-10-18 09:17:23,157][dance.CellTopicProfile][get_ct_profile] Number of 'hepatocyte' cells in batch 0: 3,501
# [INFO][2023-10-18 09:17:23,158][dance.CellTopicProfile][get_ct_profile] Aggregating 'inflammatory macrophage' profiles over 813 samples
# [INFO][2023-10-18 09:17:23,166][dance.CellTopicProfile][get_ct_profile] Number of 'inflammatory macrophage' cells in batch 0: 813
# [INFO][2023-10-18 09:17:23,167][dance.CellTopicProfile][get_ct_profile] Aggregating 'mature B cell' profiles over 129 samples
# [INFO][2023-10-18 09:17:23,169][dance.CellTopicProfile][get_ct_profile] Number of 'mature B cell' cells in batch 0: 129
# [INFO][2023-10-18 09:17:23,170][dance.CellTopicProfile][get_ct_profile] Aggregating 'natural killer cell' profiles over 488 samples
# [INFO][2023-10-18 09:17:23,175][dance.CellTopicProfile][get_ct_profile] Number of 'natural killer cell' cells in batch 0: 488
# [INFO][2023-10-18 09:17:23,176][dance.CellTopicProfile][get_ct_profile] Aggregating 'periportal liver sinusoidal endothelial cell' profiles over 327 samples
# [INFO][2023-10-18 09:17:23,180][dance.CellTopicProfile][get_ct_profile] Number of 'periportal liver sinusoidal endothelial cell' cells in batch 0: 327
# [INFO][2023-10-18 09:17:23,181][dance.CellTopicProfile][get_ct_profile] Aggregating 'portal liver sinusoidal endothelial cell' profiles over 211 samples
# [INFO][2023-10-18 09:17:23,183][dance.CellTopicProfile][get_ct_profile] Number of 'portal liver sinusoidal endothelial cell' cells in batch 0: 211
# [INFO][2023-10-18 09:17:23,184][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:23,185][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:23,186][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:23,187][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 933
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:23,188][dance][wrapped_func] Took 0:00:00.298014 to load and process data.
# [INFO][2023-10-18 09:17:23,288][dance][fit] Epoch: 100/2250 Loss: 3.76374e+00
# True
# [INFO][2023-10-18 09:17:23,389][dance][fit] Epoch: 200/2250 Loss: 2.85876e+00
# [INFO][2023-10-18 09:17:23,492][dance][fit] Epoch: 300/2250 Loss: 2.36984e+00
# [INFO][2023-10-18 09:17:23,598][dance][fit] Epoch: 400/2250 Loss: 2.05215e+00
# [INFO][2023-10-18 09:17:23,703][dance][fit] Epoch: 500/2250 Loss: 1.82592e+00
# [INFO][2023-10-18 09:17:23,814][dance][fit] Epoch: 600/2250 Loss: 1.65545e+00
# [INFO][2023-10-18 09:17:23,920][dance][fit] Epoch: 700/2250 Loss: 1.52199e+00
# [INFO][2023-10-18 09:17:24,027][dance][fit] Epoch: 800/2250 Loss: 1.41450e+00
# [INFO][2023-10-18 09:17:24,133][dance][fit] Epoch: 900/2250 Loss: 1.32607e+00
# [INFO][2023-10-18 09:17:24,243][dance][fit] Epoch: 1000/2250 Loss: 1.25207e+00
# [INFO][2023-10-18 09:17:24,351][dance][fit] Epoch: 1100/2250 Loss: 1.18928e+00
# [INFO][2023-10-18 09:17:24,463][dance][fit] Epoch: 1200/2250 Loss: 1.13541e+00
# [INFO][2023-10-18 09:17:24,575][dance][fit] Epoch: 1300/2250 Loss: 1.08874e+00
# [INFO][2023-10-18 09:17:24,684][dance][fit] Epoch: 1400/2250 Loss: 1.04798e+00
# [INFO][2023-10-18 09:17:24,795][dance][fit] Epoch: 1500/2250 Loss: 1.01213e+00
# [INFO][2023-10-18 09:17:24,904][dance][fit] Epoch: 1600/2250 Loss: 9.80412e-01
# [INFO][2023-10-18 09:17:25,020][dance][fit] Epoch: 1700/2250 Loss: 9.52190e-01
# [INFO][2023-10-18 09:17:25,135][dance][fit] Epoch: 1800/2250 Loss: 9.26974e-01
# [INFO][2023-10-18 09:17:25,256][dance][fit] Epoch: 1900/2250 Loss: 9.04338e-01
# [INFO][2023-10-18 09:17:25,385][dance][fit] Epoch: 2000/2250 Loss: 8.83956e-01
# [INFO][2023-10-18 09:17:25,514][dance][fit] Epoch: 2100/2250 Loss: 8.65532e-01
# [INFO][2023-10-18 09:17:25,667][dance][fit] Epoch: 2200/2250 Loss: 8.48843e-01
# [INFO][2023-10-18 09:17:25,743][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_1139',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:25,979][dance][_load_raw_data] Number of cell types: reference = 31, real = 33
# [INFO][2023-10-18 09:17:25,980][dance][_load_raw_data] Subsetting to common cell types (n=28):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:26,219][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39763 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:26,220][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:17:26,304][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['Ascending vasa recta endothelium', 'B cell', 'CD4 T cell', 'CD8 T cell', 'Connecting tubule', 'Descending vasa recta endothelium', 'Distinct proximal tubule 1', 'Distinct proximal tubule 2', 'Epithelial progenitor cell', 'Fibroblast', 'Glomerular endothelium', 'Indistinct intercalated cell', 'MNP-a/classical monocyte derived', 'MNP-b/non-classical monocyte derived', 'Mast cell', 'NK cell', 'Neutrophil', 'Pelvic epithelium', 'Peritubular capillary endothelium 1', 'Peritubular capillary endothelium 2', 'Podocyte', 'Principal cell', 'Proliferating Proximal Tubule', 'Proximal tubule', 'Thick ascending limb of Loop of Henle', 'Type A intercalated cell', 'Type B intercalated cell', 'dendritic cell']
# [INFO][2023-10-18 09:17:26,322][dance.CellTopicProfile][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:17:26,325][dance.CellTopicProfile][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:17:26,327][dance.CellTopicProfile][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:17:26,334][dance.CellTopicProfile][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:17:26,335][dance.CellTopicProfile][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:17:26,358][dance.CellTopicProfile][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:17:26,360][dance.CellTopicProfile][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:17:26,368][dance.CellTopicProfile][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:17:26,370][dance.CellTopicProfile][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:17:26,371][dance.CellTopicProfile][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:17:26,373][dance.CellTopicProfile][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:17:26,375][dance.CellTopicProfile][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:17:26,376][dance.CellTopicProfile][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:17:26,378][dance.CellTopicProfile][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:17:26,379][dance.CellTopicProfile][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:17:26,381][dance.CellTopicProfile][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:17:26,383][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:17:26,385][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:17:26,387][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:17:26,389][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:17:26,390][dance.CellTopicProfile][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:17:26,395][dance.CellTopicProfile][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:17:26,396][dance.CellTopicProfile][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:17:26,399][dance.CellTopicProfile][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:17:26,401][dance.CellTopicProfile][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:17:26,405][dance.CellTopicProfile][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:17:26,406][dance.CellTopicProfile][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:17:26,410][dance.CellTopicProfile][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:17:26,411][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:17:26,412][dance.CellTopicProfile][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:17:26,414][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:17:26,425][dance.CellTopicProfile][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:17:26,426][dance.CellTopicProfile][get_ct_profile] Aggregating 'Neutrophil' profiles over 46 samples
# [INFO][2023-10-18 09:17:26,428][dance.CellTopicProfile][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 46
# [INFO][2023-10-18 09:17:26,429][dance.CellTopicProfile][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:17:26,431][dance.CellTopicProfile][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:17:26,433][dance.CellTopicProfile][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:17:26,438][dance.CellTopicProfile][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:17:26,440][dance.CellTopicProfile][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:17:26,442][dance.CellTopicProfile][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:17:26,443][dance.CellTopicProfile][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:17:26,445][dance.CellTopicProfile][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:17:26,446][dance.CellTopicProfile][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:17:26,448][dance.CellTopicProfile][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:17:26,450][dance.CellTopicProfile][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:17:26,453][dance.CellTopicProfile][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:17:26,454][dance.CellTopicProfile][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# True
# [INFO][2023-10-18 09:17:26,733][dance.CellTopicProfile][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:17:26,735][dance.CellTopicProfile][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:17:26,739][dance.CellTopicProfile][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:17:26,741][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:17:26,743][dance.CellTopicProfile][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:17:26,745][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:17:26,747][dance.CellTopicProfile][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:17:26,748][dance.CellTopicProfile][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:17:26,751][dance.CellTopicProfile][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:17:26,751][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:26,753][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:26,754][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:26,755][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39763 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:26,756][dance][wrapped_func] Took 0:00:01.011894 to load and process data.
# [INFO][2023-10-18 09:17:26,846][dance][fit] Epoch: 100/2250 Loss: 6.39790e+00
# [INFO][2023-10-18 09:17:26,943][dance][fit] Epoch: 200/2250 Loss: 5.05127e+00
# [INFO][2023-10-18 09:17:27,044][dance][fit] Epoch: 300/2250 Loss: 4.27727e+00
# [INFO][2023-10-18 09:17:27,147][dance][fit] Epoch: 400/2250 Loss: 3.74985e+00
# [INFO][2023-10-18 09:17:27,251][dance][fit] Epoch: 500/2250 Loss: 3.35838e+00
# [INFO][2023-10-18 09:17:27,358][dance][fit] Epoch: 600/2250 Loss: 3.05209e+00
# [INFO][2023-10-18 09:17:27,463][dance][fit] Epoch: 700/2250 Loss: 2.80365e+00
# [INFO][2023-10-18 09:17:27,566][dance][fit] Epoch: 800/2250 Loss: 2.59677e+00
# [INFO][2023-10-18 09:17:27,669][dance][fit] Epoch: 900/2250 Loss: 2.42100e+00
# [INFO][2023-10-18 09:17:27,772][dance][fit] Epoch: 1000/2250 Loss: 2.26927e+00
# [INFO][2023-10-18 09:17:27,875][dance][fit] Epoch: 1100/2250 Loss: 2.13660e+00
# [INFO][2023-10-18 09:17:27,979][dance][fit] Epoch: 1200/2250 Loss: 2.01935e+00
# [INFO][2023-10-18 09:17:28,082][dance][fit] Epoch: 1300/2250 Loss: 1.91481e+00
# [INFO][2023-10-18 09:17:28,186][dance][fit] Epoch: 1400/2250 Loss: 1.82088e+00
# [INFO][2023-10-18 09:17:28,289][dance][fit] Epoch: 1500/2250 Loss: 1.73593e+00
# [INFO][2023-10-18 09:17:28,392][dance][fit] Epoch: 1600/2250 Loss: 1.65867e+00
# [INFO][2023-10-18 09:17:28,495][dance][fit] Epoch: 1700/2250 Loss: 1.58804e+00
# [INFO][2023-10-18 09:17:28,598][dance][fit] Epoch: 1800/2250 Loss: 1.52320e+00
# [INFO][2023-10-18 09:17:28,702][dance][fit] Epoch: 1900/2250 Loss: 1.46343e+00
# [INFO][2023-10-18 09:17:28,805][dance][fit] Epoch: 2000/2250 Loss: 1.40815e+00
# [INFO][2023-10-18 09:17:28,909][dance][fit] Epoch: 2100/2250 Loss: 1.35686e+00
# [INFO][2023-10-18 09:17:29,012][dance][fit] Epoch: 2200/2250 Loss: 1.30914e+00
# [INFO][2023-10-18 09:17:29,067][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_10838',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:17:29,310][dance][_load_raw_data] Number of cell types: reference = 31, real = 35
# [INFO][2023-10-18 09:17:29,311][dance][_load_raw_data] Subsetting to common cell types (n=29):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:17:29,553][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39668 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:17:29,554][dance.Compose][__call__] Applying composed transformations:
# Compose(
# ...
# [INFO][2023-10-18 09:17:59,399][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:17:59,401][dance.CellTopicProfile][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:17:59,404][dance.CellTopicProfile][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:17:59,407][dance.CellTopicProfile][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:17:59,408][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:17:59,410][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:17:59,411][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:17:59,412][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39788 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:17:59,415][dance][wrapped_func] Took 0:00:01.186522 to load and process data.
# [INFO][2023-10-18 09:17:59,523][dance][fit] Epoch: 100/2250 Loss: 3.57579e+00
# [INFO][2023-10-18 09:17:59,630][dance][fit] Epoch: 200/2250 Loss: 2.78711e+00
# [INFO][2023-10-18 09:17:59,746][dance][fit] Epoch: 300/2250 Loss: 2.34606e+00
# [INFO][2023-10-18 09:17:59,863][dance][fit] Epoch: 400/2250 Loss: 2.05115e+00
# [INFO][2023-10-18 09:17:59,996][dance][fit] Epoch: 500/2250 Loss: 1.83548e+00
# [INFO][2023-10-18 09:18:00,121][dance][fit] Epoch: 600/2250 Loss: 1.66879e+00
# [INFO][2023-10-18 09:18:00,255][dance][fit] Epoch: 700/2250 Loss: 1.53497e+00
# [INFO][2023-10-18 09:18:00,379][dance][fit] Epoch: 800/2250 Loss: 1.42452e+00
# [INFO][2023-10-18 09:18:00,543][dance][fit] Epoch: 900/2250 Loss: 1.33140e+00
# [INFO][2023-10-18 09:18:00,677][dance][fit] Epoch: 1000/2250 Loss: 1.25158e+00
# [INFO][2023-10-18 09:18:00,814][dance][fit] Epoch: 1100/2250 Loss: 1.18222e+00
# [INFO][2023-10-18 09:18:00,977][dance][fit] Epoch: 1200/2250 Loss: 1.12126e+00
# [INFO][2023-10-18 09:18:01,136][dance][fit] Epoch: 1300/2250 Loss: 1.06718e+00
# [INFO][2023-10-18 09:18:01,264][dance][fit] Epoch: 1400/2250 Loss: 1.01881e+00
# [INFO][2023-10-18 09:18:01,412][dance][fit] Epoch: 1500/2250 Loss: 9.75234e-01
# [INFO][2023-10-18 09:18:01,584][dance][fit] Epoch: 1600/2250 Loss: 9.35748e-01
# [INFO][2023-10-18 09:18:01,725][dance][fit] Epoch: 1700/2250 Loss: 8.99773e-01
# [INFO][2023-10-18 09:18:01,865][dance][fit] Epoch: 1800/2250 Loss: 8.66841e-01
# [INFO][2023-10-18 09:18:02,033][dance][fit] Epoch: 1900/2250 Loss: 8.36571e-01
# [INFO][2023-10-18 09:18:02,182][dance][fit] Epoch: 2000/2250 Loss: 8.08640e-01
# [INFO][2023-10-18 09:18:02,323][dance][fit] Epoch: 2100/2250 Loss: 7.82779e-01
# [INFO][2023-10-18 09:18:02,487][dance][fit] Epoch: 2200/2250 Loss: 7.58761e-01
# [INFO][2023-10-18 09:18:02,583][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_8471',
#  'device': 'auto',
#  'lr': 0.01,
#  'max_iter': 2250,
#  'seed': 17}
# [INFO][2023-10-18 09:18:02,808][dance][_load_raw_data] Number of cell types: reference = 31, real = 34
# [INFO][2023-10-18 09:18:02,809][dance][_load_raw_data] Subsetting to common cell types (n=28):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:03,092][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39562 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:03,094][dance.Compose][__call__] Applying composed transformations:
# Compose(
#   CellTopicProfile(ct_select='auto', ct_key='cellType', split_name='ref', method='median'),
#   SetConfig(config_dict={'label_channel': 'cell_type_portion'}),
# )
# [INFO][2023-10-18 09:18:03,202][dance.CellTopicProfile][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['Ascending vasa recta endothelium', 'B cell', 'CD4 T cell', 'CD8 T cell', 'Connecting tubule', 'Descending vasa recta endothelium', 'Distinct proximal tubule 1', 'Distinct proximal tubule 2', 'Epithelial progenitor cell', 'Fibroblast', 'Glomerular endothelium', 'Indistinct intercalated cell', 'MNP-a/classical monocyte derived', 'MNP-b/non-classical monocyte derived', 'Mast cell', 'NK cell', 'Pelvic epithelium', 'Peritubular capillary endothelium 1', 'Peritubular capillary endothelium 2', 'Podocyte', 'Principal cell', 'Proliferating Proximal Tubule', 'Proximal tubule', 'Thick ascending limb of Loop of Henle', 'Transitional urothelium', 'Type A intercalated cell', 'Type B intercalated cell', 'dendritic cell']
# [INFO][2023-10-18 09:18:03,227][dance.CellTopicProfile][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:18:03,232][dance.CellTopicProfile][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:18:03,234][dance.CellTopicProfile][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:18:03,243][dance.CellTopicProfile][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:18:03,246][dance.CellTopicProfile][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:18:03,268][dance.CellTopicProfile][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:18:03,270][dance.CellTopicProfile][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:18:03,279][dance.CellTopicProfile][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:18:03,282][dance.CellTopicProfile][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:18:03,284][dance.CellTopicProfile][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:18:03,286][dance.CellTopicProfile][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:18:03,289][dance.CellTopicProfile][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:18:03,291][dance.CellTopicProfile][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:18:03,292][dance.CellTopicProfile][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:18:03,294][dance.CellTopicProfile][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:18:03,296][dance.CellTopicProfile][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:18:03,298][dance.CellTopicProfile][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:18:03,301][dance.CellTopicProfile][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:18:03,303][dance.CellTopicProfile][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:18:03,305][dance.CellTopicProfile][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:18:03,307][dance.CellTopicProfile][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:18:03,313][dance.CellTopicProfile][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:18:03,315][dance.CellTopicProfile][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:18:03,318][dance.CellTopicProfile][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:18:03,320][dance.CellTopicProfile][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:18:03,325][dance.CellTopicProfile][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:18:03,327][dance.CellTopicProfile][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:18:03,331][dance.CellTopicProfile][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:18:03,333][dance.CellTopicProfile][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:18:03,334][dance.CellTopicProfile][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:18:03,336][dance.CellTopicProfile][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:18:03,349][dance.CellTopicProfile][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:18:03,351][dance.CellTopicProfile][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:18:03,354][dance.CellTopicProfile][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:18:03,356][dance.CellTopicProfile][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:18:03,362][dance.CellTopicProfile][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:18:03,365][dance.CellTopicProfile][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:18:03,367][dance.CellTopicProfile][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:18:03,369][dance.CellTopicProfile][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:18:03,371][dance.CellTopicProfile][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:18:03,373][dance.CellTopicProfile][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:18:03,375][dance.CellTopicProfile][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:18:03,377][dance.CellTopicProfile][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:18:03,381][dance.CellTopicProfile][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:18:03,386][dance.CellTopicProfile][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# True
# [INFO][2023-10-18 09:18:03,729][dance.CellTopicProfile][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:18:03,731][dance.CellTopicProfile][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:18:03,737][dance.CellTopicProfile][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:18:03,739][dance.CellTopicProfile][get_ct_profile] Aggregating 'Transitional urothelium' profiles over 45 samples
# [INFO][2023-10-18 09:18:03,742][dance.CellTopicProfile][get_ct_profile] Number of 'Transitional urothelium' cells in batch 0: 45
# [INFO][2023-10-18 09:18:03,744][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:18:03,748][dance.CellTopicProfile][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:18:03,750][dance.CellTopicProfile][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:18:03,752][dance.CellTopicProfile][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:18:03,754][dance.CellTopicProfile][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:18:03,757][dance.CellTopicProfile][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:18:03,758][dance.CellTopicProfile][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:03,760][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:03,760][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:03,761][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39562 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
#     varm: 'CellTopicProfile'
# [INFO][2023-10-18 09:18:03,764][dance][wrapped_func] Took 0:00:01.179652 to load and process data.
# [INFO][2023-10-18 09:18:03,898][dance][fit] Epoch: 100/2250 Loss: 3.43084e+00
# [INFO][2023-10-18 09:18:04,064][dance][fit] Epoch: 200/2250 Loss: 2.63794e+00
# [INFO][2023-10-18 09:18:04,205][dance][fit] Epoch: 300/2250 Loss: 2.19749e+00
# [INFO][2023-10-18 09:18:04,346][dance][fit] Epoch: 400/2250 Loss: 1.90523e+00
# [INFO][2023-10-18 09:18:04,511][dance][fit] Epoch: 500/2250 Loss: 1.69311e+00
# [INFO][2023-10-18 09:18:04,673][dance][fit] Epoch: 600/2250 Loss: 1.53040e+00
# [INFO][2023-10-18 09:18:04,814][dance][fit] Epoch: 700/2250 Loss: 1.40075e+00
# [INFO][2023-10-18 09:18:04,983][dance][fit] Epoch: 800/2250 Loss: 1.29456e+00
# [INFO][2023-10-18 09:18:05,142][dance][fit] Epoch: 900/2250 Loss: 1.20570e+00
# [INFO][2023-10-18 09:18:05,278][dance][fit] Epoch: 1000/2250 Loss: 1.13010e+00
# [INFO][2023-10-18 09:18:05,426][dance][fit] Epoch: 1100/2250 Loss: 1.06489e+00
# [INFO][2023-10-18 09:18:05,609][dance][fit] Epoch: 1200/2250 Loss: 1.00801e+00
# [INFO][2023-10-18 09:18:05,760][dance][fit] Epoch: 1300/2250 Loss: 9.57914e-01
# [INFO][2023-10-18 09:18:05,915][dance][fit] Epoch: 1400/2250 Loss: 9.13442e-01
# [INFO][2023-10-18 09:18:06,096][dance][fit] Epoch: 1500/2250 Loss: 8.73684e-01
# [INFO][2023-10-18 09:18:06,239][dance][fit] Epoch: 1600/2250 Loss: 8.37919e-01
# [INFO][2023-10-18 09:18:06,382][dance][fit] Epoch: 1700/2250 Loss: 8.05575e-01
# [INFO][2023-10-18 09:18:06,558][dance][fit] Epoch: 1800/2250 Loss: 7.76182e-01
# [INFO][2023-10-18 09:18:06,693][dance][fit] Epoch: 1900/2250 Loss: 7.49358e-01
# [INFO][2023-10-18 09:18:06,773][dance][fit] Epoch: 2000/2250 Loss: 7.24786e-01
# [INFO][2023-10-18 09:18:06,864][dance][fit] Epoch: 2100/2250 Loss: 7.02201e-01
# [INFO][2023-10-18 09:18:07,021][dance][fit] Epoch: 2200/2250 Loss: 6.81375e-01
# True
# True
# 'To reproduce SpatialDecon benchmarks, please refer to command lines belows:\n\nCARD synthetic $ python spatialdecon.py --dataset CARD_synthetic --lr .01 --max_iter\n2250 --bias 1\n\nGSE174746 $ python spatialdecon.py --dataset GSE174746 --lr .0001 --max_iter 20000\n--bias 1\n\nSPOTLight synthetic $ python spatialdecon.py --dataset SPOTLight_synthetic --lr .01\n--max_iter 500 --bias 1\n\n'

# %%
SpatialDecon_scores
# Out:
# [0.020546548,
#  0.012112096,
#  0.024561495,
#  0.029576628,
#  0.037299387,
#  0.004355375,
#  0.002765877,
#  0.006421732,
#  0.005125333,
#  0.0069700954,
#  0.005393536,
#  0.003511426,
#  0.0067862123,
#  0.0071246694,
#  0.0050303894]

# %%
import argparse
from pprint import pprint

from dance.datasets.spatial import CellTypeDeconvoDataset
from dance.modules.spatial.cell_type_deconvo.spotlight import SPOTlight
from dance.utils import set_seed

parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument("--cache", action="store_true", help="Cache processed data.")
parser.add_argument("--dataset", default="CARD_synthetic", choices=CellTypeDeconvoDataset.AVAILABLE_DATA)
parser.add_argument("--datadir", default="../../../../data/spatial", help="Directory to save the data.")
parser.add_argument("--lr", type=float, default=1e-3, help="Learning rate.")
parser.add_argument("--rank", type=int, default=2, help="Rank of the NMF module.")
parser.add_argument("--bias", type=bool, default=False, help="Include/Exclude bias term.")
parser.add_argument("--max_iter", type=int, default=4000, help="Maximum optimization iteration.")
parser.add_argument("--seed", type=int, default=17, help="Random seed.")
parser.add_argument("--device", default="auto", help="Computation device.")
SPOTlight_scores=[]
for dataset in datasets:
    try:
        args = parser.parse_args(["--dataset",dataset,"--lr",".1","--max_iter","100","--rank","8","--bias","0"])
        set_seed(args.seed)
        pprint(vars(args))

        # Load dataset
        preprocessing_pipeline = SPOTlight.preprocessing_pipeline()
        dataset = CellTypeDeconvoDataset(data_dir=args.datadir, data_id=args.dataset)
        data = dataset.load_data(transform=preprocessing_pipeline, cache=args.cache)
        cell_types = data.data.obsm["cell_type_portion"].columns.tolist()

        x, y = data.get_data(split_name="test", return_type="torch")
        ref_count = data.get_feature(split_name="ref", return_type="numpy")
        ref_annot = data.get_feature(split_name="ref", return_type="numpy", channel="cellType", channel_type="obs")

        # Train and evaluate model
        model = SPOTlight(ref_count, ref_annot, cell_types, rank=args.rank, bias=args.bias, device=args.device)
        score = model.fit_score(x, y, lr=args.lr, max_iter=args.max_iter)
    except Exception as e:
        score=e
    finally:
        SPOTlight_scores.append(score)
"""To reproduce SpatialDecon benchmarks, please refer to command lines belows:

CARD_synthetic $ python spotlight.py --dataset CARD_synthetic --lr .1 --max_iter 100
--rank 8 --bias 0

GSE174746 $ python spotlight.py --dataset GSE174746 --lr .1 --max_iter 15000 --rank 4
--bias 0

SPOTLight synthetic $ python spotlight.py --dataset SPOTLight_synthetic --lr .1
--max_iter 150 --rank 10 --bias 0

"""
# Out:
# [INFO][2023-10-18 09:18:07,142][dance][set_seed] Setting global random seed to 17
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung6',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:07,419][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:18:07,420][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:07,543][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:07,544][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:07,545][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:07,546][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17465 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:07,548][dance][wrapped_func] Took 0:00:00.404400 to load and process data.
# [INFO][2023-10-18 09:18:07,753][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:18:07,754][dance][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:18:07,756][dance][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:18:07,757][dance][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:18:07,758][dance][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:18:07,759][dance][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:18:07,761][dance][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:18:07,762][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:18:07,763][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:18:07,764][dance][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:18:07,766][dance][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:18:07,767][dance][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:18:07,768][dance][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:18:07,769][dance][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:18:07,770][dance][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:18:07,771][dance][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:18:07,772][dance][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:18:07,773][dance][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:18:07,774][dance][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:18:07,774][dance][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:18:07,776][dance][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:18:07,777][dance][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:18:07,778][dance][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:18:07,779][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:07,827][dance][fit] Epoch: 100/100 Loss: 3.00348e+04
# [INFO][2023-10-18 09:18:07,880][dance][fit] Epoch: 100/100 Loss: 9.35972e-01
# [INFO][2023-10-18 09:18:07,883][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_1',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:08,162][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:18:08,165][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:08,290][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:08,291][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:08,292][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:08,292][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17265 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:08,294][dance][wrapped_func] Took 0:00:00.409708 to load and process data.
# [INFO][2023-10-18 09:18:08,495][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:18:08,496][dance][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:18:08,497][dance][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:18:08,498][dance][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:18:08,499][dance][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:18:08,500][dance][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:18:08,502][dance][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:18:08,503][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:18:08,503][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:18:08,504][dance][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:18:08,506][dance][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:18:08,506][dance][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:18:08,507][dance][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:18:08,508][dance][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:18:08,509][dance][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:18:08,510][dance][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:18:08,511][dance][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:18:08,512][dance][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:18:08,513][dance][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:18:08,514][dance][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:18:08,514][dance][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:18:08,515][dance][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:18:08,516][dance][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:18:08,517][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:08,561][dance][fit] Epoch: 100/100 Loss: 1.86447e+04
# [INFO][2023-10-18 09:18:08,601][dance][fit] Epoch: 100/100 Loss: 1.46802e+00
# [INFO][2023-10-18 09:18:08,604][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'lung9_2',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:08,883][dance][_load_raw_data] Number of cell types: reference = 15, real = 22
# [INFO][2023-10-18 09:18:08,884][dance][_load_raw_data] Subsetting to common cell types (n=11):
# ['B_cell',
#  'Endothelial',
#  'Epithelial',
#  'Fibroblast',
#  'Macrophage',
#  'Mast',
#  'Monocyte',
#  'Myeloid',
#  'NK_cell',
#  'Neutrophil',
#  'Plasma']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:09,006][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:09,007][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:09,007][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:09,008][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 17765 × 923
#     obs: 'cellname', 'sample', 'cellType', 'malignant', 'source', 'cell_subtype', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:09,010][dance][wrapped_func] Took 0:00:00.404714 to load and process data.
# [INFO][2023-10-18 09:18:09,209][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'Fibroblast', 'Macrophage', 'Mast', 'Monocyte', 'Myeloid', 'NK_cell', 'Neutrophil', 'Plasma']
# [INFO][2023-10-18 09:18:09,210][dance][get_ct_profile] Aggregating 'B_cell' profiles over 1,836 samples
# [INFO][2023-10-18 09:18:09,211][dance][get_ct_profile] Number of 'B_cell' cells in batch 0: 1,836
# [INFO][2023-10-18 09:18:09,212][dance][get_ct_profile] Aggregating 'Endothelial' profiles over 984 samples
# [INFO][2023-10-18 09:18:09,213][dance][get_ct_profile] Number of 'Endothelial' cells in batch 0: 984
# [INFO][2023-10-18 09:18:09,214][dance][get_ct_profile] Aggregating 'Epithelial' profiles over 3,786 samples
# [INFO][2023-10-18 09:18:09,216][dance][get_ct_profile] Number of 'Epithelial' cells in batch 0: 3,786
# [INFO][2023-10-18 09:18:09,217][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 263 samples
# [INFO][2023-10-18 09:18:09,217][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 263
# [INFO][2023-10-18 09:18:09,218][dance][get_ct_profile] Aggregating 'Macrophage' profiles over 3,644 samples
# [INFO][2023-10-18 09:18:09,220][dance][get_ct_profile] Number of 'Macrophage' cells in batch 0: 3,644
# [INFO][2023-10-18 09:18:09,221][dance][get_ct_profile] Aggregating 'Mast' profiles over 724 samples
# [INFO][2023-10-18 09:18:09,221][dance][get_ct_profile] Number of 'Mast' cells in batch 0: 724
# [INFO][2023-10-18 09:18:09,222][dance][get_ct_profile] Aggregating 'Monocyte' profiles over 1,593 samples
# [INFO][2023-10-18 09:18:09,223][dance][get_ct_profile] Number of 'Monocyte' cells in batch 0: 1,593
# [INFO][2023-10-18 09:18:09,224][dance][get_ct_profile] Aggregating 'Myeloid' profiles over 1,413 samples
# [INFO][2023-10-18 09:18:09,225][dance][get_ct_profile] Number of 'Myeloid' cells in batch 0: 1,413
# [INFO][2023-10-18 09:18:09,226][dance][get_ct_profile] Aggregating 'NK_cell' profiles over 1,638 samples
# [INFO][2023-10-18 09:18:09,227][dance][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,638
# [INFO][2023-10-18 09:18:09,228][dance][get_ct_profile] Aggregating 'Neutrophil' profiles over 89 samples
# [INFO][2023-10-18 09:18:09,229][dance][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 89
# [INFO][2023-10-18 09:18:09,230][dance][get_ct_profile] Aggregating 'Plasma' profiles over 895 samples
# [INFO][2023-10-18 09:18:09,230][dance][get_ct_profile] Number of 'Plasma' cells in batch 0: 895
# [INFO][2023-10-18 09:18:09,231][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:09,273][dance][fit] Epoch: 100/100 Loss: 4.28036e+03
# [INFO][2023-10-18 09:18:09,317][dance][fit] Epoch: 100/100 Loss: 1.24051e+00
# [INFO][2023-10-18 09:18:09,319][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'hcc_liver',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:09,601][dance][_load_raw_data] Number of cell types: reference = 10, real = 14
# [INFO][2023-10-18 09:18:09,602][dance][_load_raw_data] Subsetting to common cell types (n=6):
# ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:09,707][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 977
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:09,708][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:09,709][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:09,710][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 13785 × 977
#     obs: 'cell_name', 'sample', 'source', 'disease', 'cellType', 'cell_subtype_clusters', 'complexity', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:09,711][dance][wrapped_func] Took 0:00:00.391174 to load and process data.
# [INFO][2023-10-18 09:18:09,836][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['B_cell', 'Endothelial', 'Epithelial', 'HSC', 'NK_cell', 'T_cell']
# [INFO][2023-10-18 09:18:09,837][dance][get_ct_profile] Aggregating 'B_cell' profiles over 819 samples
# [INFO][2023-10-18 09:18:09,838][dance][get_ct_profile] Number of 'B_cell' cells in batch 0: 819
# [INFO][2023-10-18 09:18:09,839][dance][get_ct_profile] Aggregating 'Endothelial' profiles over 99 samples
# [INFO][2023-10-18 09:18:09,840][dance][get_ct_profile] Number of 'Endothelial' cells in batch 0: 99
# [INFO][2023-10-18 09:18:09,840][dance][get_ct_profile] Aggregating 'Epithelial' profiles over 34 samples
# [INFO][2023-10-18 09:18:09,841][dance][get_ct_profile] Number of 'Epithelial' cells in batch 0: 34
# [INFO][2023-10-18 09:18:09,842][dance][get_ct_profile] Aggregating 'HSC' profiles over 119 samples
# [INFO][2023-10-18 09:18:09,842][dance][get_ct_profile] Number of 'HSC' cells in batch 0: 119
# [INFO][2023-10-18 09:18:09,843][dance][get_ct_profile] Aggregating 'NK_cell' profiles over 1,973 samples
# [INFO][2023-10-18 09:18:09,844][dance][get_ct_profile] Number of 'NK_cell' cells in batch 0: 1,973
# [INFO][2023-10-18 09:18:09,845][dance][get_ct_profile] Aggregating 'T_cell' profiles over 7,294 samples
# [INFO][2023-10-18 09:18:09,847][dance][get_ct_profile] Number of 'T_cell' cells in batch 0: 7,294
# [INFO][2023-10-18 09:18:09,848][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:09,902][dance][fit] Epoch: 100/100 Loss: 4.21778e+05
# [INFO][2023-10-18 09:18:09,952][dance][fit] Epoch: 100/100 Loss: 3.17238e+01
# [INFO][2023-10-18 09:18:09,954][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'normal_liver',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:10,069][dance][_load_raw_data] Number of cell types: reference = 14, real = 15
# [INFO][2023-10-18 09:18:10,070][dance][_load_raw_data] Subsetting to common cell types (n=12):
# ['alpha-beta T cell',
#  'central venous liver sinusoidal endothelial cell',
#  'cholangiocyte',
#  'erythroid cell',
#  'gamma-delta T cell',
#  'hepatic stellate cell',
#  'hepatocyte',
#  'inflammatory macrophage',
#  'mature B cell',
#  'natural killer cell',
#  'periportal liver sinusoidal endothelial cell',
#  'portal liver sinusoidal endothelial cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:10,146][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 933
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:10,147][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:10,147][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:10,148][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 10263 × 933
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:10,149][dance][wrapped_func] Took 0:00:00.193044 to load and process data.
# [INFO][2023-10-18 09:18:10,240][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['alpha-beta T cell', 'central venous liver sinusoidal endothelial cell', 'cholangiocyte', 'erythroid cell', 'gamma-delta T cell', 'hepatic stellate cell', 'hepatocyte', 'inflammatory macrophage', 'mature B cell', 'natural killer cell', 'periportal liver sinusoidal endothelial cell', 'portal liver sinusoidal endothelial cell']
# [INFO][2023-10-18 09:18:10,241][dance][get_ct_profile] Aggregating 'alpha-beta T cell' profiles over 961 samples
# [INFO][2023-10-18 09:18:10,242][dance][get_ct_profile] Number of 'alpha-beta T cell' cells in batch 0: 961
# [INFO][2023-10-18 09:18:10,243][dance][get_ct_profile] Aggregating 'central venous liver sinusoidal endothelial cell' profiles over 306 samples
# [INFO][2023-10-18 09:18:10,243][dance][get_ct_profile] Number of 'central venous liver sinusoidal endothelial cell' cells in batch 0: 306
# [INFO][2023-10-18 09:18:10,244][dance][get_ct_profile] Aggregating 'cholangiocyte' profiles over 119 samples
# [INFO][2023-10-18 09:18:10,244][dance][get_ct_profile] Number of 'cholangiocyte' cells in batch 0: 119
# [INFO][2023-10-18 09:18:10,245][dance][get_ct_profile] Aggregating 'erythroid cell' profiles over 93 samples
# [INFO][2023-10-18 09:18:10,246][dance][get_ct_profile] Number of 'erythroid cell' cells in batch 0: 93
# [INFO][2023-10-18 09:18:10,247][dance][get_ct_profile] Aggregating 'gamma-delta T cell' profiles over 569 samples
# [INFO][2023-10-18 09:18:10,247][dance][get_ct_profile] Number of 'gamma-delta T cell' cells in batch 0: 569
# [INFO][2023-10-18 09:18:10,248][dance][get_ct_profile] Aggregating 'hepatic stellate cell' profiles over 37 samples
# [INFO][2023-10-18 09:18:10,249][dance][get_ct_profile] Number of 'hepatic stellate cell' cells in batch 0: 37
# [INFO][2023-10-18 09:18:10,250][dance][get_ct_profile] Aggregating 'hepatocyte' profiles over 3,501 samples
# [INFO][2023-10-18 09:18:10,251][dance][get_ct_profile] Number of 'hepatocyte' cells in batch 0: 3,501
# [INFO][2023-10-18 09:18:10,252][dance][get_ct_profile] Aggregating 'inflammatory macrophage' profiles over 813 samples
# [INFO][2023-10-18 09:18:10,253][dance][get_ct_profile] Number of 'inflammatory macrophage' cells in batch 0: 813
# [INFO][2023-10-18 09:18:10,254][dance][get_ct_profile] Aggregating 'mature B cell' profiles over 129 samples
# [INFO][2023-10-18 09:18:10,254][dance][get_ct_profile] Number of 'mature B cell' cells in batch 0: 129
# [INFO][2023-10-18 09:18:10,255][dance][get_ct_profile] Aggregating 'natural killer cell' profiles over 488 samples
# [INFO][2023-10-18 09:18:10,256][dance][get_ct_profile] Number of 'natural killer cell' cells in batch 0: 488
# [INFO][2023-10-18 09:18:10,257][dance][get_ct_profile] Aggregating 'periportal liver sinusoidal endothelial cell' profiles over 327 samples
# [INFO][2023-10-18 09:18:10,258][dance][get_ct_profile] Number of 'periportal liver sinusoidal endothelial cell' cells in batch 0: 327
# [INFO][2023-10-18 09:18:10,259][dance][get_ct_profile] Aggregating 'portal liver sinusoidal endothelial cell' profiles over 211 samples
# [INFO][2023-10-18 09:18:10,259][dance][get_ct_profile] Number of 'portal liver sinusoidal endothelial cell' cells in batch 0: 211
# [INFO][2023-10-18 09:18:10,260][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:10,315][dance][fit] Epoch: 100/100 Loss: 2.20101e+05
# [INFO][2023-10-18 09:18:10,367][dance][fit] Epoch: 100/100 Loss: 1.17097e+01
# [INFO][2023-10-18 09:18:10,370][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_1139',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:10,604][dance][_load_raw_data] Number of cell types: reference = 31, real = 33
# [INFO][2023-10-18 09:18:10,605][dance][_load_raw_data] Subsetting to common cell types (n=28):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:10,848][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39763 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:10,849][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:10,850][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:10,850][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39763 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:10,852][dance][wrapped_func] Took 0:00:00.480924 to load and process data.
# [INFO][2023-10-18 09:18:11,258][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['Ascending vasa recta endothelium', 'B cell', 'CD4 T cell', 'CD8 T cell', 'Connecting tubule', 'Descending vasa recta endothelium', 'Distinct proximal tubule 1', 'Distinct proximal tubule 2', 'Epithelial progenitor cell', 'Fibroblast', 'Glomerular endothelium', 'Indistinct intercalated cell', 'MNP-a/classical monocyte derived', 'MNP-b/non-classical monocyte derived', 'Mast cell', 'NK cell', 'Neutrophil', 'Pelvic epithelium', 'Peritubular capillary endothelium 1', 'Peritubular capillary endothelium 2', 'Podocyte', 'Principal cell', 'Proliferating Proximal Tubule', 'Proximal tubule', 'Thick ascending limb of Loop of Henle', 'Type A intercalated cell', 'Type B intercalated cell', 'dendritic cell']
# [INFO][2023-10-18 09:18:11,261][dance][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:18:11,262][dance][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:18:11,263][dance][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:18:11,264][dance][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:18:11,265][dance][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:18:11,266][dance][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:18:11,266][dance][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:18:11,267][dance][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:18:11,268][dance][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:18:11,268][dance][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:18:11,269][dance][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:18:11,269][dance][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:18:11,270][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:18:11,271][dance][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:18:11,272][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:18:11,272][dance][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:18:11,273][dance][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:18:11,273][dance][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:18:11,274][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:18:11,275][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:18:11,276][dance][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:18:11,276][dance][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:18:11,277][dance][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:18:11,278][dance][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:18:11,279][dance][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:18:11,279][dance][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:18:11,280][dance][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:18:11,281][dance][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:18:11,282][dance][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:18:11,282][dance][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:18:11,283][dance][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:18:11,284][dance][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:18:11,285][dance][get_ct_profile] Aggregating 'Neutrophil' profiles over 46 samples
# [INFO][2023-10-18 09:18:11,285][dance][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 46
# [INFO][2023-10-18 09:18:11,286][dance][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:18:11,286][dance][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:18:11,287][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:18:11,288][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:18:11,288][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:18:11,289][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:18:11,290][dance][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:18:11,290][dance][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:18:11,291][dance][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:18:11,291][dance][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:18:11,292][dance][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:18:11,292][dance][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:18:11,293][dance][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# [INFO][2023-10-18 09:18:11,297][dance][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:18:11,298][dance][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:18:11,299][dance][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:18:11,300][dance][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:18:11,300][dance][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:18:11,301][dance][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:18:11,301][dance][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:18:11,303][dance][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:18:11,304][dance][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:18:11,304][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:11,358][dance][fit] Epoch: 100/100 Loss: 1.63921e+04
# [INFO][2023-10-18 09:18:11,411][dance][fit] Epoch: 100/100 Loss: 1.06493e+01
# [INFO][2023-10-18 09:18:11,414][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_10838',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:11,644][dance][_load_raw_data] Number of cell types: reference = 31, real = 35
# [INFO][2023-10-18 09:18:11,645][dance][_load_raw_data] Subsetting to common cell types (n=29):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:11,889][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39668 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:11,890][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:11,891][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:11,892][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39668 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:11,893][dance][wrapped_func] Took 0:00:00.478291 to load and process data.
# [INFO][2023-10-18 09:18:12,384][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['Ascending vasa recta endothelium', 'B cell', 'CD4 T cell', 'CD8 T cell', 'Connecting tubule', 'Descending vasa recta endothelium', 'Distinct proximal tubule 1', 'Distinct proximal tubule 2', 'Epithelial progenitor cell', 'Fibroblast', 'Glomerular endothelium', 'Indistinct intercalated cell', 'MNP-a/classical monocyte derived', 'MNP-b/non-classical monocyte derived', 'Mast cell', 'NK cell', 'Neutrophil', 'Pelvic epithelium', 'Peritubular capillary endothelium 1', 'Peritubular capillary endothelium 2', 'Podocyte', 'Principal cell', 'Proliferating Proximal Tubule', 'Proximal tubule', 'Thick ascending limb of Loop of Henle', 'Transitional urothelium', 'Type A intercalated cell', 'Type B intercalated cell', 'dendritic cell']
# [INFO][2023-10-18 09:18:12,387][dance][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:18:12,388][dance][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:18:12,389][dance][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:18:12,391][dance][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:18:12,392][dance][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:18:12,394][dance][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:18:12,395][dance][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:18:12,396][dance][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:18:12,397][dance][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:18:12,399][dance][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:18:12,400][dance][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:18:12,402][dance][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:18:12,403][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:18:12,403][dance][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:18:12,404][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:18:12,404][dance][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:18:12,405][dance][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:18:12,405][dance][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:18:12,406][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:18:12,407][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:18:12,407][dance][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:18:12,408][dance][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:18:12,409][dance][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:18:12,409][dance][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:18:12,410][dance][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:18:12,410][dance][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:18:12,411][dance][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:18:12,412][dance][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:18:12,412][dance][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:18:12,413][dance][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:18:12,413][dance][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:18:12,414][dance][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:18:12,415][dance][get_ct_profile] Aggregating 'Neutrophil' profiles over 46 samples
# [INFO][2023-10-18 09:18:12,415][dance][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 46
# [INFO][2023-10-18 09:18:12,416][dance][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:18:12,417][dance][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:18:12,417][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:18:12,418][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:18:12,418][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:18:12,419][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:18:12,419][dance][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:18:12,420][dance][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:18:12,421][dance][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:18:12,421][dance][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:18:12,422][dance][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:18:12,422][dance][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:18:12,423][dance][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# [INFO][2023-10-18 09:18:12,427][dance][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:18:12,428][dance][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:18:12,429][dance][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:18:12,429][dance][get_ct_profile] Aggregating 'Transitional urothelium' profiles over 45 samples
# [INFO][2023-10-18 09:18:12,430][dance][get_ct_profile] Number of 'Transitional urothelium' cells in batch 0: 45
# [INFO][2023-10-18 09:18:12,431][dance][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:18:12,432][dance][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:18:12,433][dance][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:18:12,434][dance][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:18:12,435][dance][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:18:12,436][dance][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:18:12,437][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:12,491][dance][fit] Epoch: 100/100 Loss: 3.71329e+03
# [INFO][2023-10-18 09:18:12,540][dance][fit] Epoch: 100/100 Loss: 3.72021e+00
# [INFO][2023-10-18 09:18:12,543][dance][set_seed] Setting global random seed to 17
# True
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_3323',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:12,771][dance][_load_raw_data] Number of cell types: reference = 31, real = 35
# [INFO][2023-10-18 09:18:12,772][dance][_load_raw_data] Subsetting to common cell types (n=29):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Neutrophil',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:13,012][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39688 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:13,013][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:13,013][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:13,014][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39688 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:13,016][dance][wrapped_func] Took 0:00:00.472194 to load and process data.
# [INFO][2023-10-18 09:18:13,505][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['Ascending vasa recta endothelium', 'B cell', 'CD4 T cell', 'CD8 T cell', 'Connecting tubule', 'Descending vasa recta endothelium', 'Distinct proximal tubule 1', 'Distinct proximal tubule 2', 'Epithelial progenitor cell', 'Fibroblast', 'Glomerular endothelium', 'Indistinct intercalated cell', 'MNP-a/classical monocyte derived', 'MNP-b/non-classical monocyte derived', 'Mast cell', 'NK cell', 'Neutrophil', 'Pelvic epithelium', 'Peritubular capillary endothelium 1', 'Peritubular capillary endothelium 2', 'Podocyte', 'Principal cell', 'Proliferating Proximal Tubule', 'Proximal tubule', 'Thick ascending limb of Loop of Henle', 'Transitional urothelium', 'Type A intercalated cell', 'Type B intercalated cell', 'dendritic cell']
# [INFO][2023-10-18 09:18:13,506][dance][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:18:13,508][dance][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:18:13,509][dance][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:18:13,510][dance][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:18:13,512][dance][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:18:13,513][dance][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:18:13,515][dance][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:18:13,516][dance][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:18:13,518][dance][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:18:13,519][dance][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:18:13,520][dance][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:18:13,520][dance][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:18:13,521][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:18:13,522][dance][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:18:13,523][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:18:13,523][dance][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:18:13,524][dance][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:18:13,525][dance][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:18:13,526][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:18:13,526][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:18:13,527][dance][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:18:13,527][dance][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:18:13,528][dance][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# ...
# [INFO][2023-10-18 09:18:20,423][dance][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:18:20,423][dance][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:18:20,425][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:18:20,426][dance][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:18:20,428][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:18:20,429][dance][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:18:20,430][dance][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:18:20,431][dance][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:18:20,433][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:18:20,434][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:18:20,435][dance][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:18:20,436][dance][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:18:20,438][dance][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:18:20,439][dance][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:18:20,440][dance][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:18:20,442][dance][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:18:20,443][dance][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:18:20,444][dance][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:18:20,446][dance][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:18:20,447][dance][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:18:20,448][dance][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:18:20,449][dance][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:18:20,451][dance][get_ct_profile] Aggregating 'Neutrophil' profiles over 46 samples
# [INFO][2023-10-18 09:18:20,452][dance][get_ct_profile] Number of 'Neutrophil' cells in batch 0: 46
# [INFO][2023-10-18 09:18:20,454][dance][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:18:20,455][dance][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:18:20,456][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:18:20,458][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:18:20,460][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:18:20,461][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:18:20,462][dance][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:18:20,463][dance][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:18:20,465][dance][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:18:20,466][dance][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:18:20,468][dance][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:18:20,469][dance][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:18:20,471][dance][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# [INFO][2023-10-18 09:18:20,476][dance][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:18:20,478][dance][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:18:20,479][dance][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:18:20,480][dance][get_ct_profile] Aggregating 'Transitional urothelium' profiles over 45 samples
# [INFO][2023-10-18 09:18:20,482][dance][get_ct_profile] Number of 'Transitional urothelium' cells in batch 0: 45
# [INFO][2023-10-18 09:18:20,483][dance][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:18:20,485][dance][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:18:20,486][dance][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:18:20,487][dance][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:18:20,489][dance][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:18:20,490][dance][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:18:20,491][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:20,552][dance][fit] Epoch: 100/100 Loss: 2.37466e+03
# [INFO][2023-10-18 09:18:20,608][dance][fit] Epoch: 100/100 Loss: 1.24243e+00
# True
# [INFO][2023-10-18 09:18:20,611][dance][set_seed] Setting global random seed to 17
# True
# True
# {'bias': True,
#  'cache': False,
#  'datadir': '../../../../data/spatial',
#  'dataset': 'kidney_8471',
#  'device': 'auto',
#  'lr': 0.1,
#  'max_iter': 100,
#  'rank': 8,
#  'seed': 17}
# [INFO][2023-10-18 09:18:20,841][dance][_load_raw_data] Number of cell types: reference = 31, real = 34
# [INFO][2023-10-18 09:18:20,841][dance][_load_raw_data] Subsetting to common cell types (n=28):
# ['Ascending vasa recta endothelium',
#  'B cell',
#  'CD4 T cell',
#  'CD8 T cell',
#  'Connecting tubule',
#  'Descending vasa recta endothelium',
#  'Distinct proximal tubule 1',
#  'Distinct proximal tubule 2',
#  'Epithelial progenitor cell',
#  'Fibroblast',
#  'Glomerular endothelium',
#  'Indistinct intercalated cell',
#  'MNP-a/classical monocyte derived',
#  'MNP-b/non-classical monocyte derived',
#  'Mast cell',
#  'NK cell',
#  'Pelvic epithelium',
#  'Peritubular capillary endothelium 1',
#  'Peritubular capillary endothelium 2',
#  'Podocyte',
#  'Principal cell',
#  'Proliferating Proximal Tubule',
#  'Proximal tubule',
#  'Thick ascending limb of Loop of Henle',
#  'Transitional urothelium',
#  'Type A intercalated cell',
#  'Type B intercalated cell',
#  'dendritic cell']
# /home/zyxing/anaconda3/envs/dance/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# [INFO][2023-10-18 09:18:21,075][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39562 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:21,076][dance.SetConfig][__call__] Updating the dance data object config options:
# {'label_channel': 'cell_type_portion'}
# [INFO][2023-10-18 09:18:21,077][dance][set_config_from_dict] Setting config 'label_channel' to 'cell_type_portion'
# [INFO][2023-10-18 09:18:21,078][dance][load_data] Data transformed:
# Data object that wraps (.data):
# AnnData object with n_obs × n_vars = 39562 × 952
#     obs: 'cellType', 'batch'
#     uns: 'dance_config'
#     obsm: 'cell_type_portion', 'spatial'
# [INFO][2023-10-18 09:18:21,079][dance][wrapped_func] Took 0:00:00.466948 to load and process data.
# [INFO][2023-10-18 09:18:21,481][dance][get_ct_profile] Generating cell-type profiles ('median' aggregation) for ['Ascending vasa recta endothelium', 'B cell', 'CD4 T cell', 'CD8 T cell', 'Connecting tubule', 'Descending vasa recta endothelium', 'Distinct proximal tubule 1', 'Distinct proximal tubule 2', 'Epithelial progenitor cell', 'Fibroblast', 'Glomerular endothelium', 'Indistinct intercalated cell', 'MNP-a/classical monocyte derived', 'MNP-b/non-classical monocyte derived', 'Mast cell', 'NK cell', 'Pelvic epithelium', 'Peritubular capillary endothelium 1', 'Peritubular capillary endothelium 2', 'Podocyte', 'Principal cell', 'Proliferating Proximal Tubule', 'Proximal tubule', 'Thick ascending limb of Loop of Henle', 'Transitional urothelium', 'Type A intercalated cell', 'Type B intercalated cell', 'dendritic cell']
# [INFO][2023-10-18 09:18:21,484][dance][get_ct_profile] Aggregating 'Ascending vasa recta endothelium' profiles over 300 samples
# [INFO][2023-10-18 09:18:21,485][dance][get_ct_profile] Number of 'Ascending vasa recta endothelium' cells in batch 0: 300
# [INFO][2023-10-18 09:18:21,487][dance][get_ct_profile] Aggregating 'B cell' profiles over 975 samples
# [INFO][2023-10-18 09:18:21,488][dance][get_ct_profile] Number of 'B cell' cells in batch 0: 975
# [INFO][2023-10-18 09:18:21,490][dance][get_ct_profile] Aggregating 'CD4 T cell' profiles over 2,435 samples
# [INFO][2023-10-18 09:18:21,491][dance][get_ct_profile] Number of 'CD4 T cell' cells in batch 0: 2,435
# [INFO][2023-10-18 09:18:21,493][dance][get_ct_profile] Aggregating 'CD8 T cell' profiles over 991 samples
# [INFO][2023-10-18 09:18:21,494][dance][get_ct_profile] Number of 'CD8 T cell' cells in batch 0: 991
# [INFO][2023-10-18 09:18:21,496][dance][get_ct_profile] Aggregating 'Connecting tubule' profiles over 157 samples
# [INFO][2023-10-18 09:18:21,497][dance][get_ct_profile] Number of 'Connecting tubule' cells in batch 0: 157
# [INFO][2023-10-18 09:18:21,498][dance][get_ct_profile] Aggregating 'Descending vasa recta endothelium' profiles over 192 samples
# [INFO][2023-10-18 09:18:21,499][dance][get_ct_profile] Number of 'Descending vasa recta endothelium' cells in batch 0: 192
# [INFO][2023-10-18 09:18:21,501][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 1' profiles over 65 samples
# [INFO][2023-10-18 09:18:21,502][dance][get_ct_profile] Number of 'Distinct proximal tubule 1' cells in batch 0: 65
# [INFO][2023-10-18 09:18:21,504][dance][get_ct_profile] Aggregating 'Distinct proximal tubule 2' profiles over 151 samples
# [INFO][2023-10-18 09:18:21,505][dance][get_ct_profile] Number of 'Distinct proximal tubule 2' cells in batch 0: 151
# [INFO][2023-10-18 09:18:21,506][dance][get_ct_profile] Aggregating 'Epithelial progenitor cell' profiles over 238 samples
# [INFO][2023-10-18 09:18:21,507][dance][get_ct_profile] Number of 'Epithelial progenitor cell' cells in batch 0: 238
# [INFO][2023-10-18 09:18:21,509][dance][get_ct_profile] Aggregating 'Fibroblast' profiles over 145 samples
# [INFO][2023-10-18 09:18:21,510][dance][get_ct_profile] Number of 'Fibroblast' cells in batch 0: 145
# [INFO][2023-10-18 09:18:21,512][dance][get_ct_profile] Aggregating 'Glomerular endothelium' profiles over 622 samples
# [INFO][2023-10-18 09:18:21,513][dance][get_ct_profile] Number of 'Glomerular endothelium' cells in batch 0: 622
# [INFO][2023-10-18 09:18:21,514][dance][get_ct_profile] Aggregating 'Indistinct intercalated cell' profiles over 429 samples
# [INFO][2023-10-18 09:18:21,515][dance][get_ct_profile] Number of 'Indistinct intercalated cell' cells in batch 0: 429
# [INFO][2023-10-18 09:18:21,517][dance][get_ct_profile] Aggregating 'MNP-a/classical monocyte derived' profiles over 555 samples
# [INFO][2023-10-18 09:18:21,518][dance][get_ct_profile] Number of 'MNP-a/classical monocyte derived' cells in batch 0: 555
# [INFO][2023-10-18 09:18:21,519][dance][get_ct_profile] Aggregating 'MNP-b/non-classical monocyte derived' profiles over 375 samples
# [INFO][2023-10-18 09:18:21,521][dance][get_ct_profile] Number of 'MNP-b/non-classical monocyte derived' cells in batch 0: 375
# [INFO][2023-10-18 09:18:21,522][dance][get_ct_profile] Aggregating 'Mast cell' profiles over 41 samples
# [INFO][2023-10-18 09:18:21,523][dance][get_ct_profile] Number of 'Mast cell' cells in batch 0: 41
# [INFO][2023-10-18 09:18:21,525][dance][get_ct_profile] Aggregating 'NK cell' profiles over 1,322 samples
# [INFO][2023-10-18 09:18:21,526][dance][get_ct_profile] Number of 'NK cell' cells in batch 0: 1,322
# [INFO][2023-10-18 09:18:21,528][dance][get_ct_profile] Aggregating 'Pelvic epithelium' profiles over 136 samples
# [INFO][2023-10-18 09:18:21,529][dance][get_ct_profile] Number of 'Pelvic epithelium' cells in batch 0: 136
# [INFO][2023-10-18 09:18:21,530][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 1' profiles over 666 samples
# [INFO][2023-10-18 09:18:21,531][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 1' cells in batch 0: 666
# [INFO][2023-10-18 09:18:21,533][dance][get_ct_profile] Aggregating 'Peritubular capillary endothelium 2' profiles over 185 samples
# [INFO][2023-10-18 09:18:21,534][dance][get_ct_profile] Number of 'Peritubular capillary endothelium 2' cells in batch 0: 185
# [INFO][2023-10-18 09:18:21,536][dance][get_ct_profile] Aggregating 'Podocyte' profiles over 126 samples
# [INFO][2023-10-18 09:18:21,537][dance][get_ct_profile] Number of 'Podocyte' cells in batch 0: 126
# [INFO][2023-10-18 09:18:21,538][dance][get_ct_profile] Aggregating 'Principal cell' profiles over 88 samples
# [INFO][2023-10-18 09:18:21,539][dance][get_ct_profile] Number of 'Principal cell' cells in batch 0: 88
# [INFO][2023-10-18 09:18:21,541][dance][get_ct_profile] Aggregating 'Proliferating Proximal Tubule' profiles over 348 samples
# [INFO][2023-10-18 09:18:21,542][dance][get_ct_profile] Number of 'Proliferating Proximal Tubule' cells in batch 0: 348
# [INFO][2023-10-18 09:18:21,544][dance][get_ct_profile] Aggregating 'Proximal tubule' profiles over 27,497 samples
# [INFO][2023-10-18 09:18:21,548][dance][get_ct_profile] Number of 'Proximal tubule' cells in batch 0: 27,497
# [INFO][2023-10-18 09:18:21,550][dance][get_ct_profile] Aggregating 'Thick ascending limb of Loop of Henle' profiles over 675 samples
# [INFO][2023-10-18 09:18:21,551][dance][get_ct_profile] Number of 'Thick ascending limb of Loop of Henle' cells in batch 0: 675
# [INFO][2023-10-18 09:18:21,552][dance][get_ct_profile] Aggregating 'Transitional urothelium' profiles over 45 samples
# [INFO][2023-10-18 09:18:21,554][dance][get_ct_profile] Number of 'Transitional urothelium' cells in batch 0: 45
# [INFO][2023-10-18 09:18:21,555][dance][get_ct_profile] Aggregating 'Type A intercalated cell' profiles over 275 samples
# [INFO][2023-10-18 09:18:21,556][dance][get_ct_profile] Number of 'Type A intercalated cell' cells in batch 0: 275
# [INFO][2023-10-18 09:18:21,557][dance][get_ct_profile] Aggregating 'Type B intercalated cell' profiles over 125 samples
# [INFO][2023-10-18 09:18:21,559][dance][get_ct_profile] Number of 'Type B intercalated cell' cells in batch 0: 125
# [INFO][2023-10-18 09:18:21,560][dance][get_ct_profile] Aggregating 'dendritic cell' profiles over 243 samples
# [INFO][2023-10-18 09:18:21,561][dance][get_ct_profile] Number of 'dendritic cell' cells in batch 0: 243
# [INFO][2023-10-18 09:18:21,562][dance][get_ct_profile] Cell-type profile generated
# [INFO][2023-10-18 09:18:21,622][dance][fit] Epoch: 100/100 Loss: 3.07824e+03
# [INFO][2023-10-18 09:18:21,678][dance][fit] Epoch: 100/100 Loss: 1.85358e+00
# True
# True
# True
# 'To reproduce SpatialDecon benchmarks, please refer to command lines belows:\n\nCARD_synthetic $ python spotlight.py --dataset CARD_synthetic --lr .1 --max_iter 100\n--rank 8 --bias 0\n\nGSE174746 $ python spotlight.py --dataset GSE174746 --lr .1 --max_iter 15000 --rank 4\n--bias 0\n\nSPOTLight synthetic $ python spotlight.py --dataset SPOTLight_synthetic --lr .1\n--max_iter 150 --rank 10 --bias 0\n\n'

# %%
SPOTlight_scores
# Out:
# [0.024866568,
#  0.018249623,
#  0.04081243,
#  0.032837987,
#  0.024835482,
#  0.0042338525,
#  0.0025953983,
#  0.0055743875,
#  0.005686653,
#  0.0083912825,
#  0.0047201323,
#  0.0035900192,
#  0.0053713303,
#  0.0060201143,
#  0.004751296]
